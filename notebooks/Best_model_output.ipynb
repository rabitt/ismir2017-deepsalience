# %% [markdown]
# This notebook computes outputs of a few different models in a hacky adhoc way. It loads a model (specified in the imports) and its weights from a specific pickle file path.
# The data path determines which input npy files are used.
# I ran this to quickly generate (and evaluate) outputs of the models trained for different melody definitions.

# %%
cd ../deepsalience/
# Out:
# /scratch/rmb456/multif0/deepsalience

# %%
# from multif0_exper11_batchin import model_def
from multif0_exper11_batchin_mel2 import model_def
import core
import medleydb as mdb
import evaluate
import glob
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# pkl_path = "../experiment_output/multif0_exper11_batchin/multif0_exper11_batchin.pkl"
# pkl_path = "../experiment_output/multif0_exper11_batchin_mel3/multif0_exper11_batchin_mel3.pkl"
# pkl_path = "../experiment_output/multif0_exper11_batchin_mf0incomplete/multif0_exper11_batchin_mf0incomplete.pkl"
pkl_path = "../experiment_output/multif0_exper11_batchin_mel2/multif0_exper11_batchin_mel2.pkl"

# %%
model = model_def()
model.load_weights(pkl_path)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, None, None, 6)     0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, None, None, 6)     24
# _________________________________________________________________
# bendy1 (Conv2D)              (None, None, None, 128)   19328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, None, None, 128)   512
# _________________________________________________________________
# bendy2 (Conv2D)              (None, None, None, 64)    204864
# _________________________________________________________________
# batch_normalization_15 (Batc (None, None, None, 64)    256
# _________________________________________________________________
# smoothy1 (Conv2D)            (None, None, None, 64)    36928
# _________________________________________________________________
# batch_normalization_16 (Batc (None, None, None, 64)    256
# _________________________________________________________________
# smoothy2 (Conv2D)            (None, None, None, 64)    36928
# _________________________________________________________________
# batch_normalization_17 (Batc (None, None, None, 64)    256
# _________________________________________________________________
# distribute (Conv2D)          (None, None, None, 8)     107528
# _________________________________________________________________
# batch_normalization_18 (Batc (None, None, None, 8)     32
# _________________________________________________________________
# squishy (Conv2D)             (None, None, None, 1)     9
# _________________________________________________________________
# lambda_3 (Lambda)            (None, None, None)        0
# =================================================================
# Total params: 406,921
# Trainable params: 406,253
# Non-trainable params: 668
# _________________________________________________________________

# %%
# mf0_incomplete_path = core.data_path_multif0_incomplete()
# mf0_mel3_path = core.data_path_melody3()
mf0_mel2_path = core.data_path_melody2()
output_path = "../experiment_output_submission/Model_11b_mel2_outputs/"
mtracks = list(mdb.load_all_multitracks(dataset_version=['V1']))

# %%
for mtrack in mtracks:
    if mtrack.melody1_annotation is not None:
        print(mtrack.track_id)
        # get input numpy file
        input_npy = glob.glob(
            os.path.join(mf0_mel2_path, 'inputs', '{}*.npy'.format(mtrack.track_id))
        )[0]
        
        # get predicted output
        print("    Getting prediction...")
        predicted_output, input_hcqt = evaluate.get_single_test_prediction(model npy_file=input_npy)
        
        # save output numpy
        print("    Saving prediction...")
        np.save(
            os.path.join(output_path, '{}_prediction.npy'.format(mtrack.track_id)),
            predicted_output.astype(np.float32)
        )
        
        print("    Plotting output...")
        plt.figure(figsize=(15, 15))

        plt.subplot(2, 1, 1)
        plt.imshow(input_hcqt[0, :, :, 1], origin='lower')
        plt.axis('auto')
        plt.colorbar()

        plt.subplot(2, 1, 2)
        plt.imshow(predicted_output, origin='lower')
        plt.axis('auto')
        plt.colorbar()

        plot_save_path = os.path.join(output_path, '{}_plot.pdf'.format(mtrack.track_id))
        plt.savefig(plot_save_path, format='pdf')
        plt.close()
    else:
        print("    > {} does not have melody".format(mtrack.track_id))
# Out:
# AClassicEducation_NightOwl
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# AimeeNorwich_Child
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# AimeeNorwich_Flying
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# AlexanderRoss_GoodbyeBolero
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# AlexanderRoss_VelvetCurtain
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# AmarLal_Rest
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# AmarLal_SpringDay1
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Auctioneer_OurFutureFaces
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# AvaLuna_Waterduct
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# BigTroubles_Phantom
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# BrandonWebster_DontHearAThing
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# BrandonWebster_YesSirICanFly
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# CelestialShore_DieForUs
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# ChrisJacoby_BoothShotLincoln
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# ChrisJacoby_PigsFoot
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# ClaraBerryAndWooldog_AirTraffic
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# ClaraBerryAndWooldog_Boys
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# ClaraBerryAndWooldog_Stella
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# ClaraBerryAndWooldog_TheBadGuys
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# ClaraBerryAndWooldog_WaltzForMyVictims
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Creepoid_OldTree
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# CroqueMadame_Oil
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# CroqueMadame_Pilot
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Debussy_LenfantProdigue
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# DreamersOfTheGhetto_HeavyLove
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# EthanHein_1930sSynthAndUprightBass
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
#     > EthanHein_BluesForNofi does not have melody
# EthanHein_GirlOnABridge
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
#     > EthanHein_HarmonicaFigure does not have melody
# FacesOnFilm_WaitingForGa
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# FamilyBand_Again
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
#     > Grants_PunchDrunk does not have melody
# Handel_TornamiAVagheggiar
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# HeladoNegro_MitadDelMundo
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# HezekiahJones_BorrowedHeart
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# HopAlong_SisterCities
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# InvisibleFamiliars_DisturbingWildlife
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# JoelHelander_Definition
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# JoelHelander_ExcessiveResistancetoChange
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# JoelHelander_IntheAtticBedroom
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# KarimDouaidy_Hopscotch
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# KarimDouaidy_Yatora
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# LizNelson_Coldwar
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# LizNelson_ImComingHome
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# LizNelson_Rainfall
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
#     > Lushlife_ToynbeeSuite does not have melody
#     > MatthewEntwistle_AnEveningWithOliver does not have melody
# MatthewEntwistle_DontYouEver
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MatthewEntwistle_FairerHopes
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MatthewEntwistle_ImpressionsOfSaturn
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MatthewEntwistle_Lontano
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MatthewEntwistle_TheArch
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MatthewEntwistle_TheFlaxenField
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Meaxic_TakeAStep
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Meaxic_YouListen
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MichaelKropf_AllGoodThings
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Mozart_BesterJungling
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Mozart_DiesBildnis
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_80sRock
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Beatles
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_BebopJazz
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Beethoven
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Britpop
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_ChineseChaoZhou
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_ChineseDrama
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_ChineseHenan
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_ChineseJiangNan
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_ChineseXinJing
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_ChineseYaoZu
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_CoolJazz
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Country1
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Country2
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Disco
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_FreeJazz
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_FunkJazz
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_FusionJazz
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Gospel
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_GriegTrolltog
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Grunge
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Hendrix
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_InTheHalloftheMountainKing
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_LatinJazz
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_ModalJazz
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Pachelbel
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Punk
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Reggae
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Rock
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Rockabilly
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Shadows
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_SpeedMetal
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_SwingJazz
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Vivaldi
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# MusicDelta_Zeppelin
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# NightPanther_Fire
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Phoenix_BrokenPledgeChicagoReel
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Phoenix_ColliersDaughter
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Phoenix_ElzicsFarewell
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Phoenix_LarkOnTheStrandDrummondCastle
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Phoenix_ScotchMorris
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Phoenix_SeanCaughlinsTheScartaglen
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# PortStWillow_StayEven
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# PurlingHiss_Lolita
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Schubert_Erstarrung
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Schumann_Mignon
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# SecretMountains_HighHorse
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# Snowmine_Curfews
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# StevenClark_Bounty
#     Getting prediction...
#     Saving prediction...
#     Plotting output...
# StrandOfOaks_Spacestation
#     Getting prediction...

# %%
ls /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/inputs/
# Out:
# AcDc_BackInBlack_multif0_incomplete_input.npy
# AClassicEducation_NightOwl_multif0_incomplete_input.npy
# Adele_SomeoneLikeYou_multif0_incomplete_input.npy
# Aerosmith_LoveInAnElevator_multif0_incomplete_input.npy
# AHa_TakeOnMe_multif0_incomplete_input.npy
# AimeeNorwich_Child_multif0_incomplete_input.npy
# AimeeNorwich_Flying_multif0_incomplete_input.npy
# AlanisMorissette_YouOughtaKnow_multif0_incomplete_input.npy
# AlexanderRoss_GoodbyeBolero_multif0_incomplete_input.npy
# AlexanderRoss_VelvetCurtain_multif0_incomplete_input.npy
# AllThatRemains_Chiron_multif0_incomplete_input.npy
# AmarLal_Rest_multif0_incomplete_input.npy
# AmarLal_SpringDay1_multif0_incomplete_input.npy
# Anberlin_TheFeelGoodDrag_multif0_incomplete_input.npy
# AnEndlessSporadic_Anything_multif0_incomplete_input.npy
# ArcadeFire_BlackMirror_multif0_incomplete_input.npy
# ArcticMonkeys_Brainstorm_multif0_incomplete_input.npy
# Auctioneer_OurFutureFaces_multif0_incomplete_input.npy
# AvaLuna_Waterduct_multif0_incomplete_input.npy
# Bach10_01AchGottundHerr_multif0_incomplete_input.npy
# Bach10_02AchLiebenChristen_multif0_incomplete_input.npy
# Bach10_03ChristederdubistTagundLicht_multif0_incomplete_input.npy
# Bach10_04ChristeDuBeistand_multif0_incomplete_input.npy
# Bach10_05DieNacht_multif0_incomplete_input.npy
# Bach10_06DieSonne_multif0_incomplete_input.npy
# Bach10_07HerrGott_multif0_incomplete_input.npy
# Bach10_08FuerDeinenThron_multif0_incomplete_input.npy
# Bach10_09Jesus_multif0_incomplete_input.npy
# Bach10_10NunBitten_multif0_incomplete_input.npy
# BigTroubles_Phantom_multif0_incomplete_input.npy
# BillyIdol_WhiteWedding_multif0_incomplete_input.npy
# BillySquier_TheStroke_multif0_incomplete_input.npy
# BlackEyedPeas_IGottaFeeling_multif0_incomplete_input.npy
# BlackSabbath_WarPigs_multif0_incomplete_input.npy
# Blink182_AllTheSmallThings_multif0_incomplete_input.npy
# Blondie_OneWayOrAnother_multif0_incomplete_input.npy
# BlueOysterCult_DontFearTheReaper_multif0_incomplete_input.npy
# BobSeger_OldTimeRockAndRoll_multif0_incomplete_input.npy
# Boston_MoreThanAFeeling_multif0_incomplete_input.npy
# BradPaisley_MudOnTheTires_multif0_incomplete_input.npy
# BrandonWebster_DontHearAThing_multif0_incomplete_input.npy
# BrandonWebster_YesSirICanFly_multif0_incomplete_input.npy
# BrooksDunn_HillbillyDeluxe_multif0_incomplete_input.npy
# BrunoMars_Grenade_multif0_incomplete_input.npy
# BrunoMars_JustTheWayYouAre_multif0_incomplete_input.npy
# BrunoMars_MarryYou_multif0_incomplete_input.npy
# BryanAdams_SummerOf69_multif0_incomplete_input.npy
# Bush_Machinehead_multif0_incomplete_input.npy
# CarlDouglas_KungFuFighting_multif0_incomplete_input.npy
# CarrieUnderwood_HomeSweetHome_multif0_incomplete_input.npy
# CassandraJenkins_PerfectDay_multif0_incomplete_input.npy
# CatMartino_IPromise_multif0_incomplete_input.npy
# Cayetana_MissThing_multif0_incomplete_input.npy
# CeeloGreen_ForgetYou_multif0_incomplete_input.npy
# CelestialShore_DieForUs_multif0_incomplete_input.npy
# CheapTrick_IWantYouToWantMe_multif0_incomplete_input.npy
# CherryPoppinDaddies_ZootSuitRiot_multif0_incomplete_input.npy
# ChrisBrown_Yeah_multif0_incomplete_input.npy
# ChrisJacoby_BoothShotLincoln_multif0_incomplete_input.npy
# ChrisJacoby_PigsFoot_multif0_incomplete_input.npy
# ChristinaAguilera_GenieInABottle_multif0_incomplete_input.npy
# Chromeo_Tenderoni_multif0_incomplete_input.npy
# ClaraBerryAndWooldog_AirTraffic_multif0_incomplete_input.npy
# ClaraBerryAndWooldog_Boys_multif0_incomplete_input.npy
# ClaraBerryAndWooldog_Stella_multif0_incomplete_input.npy
# ClaraBerryAndWooldog_TheBadGuys_multif0_incomplete_input.npy
# ClaraBerryAndWooldog_WaltzForMyVictims_multif0_incomplete_input.npy
# Coldplay_InMyPlace_multif0_incomplete_input.npy
# Coldplay_Shiver_multif0_incomplete_input.npy
# ColdWarKids_HangMeUpToDry_multif0_incomplete_input.npy
# CorinneBaileyRae_PutYourRecordsOn_multif0_incomplete_input.npy
# CountingCrows_AccidentallyInLove_multif0_incomplete_input.npy
# CountZero_Shake_multif0_incomplete_input.npy
# Creepoid_OldTree_multif0_incomplete_input.npy
# CroqueMadame_Oil_multif0_incomplete_input.npy
# CroqueMadame_Pilot_multif0_incomplete_input.npy
# DeadMilkmen_PrisonersCinema_multif0_incomplete_input.npy
# Debussy_LenfantProdigue_multif0_incomplete_input.npy
# DreamersOfTheGhetto_HeavyLove_multif0_incomplete_input.npy
# EthanHein_1930sSynthAndUprightBass_multif0_incomplete_input.npy
# EthanHein_BluesForNofi_multif0_incomplete_input.npy
# EthanHein_GirlOnABridge_multif0_incomplete_input.npy
# FacesOnFilm_WaitingForGa_multif0_incomplete_input.npy
# FamilyBand_Again_multif0_incomplete_input.npy
# FilthyBird_IdLikeToKnow_multif0_incomplete_input.npy
# FleetwoodMac_Rhiannon_multif0_incomplete_input.npy
# FlightOfTheConcords_BusinessTime_multif0_incomplete_input.npy
# FooFighters_AllMyLife_multif0_incomplete_input.npy
# FruitCathedral_KeepMeRunnin_multif0_incomplete_input.npy
# Grants_PunchDrunk_multif0_incomplete_input.npy
# Handel_TornamiAVagheggiar_multif0_incomplete_input.npy
# HeladoNegro_MitadDelMundo_multif0_incomplete_input.npy
# HezekiahJones_BorrowedHeart_multif0_incomplete_input.npy
# HopAlong_SisterCities_multif0_incomplete_input.npy
# Incubus_Drive_multif0_incomplete_input.npy
# InvisibleFamiliars_DisturbingWildlife_multif0_incomplete_input.npy
# Plasma_GoodShout_multif0_incomplete_input.npy
# PortStWillow_StayEven_multif0_incomplete_input.npy
# PurlingHiss_Lolita_multif0_incomplete_input.npy
# Schubert_Erstarrung_multif0_incomplete_input.npy
# Schumann_Mignon_multif0_incomplete_input.npy
# SecretMountains_HighHorse_multif0_incomplete_input.npy
# SlowGhost_FirstSnow_multif0_incomplete_input.npy
# SlowGhost_MidnightGroove_multif0_incomplete_input.npy
# SlowGhost_Peanut_multif0_incomplete_input.npy
# SlowGhost_YoureAMystery_multif0_incomplete_input.npy
# Snowmine_Curfews_multif0_incomplete_input.npy
# StevenClark_Bounty_multif0_incomplete_input.npy
# StrandOfOaks_Spacestation_multif0_incomplete_input.npy
# SweetLights_YouLetMeDown_multif0_incomplete_input.npy
# TablaBreakbeatScience_Animoog_multif0_incomplete_input.npy
# TablaBreakbeatScience_CaptainSky_multif0_incomplete_input.npy
# TablaBreakbeatScience_PhaseTransition_multif0_incomplete_input.npy
# TablaBreakbeatScience_WhoIsIt_multif0_incomplete_input.npy
# TalkingHeads_PsychoKiller_multif0_incomplete_input.npy
# TaylorSwift_LoveStory_multif0_incomplete_input.npy
# TaylorSwift_YouBelongWithMe_multif0_incomplete_input.npy
# TearsForFears_EverybodyWantsToRuleTheWorld_multif0_incomplete_input.npy
# Tesla_ModernDayCowboy_multif0_incomplete_input.npy
# TheAllAmericanRejects_DirtyLittleSecret_multif0_incomplete_input.npy
# TheAllmanBrothersBand_RamblinMan_multif0_incomplete_input.npy
# TheBronx_FalseAlarm_multif0_incomplete_input.npy
# TheBronx_SixDaysAWeek_multif0_incomplete_input.npy
# TheDistricts_Vermont_multif0_incomplete_input.npy
# TheFranckDuo_FranckViolinSonataInAMajorMovement1_multif0_incomplete_input.npy
# TheKillers_SomebodyToldMe_multif0_incomplete_input.npy
# TheKitchenettes_Alive_multif0_incomplete_input.npy
# TheKooks_Naive_multif0_incomplete_input.npy
# TheLastGoodnight_PicturesOfYou_multif0_incomplete_input.npy
# TheScarletBrand_LesFleursDuMal_multif0_incomplete_input.npy
# TheSoSoGlos_Emergency_multif0_incomplete_input.npy
# TheTonTons_Lush_multif0_incomplete_input.npy
# TheTurtles_HappyTogether_multif0_incomplete_input.npy
# ThinLizzy_TheBoysAreBackInTown_multif0_incomplete_input.npy
# ThirdEyeBlind_Jumper_multif0_incomplete_input.npy
# ThirdEyeBlind_NeverLetYouGo_multif0_incomplete_input.npy
# TomPettyAndTheHeartbreakers_IWontBackDown_multif0_incomplete_input.npy
# TomPetty_FreeFallin_multif0_incomplete_input.npy
# Tonic_IfYouCouldOnlySee_multif0_incomplete_input.npy
# Torres_NewSkin_multif0_incomplete_input.npy
# TPain_Bartender_multif0_incomplete_input.npy
# TrevorAndTheSoundwaves_AloneAndSad_multif0_incomplete_input.npy
# VampireWeekend_Cousins_multif0_incomplete_input.npy
# VampireWeekend_Holiday_multif0_incomplete_input.npy
# VanillaIce_IceIceBaby_multif0_incomplete_input.npy
# VillagePeople_Ymca_multif0_incomplete_input.npy
# Wolf_DieBekherte_multif0_incomplete_input.npy
