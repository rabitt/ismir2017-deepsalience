# %%
cd ../
# Out:
# /home/rmb456/repos/multif0

# %%
# %run compute_training_data.py --help
# Out:
# usage: compute_training_data.py [-h] [--blur-labels]
#                                 save_dir option n_jobs precomputed_hcqt_path
#
# Generate feature files for multif0 learning.
#
# positional arguments:
#   save_dir              Path to save npz files.
#   option                Type of data to compute. One of 'solo_pitch'
#                         'melody1', 'melody2', 'melody3' 'multif0_incomplete',
#                         'multif0_complete'.
#   n_jobs                Number of jobs to run in parallel.
#   precomputed_hcqt_path
#                         Path to folder with hcqts precomputed
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --blur-labels

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/" "multif0_complete" -1 '' "--blur-labels"
# Out:
# AClassicEducation_NightOwl
#    AClassicEducation_NightOwl already computed!
# AimeeNorwich_Child
#    AimeeNorwich_Child already computed!
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
#    AimeeNorwich_Flying already computed!
# ClaraBerryAndWooldog_Boys
# FamilyBand_Again
# LizNelson_Rainfall
# MusicDelta_80sRock
#     Saved data to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/MusicDelta_80sRock_multif0_complete.npz
# MusicDelta_Beatles
#     Saved data to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/MusicDelta_Beatles_multif0_complete.npz
# MusicDelta_BebopJazz
#     Saved data to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/ClaraBerryAndWooldog_Boys_multif0_complete.npz
# ClaraBerryAndWooldog_Stella
#    ClaraBerryAndWooldog_Stella already computed!
# ClaraBerryAndWooldog_TheBadGuys
# ...

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/" "melody1" -1 '' "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
#    AClassicEducation_NightOwl already computed!
#    AimeeNorwich_Child already computed!
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
#    AimeeNorwich_Flying already computed!
# AmarLal_Rest
#    AmarLal_Rest already computed!
# AmarLal_SpringDay1
#    AmarLal_SpringDay1 already computed!
# Auctioneer_OurFutureFaces
#    AlexanderRoss_GoodbyeBolero already computed!
# AlexanderRoss_VelvetCurtain
# BigTroubles_Phantom
#    Auctioneer_OurFutureFaces already computed!
# AvaLuna_Waterduct
# BrandonWebster_YesSirICanFly
#    BigTroubles_Phantom already computed!
# ChrisJacoby_BoothShotLincoln
#    BrandonWebster_YesSirICanFly already computed!
# BrandonWebster_DontHearAThing
# CelestialShore_DieForUs
#    AvaLuna_Waterduct already computed!
# ClaraBerryAndWooldog_AirTraffic
#    BrandonWebster_DontHearAThing already computed!
#    AlexanderRoss_VelvetCurtain already computed!
#    ChrisJacoby_BoothShotLincoln already computed!
# ...

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/" "melody2" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
# AlexanderRoss_VelvetCurtain
# AmarLal_Rest
# AmarLal_SpringDay1
# Auctioneer_OurFutureFaces
# AvaLuna_Waterduct
# BigTroubles_Phantom
# BrandonWebster_DontHearAThing
# BrandonWebster_YesSirICanFly
# CelestialShore_DieForUs
# ChrisJacoby_BoothShotLincoln
# ChrisJacoby_PigsFoot
# ClaraBerryAndWooldog_AirTraffic
# ClaraBerryAndWooldog_Boys
# ClaraBerryAndWooldog_Stella
# ClaraBerryAndWooldog_TheBadGuys
# ClaraBerryAndWooldog_WaltzForMyVictims
#     Saved data to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/BrandonWebster_YesSirICanFly_mel2.npz
# Creepoid_OldTree
#     Saved data to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/AmarLal_SpringDay1_mel2.npz
# CroqueMadame_Oil
#     Saved data to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/AimeeNorwich_Flying_mel2.npz
# CroqueMadame_Pilot
# ...

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/" "melody3" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
# AlexanderRoss_VelvetCurtain
# AmarLal_Rest
# AmarLal_SpringDay1
# Auctioneer_OurFutureFaces
# AvaLuna_Waterduct
# BigTroubles_Phantom
# BrandonWebster_DontHearAThing
# BrandonWebster_YesSirICanFly
# CelestialShore_DieForUs
# ChrisJacoby_PigsFoot
# ChrisJacoby_BoothShotLincoln
# ClaraBerryAndWooldog_AirTraffic
# ClaraBerryAndWooldog_Boys
# ClaraBerryAndWooldog_Stella
# ClaraBerryAndWooldog_TheBadGuys
# ClaraBerryAndWooldog_WaltzForMyVictims
#     Saved data to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/AimeeNorwich_Flying_mel3.npz
# Creepoid_OldTree
#     Saved data to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/BrandonWebster_YesSirICanFly_mel3.npz
# CroqueMadame_Oil
#     Saved data to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/ClaraBerryAndWooldog_AirTraffic_mel3.npz
# CroqueMadame_Pilot
# ...

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/" "multif0_incomplete" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
#    AClassicEducation_NightOwl already computed!
# AimeeNorwich_Child
#    AimeeNorwich_Child already computed!
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
#    AimeeNorwich_Flying already computed!
#    AlexanderRoss_GoodbyeBolero already computed!
# AlexanderRoss_VelvetCurtain
#    AlexanderRoss_VelvetCurtain already computed!
# AmarLal_Rest
#    AmarLal_Rest already computed!
# AmarLal_SpringDay1
#    AmarLal_SpringDay1 already computed!
# Auctioneer_OurFutureFaces
#    Auctioneer_OurFutureFaces already computed!
# AvaLuna_Waterduct
#    AvaLuna_Waterduct already computed!
# BigTroubles_Phantom
#    BigTroubles_Phantom already computed!
# BrandonWebster_DontHearAThing
#    BrandonWebster_DontHearAThing already computed!
# BrandonWebster_YesSirICanFly
#    BrandonWebster_YesSirICanFly already computed!
# CelestialShore_DieForUs
#    CelestialShore_DieForUs already computed!
# ChrisJacoby_BoothShotLincoln
# ...

# %%
data_dir = ("/scratch/rmb456/multif0_ismir2017/" +
    "training_data_with_blur/multif0_complete")

# %%
import medleydb as mdb
import glob
import shutil
import os

# %%
mtracks = list(mtracks)

# %%
new_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/bad_extras"

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['EXTRA'])
good_count = 0
bad_count = 0

for mtrack in mtracks:
    bad_mtrack = False
    for stem in mtrack.stems.values():
        if stem.pitch_estimate_pyin is not None:

            if 'p' in stem.f0_type:
                bad_mtrack = True
                print(stem.instrument)
    if bad_mtrack:
        bad_count += 1
        print mtrack.track_id
    else:
        good_count += 1
        
        
    if bad_mtrack:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                bname = os.path.basename(f)
                os.rename(f, os.path.join(new_dir, bname))
# Out:
# ['male singer', 'vocalists']
# AHa_TakeOnMe
# ['female speaker', 'distorted electric guitar', 'drum set', 'piano', 'synthesizer', 'shaker']
# ['male singer', 'vocalists']
# Aerosmith_LoveInAnElevator
# ['male singer', 'synthesizer', 'vocalists', 'distorted electric guitar', 'tambourine']
# Anberlin_TheFeelGoodDrag
# ['fx/processed sound', 'vocalists', 'female singer']
# ArcadeFire_BlackMirror
# ['male singer', 'tambourine', 'distorted electric guitar', 'vocalists']
# ArcticMonkeys_Brainstorm
# ['male singer', 'vocalists']
# BillyIdol_WhiteWedding
# ['male singer', 'vocalists']
# BillySquier_TheStroke
# ['male singer', 'vocalists']
# ['synthesizer', 'high hat', 'male singer', 'vocalists', 'piano', 'clean electric guitar']
# Blink182_AllTheSmallThings
# ['female singer', 'vocalists']
# Blondie_OneWayOrAnother
# ['auxiliary percussion', 'electronic organ', 'male singer', 'vocalists', 'clean electric guitar', 'synthesizer']
# BlueOysterCult_DontFearTheReaper
# ...

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['V1'])
for mtrack in mtracks:
    if mtrack.has_melody:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                print(f)
                os.remove(f)

# %%
mkdir /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/bad_extras

# %%
x = 5
print(x)
