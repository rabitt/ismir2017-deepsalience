# %%
cd ../
# Out:
# /home/rmb456/repos/multif0

# %%
import medleydb as mdb
import numpy as np
import os


mel1_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/"
mel2_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/"
mel3_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/"
mf0_incomplete = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/"
mf0_complete = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/"

mtracks = mdb.load_all_multitracks(
    dataset_version=['V1', 'V2', 'EXTRA']
)

for mtrack in mtracks:
#     print(mtrack.track_id)
    fpath = os.path.join(mel1_dir, 'inputs', '{}_mel1_input.npy'.format(mtrack.track_id))
    if not os.path.exists(fpath):
#         print("   > no npy file")
        continue

    data = np.load(fpath, mmap_mode='r')

    if data.shape[0] != 6:
        print(mtrack.track_id)
        print("   > {}".format(data.shape))
        os.remove(fpath)
        os.remove(os.path.join(mel2_dir, 'inputs', '{}_mel2_input.npy'.format(mtrack.track_id)))
        os.remove(os.path.join(mel3_dir, 'inputs', '{}_mel3_input.npy'.format(mtrack.track_id)))
        os.remove(os.path.join(mf0_incomplete, 'inputs', '{}_multif0_incomplete_input.npy'.format(mtrack.track_id)))

# %%
# %run compute_training_data.py --help
# Out:
# usage: compute_training_data.py [-h] [--blur-labels]
#                                 save_dir option n_jobs precomputed_hcqt_path
#
# Generate feature files for multif0 learning.
#
# positional arguments:
#   save_dir              Path to save npy files.
#   option                Type of data to compute. One of 'solo_pitch'
#                         'melody1', 'melody2', 'melody3' 'multif0_incomplete',
#                         'multif0_complete'.
#   n_jobs                Number of jobs to run in parallel.
#   precomputed_hcqt_path
#                         Path to folder with hcqts precomputed
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --blur-labels

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/" "melody1" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs/" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/" "multif0_complete" -1 '' "--blur-labels"
# Out:
# AClassicEducation_NightOwl
#     > already done!
# AimeeNorwich_Child
#     > already done!
# AimeeNorwich_Flying
#     > already done!
#     > already done!
# AlexanderRoss_GoodbyeBolero
#     > already done!
# AlexanderRoss_VelvetCurtain
# AmarLal_Rest
#     > already done!
# AmarLal_SpringDay1
#     > already done!
# Auctioneer_OurFutureFaces
#     > already done!
# AvaLuna_Waterduct
#     > already done!
# BigTroubles_Phantom
#     > already done!
# BrandonWebster_DontHearAThing
#     > already done!
# BrandonWebster_YesSirICanFly
#     > already done!
# CelestialShore_DieForUs
#     > already done!
# ChrisJacoby_BoothShotLincoln
#     > already done!
# ChrisJacoby_PigsFoot
#     > already done!
# ClaraBerryAndWooldog_AirTraffic
#     > already done!
# ClaraBerryAndWooldog_Boys
#     > already done!
# ClaraBerryAndWooldog_Stella
# ClaraBerryAndWooldog_TheBadGuys
#     > already done!
#     > already done!
# ClaraBerryAndWooldog_WaltzForMyVictims
#     > already done!
#     > already done!
# Creepoid_OldTree
#     > already done!
# CroqueMadame_Oil
# CroqueMadame_Pilot
#     > already done!
# Debussy_LenfantProdigue
#     > already done!
#     > already done!
# DreamersOfTheGhetto_HeavyLove
#     > already done!
# EthanHein_1930sSynthAndUprightBass
#     > already done!
# EthanHein_BluesForNofi
#     > already done!
# EthanHein_GirlOnABridge
#     > already done!
# EthanHein_HarmonicaFigure
#     EthanHein_HarmonicaFigure No multif0 data
# FacesOnFilm_WaitingForGa
#     > already done!
# FamilyBand_Again
#     > already done!
# Grants_PunchDrunk
# Handel_TornamiAVagheggiar
# HezekiahJones_BorrowedHeart
#     > already done!
# HeladoNegro_MitadDelMundo
#     > already done!
#     > already done!
# KarimDouaidy_Hopscotch
# HopAlong_SisterCities
#     > already done!
# InvisibleFamiliars_DisturbingWildlife
#     > already done!
# JoelHelander_Definition
#     > already done!
# JoelHelander_ExcessiveResistancetoChange
#     > already done!
# JoelHelander_IntheAtticBedroom
#     > already done!
#     > already done!
# KarimDouaidy_Yatora
#     > already done!
# LizNelson_Coldwar
# Lushlife_ToynbeeSuite
#     > already done!
# LizNelson_ImComingHome
#     > already done!
# LizNelson_Rainfall
#     > already done!
#     > already done!
# MatthewEntwistle_AnEveningWithOliver
#     > already done!
# MatthewEntwistle_DontYouEver
#     > already done!
# MatthewEntwistle_FairerHopes
#     > already done!
# MatthewEntwistle_ImpressionsOfSaturn
#     > already done!
#     > already done!
# MatthewEntwistle_Lontano
#     > already done!
# MatthewEntwistle_TheArch
# MatthewEntwistle_TheFlaxenField
# Meaxic_TakeAStep
#     > already done!
#     > already done!
# Meaxic_YouListen
# Mozart_BesterJungling
#     > already done!
# MichaelKropf_AllGoodThings
#     > already done!
#     > already done!
# Mozart_DiesBildnis
#     > already done!
# MusicDelta_80sRock
#     > already done!
#     > already done!
# MusicDelta_Beatles
# MusicDelta_BebopJazz
#     > already done!
# MusicDelta_Beethoven
#     > already done!
# MusicDelta_Britpop
#     > already done!
# MusicDelta_ChineseChaoZhou
#     > already done!
# MusicDelta_ChineseDrama
#     > already done!
# MusicDelta_ChineseHenan
#     > already done!
#     > already done!
# MusicDelta_ChineseJiangNan
#     > already done!
# MusicDelta_ChineseXinJing
# MusicDelta_ChineseYaoZu
#     > already done!
# MusicDelta_CoolJazz
#     > already done!
# MusicDelta_Country1
#     > already done!
# MusicDelta_Country2
#     > already done!
# MusicDelta_Disco
# MusicDelta_GriegTrolltog
#     > already done!
# MusicDelta_FreeJazz
#     > already done!
# MusicDelta_FunkJazz
#     > already done!
# MusicDelta_FusionJazz
#     > already done!
# MusicDelta_Gospel
#     > already done!
#     > already done!
# MusicDelta_Grunge
#     > already done!
# MusicDelta_Hendrix
#     > already done!
# MusicDelta_InTheHalloftheMountainKing
#     > already done!
# MusicDelta_LatinJazz
#     > already done!
# MusicDelta_ModalJazz
# MusicDelta_SwingJazz
#     > already done!
# MusicDelta_Pachelbel
#     > already done!
# MusicDelta_Punk
#     > already done!
# MusicDelta_Reggae
#     > already done!
# MusicDelta_Rock
#     > already done!
# MusicDelta_Rockabilly
#     > already done!
# MusicDelta_Shadows
#     > already done!
# MusicDelta_SpeedMetal
#     > already done!
#     > already done!
# MusicDelta_Vivaldi
#     > already done!
# MusicDelta_Zeppelin
#     > already done!
#     > already done!
# NightPanther_Fire
#     > already done!
# Phoenix_BrokenPledgeChicagoReel
#     > already done!
# Phoenix_ColliersDaughter
# Phoenix_ElzicsFarewell
#     > already done!
#     > already done!
# Phoenix_LarkOnTheStrandDrummondCastle
#     > already done!
# Phoenix_ScotchMorris
#     > already done!
# Phoenix_SeanCaughlinsTheScartaglen
#     > already done!
# PortStWillow_StayEven
#     > already done!
# PurlingHiss_Lolita
# Schubert_Erstarrung
#     > already done!
#     > already done!
# Schumann_Mignon
#     > already done!
# SecretMountains_HighHorse
#     > already done!
# Snowmine_Curfews
# StevenClark_Bounty
#     > already done!
# StrandOfOaks_Spacestation
#     > already done!
# SweetLights_YouLetMeDown
#     > already done!
# TablaBreakbeatScience_Animoog
#     > already done!
# TablaBreakbeatScience_CaptainSky
#     > already done!
# TablaBreakbeatScience_MiloVsMongo
#     TablaBreakbeatScience_MiloVsMongo No multif0 data
# TablaBreakbeatScience_MoodyPlucks
#     TablaBreakbeatScience_MoodyPlucks No multif0 data
# TablaBreakbeatScience_PhaseTransition
#     > already done!
# TablaBreakbeatScience_RockSteady
#     TablaBreakbeatScience_RockSteady No multif0 data
# TablaBreakbeatScience_Scorpio
#     TablaBreakbeatScience_Scorpio No multif0 data
# TablaBreakbeatScience_Vger
#     > already done!
#     TablaBreakbeatScience_Vger No multif0 data
# TablaBreakbeatScience_WhoIsIt
#     > already done!
# TheDistricts_Vermont
#     > already done!
# TheScarletBrand_LesFleursDuMal
#     > already done!
# TheSoSoGlos_Emergency
#     > already done!
# Wolf_DieBekherte
# Allegria_MendelssohnMovement1
#     Allegria_MendelssohnMovement1 No multif0 data
# AmadeusRedux_MozartAllegro
#     AmadeusRedux_MozartAllegro No multif0 data
# AmadeusRedux_SchubertMovement2
#     AmadeusRedux_SchubertMovement2 No multif0 data
# AmadeusRedux_SchubertMovement3
#     AmadeusRedux_SchubertMovement3 No multif0 data
# BarefootSisters_RedJetta
# FallingSparks_Improvisation2
#     BarefootSisters_RedJetta No multif0 data
# CassandraJenkins_PerfectDay
#     > already done!
# CatMartino_IPromise
#     > already done!
# Cayetana_MissThing
#     > already done!
# DahkaBand_SoldierMan
#     DahkaBand_SoldierMan No multif0 data
# DeadMilkmen_PrisonersCinema
#     > already done!
# DeclareAString_MendelssohnPianoTrio1Movement1
#     DeclareAString_MendelssohnPianoTrio1Movement1 No multif0 data
# DeclareAString_MendelssohnPianoTrio1Movement2
#     DeclareAString_MendelssohnPianoTrio1Movement2 No multif0 data
# FallingSparks_Improvisation1
#     FallingSparks_Improvisation1 No multif0 data
#     FallingSparks_Improvisation2 No multif0 data
# FallingSparks_Improvisation3
# FennelCartwright_FlowerDrumSong
#     FallingSparks_Improvisation3 No multif0 data
# FallingSparks_PakKlongTalad
#     FallingSparks_PakKlongTalad No multif0 data
# FennelCartwright_DearTessie
#     FennelCartwright_DearTessie No multif0 data
#     FennelCartwright_FlowerDrumSong No multif0 data
# FennelCartwright_WinterLake
#     FennelCartwright_WinterLake No multif0 data
# FilthyBird_IdLikeToKnow
#     > already done!
# FruitCathedral_KeepMeRunnin
#     > already done!
# HopsNVinyl_ChickenFriedSteak
#     HopsNVinyl_ChickenFriedSteak No multif0 data
# HopsNVinyl_HoneyBrown
#     HopsNVinyl_HoneyBrown No multif0 data
# HopsNVinyl_ReignCheck
#     HopsNVinyl_ReignCheck No multif0 data
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    4.2s
# HopsNVinyl_WidowsWalk
#     Katzn_CharlieKnox No multif0 data
#     HopsNVinyl_WidowsWalk No multif0 data
# Karachacha_Volamos
#     Karachacha_Volamos No multif0 data
# Katzn_CharlieKnox
# LewisAndClarke_TheSilverSea
#     LewisAndClarke_TheSilverSea No multif0 data
# LittleTybee_TheAlchemist
#     > already done!
# MatthewEntwistle_ReturnToVenezia
#     MatthewEntwistle_ReturnToVenezia No multif0 data
#     > already done!
# MidnightBlue_HuntingSeason
#     > already done!
# MidnightBlue_StarsAreScreaming
#     > already done!
# MutualBenefit_NotForNothing
#     > already done!
# PatternIsMovement_SaveMe
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#     > already done!
# Plasma_GoodShout
#     > already done!
# PoliceHearingDepartment_Brahms
#     PoliceHearingDepartment_Brahms No multif0 data
# PoliceHearingDepartment_SchumannMovement1
#     PoliceHearingDepartment_SchumannMovement1 No multif0 data
# PoliceHearingDepartment_SchumannMovement2
#     PoliceHearingDepartment_SchumannMovement2 No multif0 data
# PoliceHearingDepartment_VivaldiMovement1
#     PoliceHearingDepartment_VivaldiMovement1 No multif0 data
# PoliceHearingDepartment_VivaldiMovement2
#     PoliceHearingDepartment_VivaldiMovement2 No multif0 data
# PoliceHearingDepartment_VivaldiMovement3
#     PoliceHearingDepartment_VivaldiMovement3 No multif0 data
# QuantumChromos_Circuits
#     QuantumChromos_Circuits No multif0 data
# RodrigoBonelli_BalladForLaura
#     RodrigoBonelli_BalladForLaura No multif0 data
# SasquatchConnection_BoomBoxing
#     SasquatchConnection_ThanksALatte No multif0 data
#     SasquatchConnection_BoomBoxing No multif0 data
# SasquatchConnection_HolyClamsBatman
#     SasquatchConnection_HolyClamsBatman No multif0 data
# SasquatchConnection_Illuminati
#     SasquatchConnection_Illuminati No multif0 data
# SasquatchConnection_Struttin
#     SasquatchConnection_Struttin No multif0 data
# SasquatchConnection_ThanksALatte
# SlowGhost_FirstSnow
#     > already done!
# SlowGhost_MidnightGroove
#     > already done!
# SlowGhost_Peanut
#     > already done!
# SlowGhost_YoureAMystery
#     > already done!
# SongYiJeon_TwoMoons
#     SongYiJeon_TwoMoons No multif0 data
# Sweat_AlmostAlways
# Sweat_Sn1572
#     Sweat_AlmostAlways No multif0 data
# Sweat_Anecdoche
#     Sweat_Anecdoche No multif0 data
# Sweat_Elegy
#     Sweat_Elegy No multif0 data
# Sweat_Mesozoic
#     Sweat_Mesozoic No multif0 data
#     Sweat_Sn1572 No multif0 data
# Sweat_Tact
#     Sweat_Tact No multif0 data
# TemperedElan_DorothyJeanne
#     TemperedElan_DorothyJeanne No multif0 data
#     TheFranckDuo_FranckViolinSonataInAMajorMovement2 No multif0 data
# TemperedElan_WiseOne
#     TemperedElan_WiseOne No multif0 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#     > already done!
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
# TheKitchenettes_Alive
#     TheNoHoStringOrchestra_ElgarMovement2 No multif0 data
#     > already done!
# TheNoHoStringOrchestra_ElgarMovement1
#     TheNoHoStringOrchestra_ElgarMovement1 No multif0 data
# TheNoHoStringOrchestra_ElgarMovement2
# TheNoHoStringOrchestra_ElgarMovement3
#     TheNoHoStringOrchestra_ElgarMovement3 No multif0 data
# TheTonTons_Lush
#     > already done!
# TleilaxEnsemble_Late
#     TleilaxEnsemble_Late No multif0 data
# TleilaxEnsemble_MelancholyFlowers
#     TleilaxEnsemble_MelancholyFlowers No multif0 data
# Torres_NewSkin
#     > already done!
# TrevorAndTheSoundwaves_AloneAndSad
#     > already done!
# Verdi_IlTrovatore
#     Verdi_IlTrovatore No multif0 data
# AHa_TakeOnMe
# multitrack has stems with polyphonic instruments
# AcDc_BackInBlack
# Aerosmith_LoveInAnElevator
#     > already done!
# Adele_SomeoneLikeYou
#     > already done!
# multitrack has stems with polyphonic instruments
# AlanisMorissette_YouOughtaKnow
# BillyIdol_WhiteWedding
#     > already done!
# AllThatRemains_Chiron
#     > already done!
# AnEndlessSporadic_Anything
#     > already done!
# Anberlin_TheFeelGoodDrag
# multitrack has stems with polyphonic instruments
# ArcadeFire_BlackMirror
# multitrack has stems with polyphonic instruments
# BillySquier_TheStroke
# multitrack has stems with polyphonic instruments
# BlackEyedPeas_IGottaFeeling
#     > already done!
# BlackSabbath_WarPigs
#     > already done!
# Blink182_AllTheSmallThings
# multitrack has stems with polyphonic instruments
# ArcticMonkeys_Brainstorm
# BrooksDunn_HillbillyDeluxe
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# Blondie_OneWayOrAnother
# multitrack has stems with polyphonic instruments
# BrunoMars_Grenade
# multitrack has stems with polyphonic instruments
# BlueOysterCult_DontFearTheReaper
# CherryPoppinDaddies_ZootSuitRiot
# multitrack has stems with polyphonic instruments
# BrunoMars_JustTheWayYouAre
# multitrack has stems with polyphonic instruments
# BrunoMars_MarryYou
# multitrack has stems with polyphonic instruments
# ChrisBrown_Yeah
# multitrack has stems with polyphonic instruments
# ChristinaAguilera_GenieInABottle
# multitrack has stems with polyphonic instruments
# BobSeger_OldTimeRockAndRoll
# multitrack has stems with polyphonic instruments
# CountingCrows_AccidentallyInLove
# BryanAdams_SummerOf69
#     > already done!
#     > already done!
# Bush_Machinehead
# CrazyFrog_JingleBells
#     > already done!
# CarlDouglas_KungFuFighting
# Boston_MoreThanAFeeling
# multitrack has stems with polyphonic instruments
#     CrazyFrog_JingleBells No multif0 data
# FleetwoodMac_Rhiannon
# multitrack has stems with polyphonic instruments
# Chromeo_Tenderoni
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# CarrieUnderwood_HomeSweetHome
# multitrack has stems with polyphonic instruments
#     > already done!
# FlightOfTheConcords_BusinessTime
# CeeloGreen_ForgetYou
#     > already done!
#     > already done!
# CheapTrick_IWantYouToWantMe
# FooFighters_AllMyLife
# Incubus_Drive
#     > already done!
#     > already done!
# Chumbawamba_Tubthumping
#     Chumbawamba_Tubthumping No multif0 data
# ColdWarKids_HangMeUpToDry
#     > already done!
# Coldplay_InMyPlace
#     > already done!
#     > already done!
# Coldplay_Shiver
# CorinneBaileyRae_PutYourRecordsOn
# multitrack has stems with polyphonic instruments
# KeithUrban_IToldYouSo
#     > already done!
# KennyChesney_SheThinksMyTractorsSexy
# BradPaisley_MudOnTheTires
#     > already done!
#     > already done!
# KingsOfLeon_SexOnFire
#     KingsOfLeon_SexOnFire No multif0 data
# Kiss_RockAndRollAllNite
# multitrack has stems with polyphonic instruments
# Inxs_NeedYouTonight
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# CountZero_Shake
# Knack_MySharona
#     > already done!
#     > already done!
# Korn_FreakOnALeash
#     > already done!
# KtTunstall_BlackHorseAndTheCherryTree
# multitrack has stems with polyphonic instruments
# KaiserChiefs_Ruby
# multitrack has stems with polyphonic instruments
# KtTunstall_SuddenlyISee
#     > already done!
# LaRoux_Bulletproof
# LadyGagaFeaturingBeyonce_Telephone
#     > already done!
#     > already done!
# multitrack has stems with polyphonic instruments
#     > already done!
# Kansas_CarryOnMyWaywardSon
#     > already done!
# KanyeWest_LoveLockdown
# LadyGaga_BadRomance
# multitrack has stems with polyphonic instruments
# LadyGaga_BornThisWay
# multitrack has stems with polyphonic instruments
# LinkinPark_InTheEnd
# LambOfGod_Requiem
#     > already done!
# LennyKravitz_AreYouGonnaGoMyWay
#     > already done!
# LilyAllen_NotFair
#     > already done!
# multitrack has stems with polyphonic instruments
# Lit_MyOwnWorstEnemy
# LynyrdSkynyrd_FreeBird
# Maroon5_ThisLove
#     > already done!
# Live_IAlone
#     > already done!
# multitrack has stems with polyphonic instruments
# MartinaMcbride_ThisOnesForTheGirls
#     LoquilloYLosTrogloditas_CadillacSolitario No multif0 data
# multitrack has stems with polyphonic instruments
# LoquilloYLosTrogloditas_CadillacSolitario
# LosLobos_LaBamba
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# MarvinGaye_IHeardItThroughTheGrapevine
# MirandaCosgrove_HeadphonesOn
#     > already done!
# ModestMouse_FloatOn
# Misfits_AstroZombies
#     > already done!
# multitrack has stems with polyphonic instruments
# MichaelJackson_BeatIt
# MarvinGaye_WhatsGoingOn
#     > already done!
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
#     > already done!
# multitrack has stems with polyphonic instruments
# Muse_Hysteria
# Muffs_KidsInAmerica
#     > already done!
#     > already done!
# TPain_Bartender
# multitrack has stems with polyphonic instruments
# MightyMightyBosstones_WheredYouGo
#     > already done!
# MikeOldfield_Quicksilver
#     MikeOldfield_Quicksilver No multif0 data
# MileyCyrus_7Things
# Tesla_ModernDayCowboy
# multitrack has stems with polyphonic instruments
# TheAllAmericanRejects_DirtyLittleSecret
# multitrack has stems with polyphonic instruments
# TalkingHeads_PsychoKiller
#     > already done!
# multitrack has stems with polyphonic instruments
# TaylorSwift_LoveStory
# multitrack has stems with polyphonic instruments
# TheAllmanBrothersBand_RamblinMan
#     > already done!
# TheBeatles_TwistAndShout
#     TheBeatles_TwistAndShout No multif0 data
# TheBeatles_Wait
#     TheBeatles_WithALittleHelpFromMyFriends No multif0 data
#     TheBeatles_Wait No multif0 data
# TheBeatles_WhatGoesOn
#     TheBeatles_WhatGoesOn No multif0 data
# TheBeatles_WhenIm64
#     TheBeatles_WhenIm64 No multif0 data
# TheBeatles_WhileMyGuitarGentlyWeeps
#     TheBeatles_WhileMyGuitarGentlyWeeps No multif0 data
# TheBeatles_WithALittleHelpFromMyFriends
# TheBeatles_WithinYouWithoutYou
#     TheBeatles_WithinYouWithoutYou No multif0 data
# TheBeatles_YellowSubmarine
# multitrack has stems with polyphonic instruments
# TaylorSwift_YouBelongWithMe
#     TheBeatles_YellowSubmarine No multif0 data
# TheBeatles_YouWontSeeMe
#     TheBeatles_YouWontSeeMe No multif0 data
# TheBlackKeys_YourTouch
#     TheBlackKeys_YourTouch No multif0 data
# TheBravery_Believe
#     TheBravery_Believe No multif0 data
# TheBronx_FalseAlarm
#     > already done!
# TheBronx_SixDaysAWeek
#     > already done!
# TheKillers_SomebodyToldMe
# multitrack has stems with polyphonic instruments
# TheKooks_Naive
# multitrack has stems with polyphonic instruments
# TearsForFears_EverybodyWantsToRuleTheWorld
# multitrack has stems with polyphonic instruments
# TheLastGoodnight_PicturesOfYou
#     > already done!
# TheTurtles_HappyTogether
# multitrack has stems with polyphonic instruments
# ThinLizzy_TheBoysAreBackInTown
#     > already done!
# ThirdEyeBlind_Jumper
#     > already done!
# ThirdEyeBlind_NeverLetYouGo
# VanillaIce_IceIceBaby
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# TomPettyAndTheHeartbreakers_IWontBackDown
# multitrack has stems with polyphonic instruments
# VillagePeople_Ymca
# multitrack has stems with polyphonic instruments
# Weezer_IslandInTheSun
#     Weezer_IslandInTheSun No multif0 data
# WildCherry_PlayThatFunkyMusic
#     WildCherry_PlayThatFunkyMusic No multif0 data
# multitrack has stems with polyphonic instruments
# TomPetty_FreeFallin
# multitrack has stems with polyphonic instruments
# Tonic_IfYouCouldOnlySee
# multitrack has stems with polyphonic instruments
# TvOnTheRadio_WolfLikeMe
#     TvOnTheRadio_WolfLikeMe No multif0 data
# VampireWeekend_Cousins
#     > already done!
# VampireWeekend_Holiday
#     > already done!
# VanHalen_Jump
#     VanHalen_Jump No multif0 data
# Done!
# [Parallel(n_jobs=-1)]: Done 320 out of 320 | elapsed:    8.7s finished

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/" "melody2" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs/" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
# AimeeNorwich_Flying
#     > using precomputed CQT for AClassicEducation_NightOwl_MIX.wav
# AlexanderRoss_GoodbyeBolero
#     > using precomputed CQT for AimeeNorwich_Child_MIX.wav
# AlexanderRoss_VelvetCurtain
# AmarLal_Rest
#     > using precomputed CQT for AimeeNorwich_Flying_MIX.wav
# AmarLal_SpringDay1
#     > using precomputed CQT for AmarLal_Rest_MIX.wav
#     > using precomputed CQT for AmarLal_SpringDay1_MIX.wav
# Auctioneer_OurFutureFaces
# AvaLuna_Waterduct
#     > using precomputed CQT for AlexanderRoss_GoodbyeBolero_MIX.wav
# BrandonWebster_DontHearAThing
# BigTroubles_Phantom
# BrandonWebster_YesSirICanFly
#     > using precomputed CQT for Auctioneer_OurFutureFaces_MIX.wav
# CelestialShore_DieForUs
# ChrisJacoby_BoothShotLincoln
#     > using precomputed CQT for AlexanderRoss_VelvetCurtain_MIX.wav
#     > using precomputed CQT for BrandonWebster_YesSirICanFly_MIX.wav
# ChrisJacoby_PigsFoot
#     > using precomputed CQT for AvaLuna_Waterduct_MIX.wav
#     > using precomputed CQT for BigTroubles_Phantom_MIX.wav
#     > using precomputed CQT for BrandonWebster_DontHearAThing_MIX.wav
# ClaraBerryAndWooldog_AirTraffic
#     > using precomputed CQT for ChrisJacoby_BoothShotLincoln_MIX.wav
# ClaraBerryAndWooldog_Boys
# ClaraBerryAndWooldog_Stella
# ClaraBerryAndWooldog_TheBadGuys
#     > using precomputed CQT for ClaraBerryAndWooldog_AirTraffic_MIX.wav
#     > using precomputed CQT for CelestialShore_DieForUs_MIX.wav
# ClaraBerryAndWooldog_WaltzForMyVictims
#     > using precomputed CQT for ClaraBerryAndWooldog_Boys_MIX.wav
# Creepoid_OldTree
#     > using precomputed CQT for ChrisJacoby_PigsFoot_MIX.wav
#     > using precomputed CQT for ClaraBerryAndWooldog_Stella_MIX.wav
#     > using precomputed CQT for ClaraBerryAndWooldog_WaltzForMyVictims_MIX.wav
# CroqueMadame_Oil
# CroqueMadame_Pilot
#     > using precomputed CQT for ClaraBerryAndWooldog_TheBadGuys_MIX.wav
# Debussy_LenfantProdigue
# DreamersOfTheGhetto_HeavyLove
# EthanHein_1930sSynthAndUprightBass
# EthanHein_BluesForNofi
#     EthanHein_BluesForNofi No melody 2 data
#     > using precomputed CQT for Creepoid_OldTree_MIX.wav
# EthanHein_GirlOnABridge
#     > using precomputed CQT for Debussy_LenfantProdigue_MIX.wav
#     > using precomputed CQT for EthanHein_GirlOnABridge_MIX.wav
#     > using precomputed CQT for DreamersOfTheGhetto_HeavyLove_MIX.wav
#     > using precomputed CQT for EthanHein_1930sSynthAndUprightBass_MIX.wav
#     > using precomputed CQT for CroqueMadame_Pilot_MIX.wav
#     > using precomputed CQT for CroqueMadame_Oil_MIX.wav
# EthanHein_HarmonicaFigure
#     EthanHein_HarmonicaFigure No melody 2 data
# FacesOnFilm_WaitingForGa
#     > using precomputed CQT for FacesOnFilm_WaitingForGa_MIX.wav
#     Saved data for BrandonWebster_YesSirICanFly_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# InvisibleFamiliars_DisturbingWildlife
#     > using precomputed CQT for InvisibleFamiliars_DisturbingWildlife_MIX.wav
#     Saved data for BigTroubles_Phantom_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# LizNelson_Rainfall
#     > using precomputed CQT for LizNelson_Rainfall_MIX.wav
#     Saved data for AmarLal_SpringDay1_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MatthewEntwistle_TheFlaxenField
#     > using precomputed CQT for MatthewEntwistle_TheFlaxenField_MIX.wav
#     Saved data for EthanHein_GirlOnABridge_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_BebopJazz
#     > using precomputed CQT for MusicDelta_BebopJazz_MIX.wav
#     Saved data for ClaraBerryAndWooldog_Boys_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_ChineseDrama
#     > using precomputed CQT for MusicDelta_ChineseDrama_MIX.wav
#     Saved data for AClassicEducation_NightOwl_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Disco
#     > using precomputed CQT for MusicDelta_Disco_MIX.wav
#     Saved data for BrandonWebster_DontHearAThing_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_InTheHalloftheMountainKing
#     > using precomputed CQT for MusicDelta_InTheHalloftheMountainKing_MIX.wav
#     Saved data for MusicDelta_InTheHalloftheMountainKing_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_LatinJazz
#     > using precomputed CQT for MusicDelta_LatinJazz_MIX.wav
#     Saved data for AimeeNorwich_Child_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Shadows
#     > using precomputed CQT for MusicDelta_Shadows_MIX.wav
#     Saved data for ClaraBerryAndWooldog_AirTraffic_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Phoenix_ElzicsFarewell
#     > using precomputed CQT for Phoenix_ElzicsFarewell_MIX.wav
#     Saved data for AmarLal_Rest_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# SecretMountains_HighHorse
#     > using precomputed CQT for SecretMountains_HighHorse_MIX.wav
#     Saved data for ClaraBerryAndWooldog_WaltzForMyVictims_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# TablaBreakbeatScience_MoodyPlucks
# TheDistricts_Vermont
#     TablaBreakbeatScience_MoodyPlucks No melody 2 data
# TablaBreakbeatScience_PhaseTransition
#     TablaBreakbeatScience_PhaseTransition No melody 2 data
# TablaBreakbeatScience_RockSteady
#     TablaBreakbeatScience_RockSteady No melody 2 data
# TablaBreakbeatScience_Scorpio
#     TablaBreakbeatScience_Scorpio No melody 2 data
# TablaBreakbeatScience_Vger
#     TablaBreakbeatScience_Vger No melody 2 data
# TablaBreakbeatScience_WhoIsIt
#     TablaBreakbeatScience_WhoIsIt No melody 2 data
#     > using precomputed CQT for TheDistricts_Vermont_MIX.wav
#     Saved data for MusicDelta_Shadows_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_SpeedMetal
#     > using precomputed CQT for MusicDelta_SpeedMetal_MIX.wav
#     Saved data for MusicDelta_ChineseDrama_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_ChineseHenan
#     > using precomputed CQT for MusicDelta_ChineseHenan_MIX.wav
#     Saved data for ClaraBerryAndWooldog_Stella_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# TheSoSoGlos_Emergency
#     > using precomputed CQT for TheSoSoGlos_Emergency_MIX.wav
#     Saved data for Auctioneer_OurFutureFaces_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# CatMartino_IPromise
# DahkaBand_SoldierMan
#     CatMartino_IPromise No melody 2 data
# Cayetana_MissThing
#     Cayetana_MissThing No melody 2 data
#     DahkaBand_SoldierMan No melody 2 data
# DeadMilkmen_PrisonersCinema
#     DeadMilkmen_PrisonersCinema No melody 2 data
# DeclareAString_MendelssohnPianoTrio1Movement1
#     DeclareAString_MendelssohnPianoTrio1Movement1 No melody 2 data
# DeclareAString_MendelssohnPianoTrio1Movement2
#     DeclareAString_MendelssohnPianoTrio1Movement2 No melody 2 data
# FallingSparks_Improvisation1
#     FallingSparks_Improvisation1 No melody 2 data
# FallingSparks_Improvisation2
#     FallingSparks_Improvisation2 No melody 2 data
# FallingSparks_Improvisation3
#     FallingSparks_Improvisation3 No melody 2 data
# FallingSparks_PakKlongTalad
#     FallingSparks_PakKlongTalad No melody 2 data
# FennelCartwright_DearTessie
#     FennelCartwright_DearTessie No melody 2 data
# FennelCartwright_FlowerDrumSong
#     FennelCartwright_FlowerDrumSong No melody 2 data
# FennelCartwright_WinterLake
#     FennelCartwright_WinterLake No melody 2 data
# FilthyBird_IdLikeToKnow
#     FilthyBird_IdLikeToKnow No melody 2 data
# FruitCathedral_KeepMeRunnin
#     FruitCathedral_KeepMeRunnin No melody 2 data
# HopsNVinyl_ChickenFriedSteak
#     HopsNVinyl_ChickenFriedSteak No melody 2 data
# HopsNVinyl_HoneyBrown
#     HopsNVinyl_HoneyBrown No melody 2 data
# HopsNVinyl_ReignCheck
#     HopsNVinyl_ReignCheck No melody 2 data
# HopsNVinyl_WidowsWalk
#     HopsNVinyl_WidowsWalk No melody 2 data
# Karachacha_Volamos
#     Karachacha_Volamos No melody 2 data
# Katzn_CharlieKnox
#     Katzn_CharlieKnox No melody 2 data
# LewisAndClarke_TheSilverSea
#     LewisAndClarke_TheSilverSea No melody 2 data
# LittleTybee_TheAlchemist
#     LittleTybee_TheAlchemist No melody 2 data
# MatthewEntwistle_ReturnToVenezia
#     MatthewEntwistle_ReturnToVenezia No melody 2 data
# MidnightBlue_HuntingSeason
#     MidnightBlue_HuntingSeason No melody 2 data
# MidnightBlue_StarsAreScreaming
#     MidnightBlue_StarsAreScreaming No melody 2 data
# MutualBenefit_NotForNothing
#     MutualBenefit_NotForNothing No melody 2 data
# PatternIsMovement_SaveMe
#     PatternIsMovement_SaveMe No melody 2 data
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#     PeterMatthewBauer_YouAlwaysLookForSomeoneLost No melody 2 data
# Plasma_GoodShout
#     Plasma_GoodShout No melody 2 data
# PoliceHearingDepartment_Brahms
#     PoliceHearingDepartment_Brahms No melody 2 data
# PoliceHearingDepartment_SchumannMovement1
#     PoliceHearingDepartment_SchumannMovement1 No melody 2 data
# PoliceHearingDepartment_SchumannMovement2
#     PoliceHearingDepartment_SchumannMovement2 No melody 2 data
# PoliceHearingDepartment_VivaldiMovement1
#     PoliceHearingDepartment_VivaldiMovement1 No melody 2 data
# PoliceHearingDepartment_VivaldiMovement2
#     PoliceHearingDepartment_VivaldiMovement2 No melody 2 data
# PoliceHearingDepartment_VivaldiMovement3
#     PoliceHearingDepartment_VivaldiMovement3 No melody 2 data
# QuantumChromos_Circuits
#     QuantumChromos_Circuits No melody 2 data
# RodrigoBonelli_BalladForLaura
#     RodrigoBonelli_BalladForLaura No melody 2 data
# SasquatchConnection_BoomBoxing
#     SasquatchConnection_BoomBoxing No melody 2 data
# SasquatchConnection_HolyClamsBatman
#     SasquatchConnection_HolyClamsBatman No melody 2 data
# SasquatchConnection_Illuminati
#     SasquatchConnection_Illuminati No melody 2 data
# SasquatchConnection_Struttin
#     SasquatchConnection_Struttin No melody 2 data
# SasquatchConnection_ThanksALatte
#     SasquatchConnection_ThanksALatte No melody 2 data
# SlowGhost_FirstSnow
#     SlowGhost_FirstSnow No melody 2 data
# SlowGhost_MidnightGroove
#     SongYiJeon_TwoMoons No melody 2 data
#     SlowGhost_MidnightGroove No melody 2 data
# SlowGhost_Peanut
#     SlowGhost_Peanut No melody 2 data
# SlowGhost_YoureAMystery
#     SlowGhost_YoureAMystery No melody 2 data
# SongYiJeon_TwoMoons
# Sweat_AlmostAlways
#     Sweat_Anecdoche No melody 2 data
#     Sweat_AlmostAlways No melody 2 data
# Sweat_Anecdoche
# Sweat_Elegy
#     Sweat_Elegy No melody 2 data
# Sweat_Mesozoic
#     Sweat_Mesozoic No melody 2 data
# Sweat_Sn1572
#     Sweat_Sn1572 No melody 2 data
# Sweat_Tact
#     Sweat_Tact No melody 2 data
# TemperedElan_DorothyJeanne
#     TemperedElan_DorothyJeanne No melody 2 data
# TemperedElan_WiseOne
#     TemperedElan_WiseOne No melody 2 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#     TheNoHoStringOrchestra_ElgarMovement1 No melody 2 data
#     TheFranckDuo_FranckViolinSonataInAMajorMovement1 No melody 2 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
#     TheFranckDuo_FranckViolinSonataInAMajorMovement2 No melody 2 data
# TheKitchenettes_Alive
#     TheKitchenettes_Alive No melody 2 data
# TheNoHoStringOrchestra_ElgarMovement1
# TheNoHoStringOrchestra_ElgarMovement2
#     TheTonTons_Lush No melody 2 data
#     TheNoHoStringOrchestra_ElgarMovement2 No melody 2 data
# TheNoHoStringOrchestra_ElgarMovement3
#     TheNoHoStringOrchestra_ElgarMovement3 No melody 2 data
# TheTonTons_Lush
# TleilaxEnsemble_Late
#     TleilaxEnsemble_Late No melody 2 data
# TleilaxEnsemble_MelancholyFlowers
#     Torres_NewSkin No melody 2 data
#     TleilaxEnsemble_MelancholyFlowers No melody 2 data
# Torres_NewSkin
# TrevorAndTheSoundwaves_AloneAndSad
#     TrevorAndTheSoundwaves_AloneAndSad No melody 2 data
# Verdi_IlTrovatore
#     Verdi_IlTrovatore No melody 2 data
# AHa_TakeOnMe
# Adele_SomeoneLikeYou
#     AHa_TakeOnMe No melody 2 data
# AcDc_BackInBlack
#     AcDc_BackInBlack No melody 2 data
#     Adele_SomeoneLikeYou No melody 2 data
# Aerosmith_LoveInAnElevator
#     Aerosmith_LoveInAnElevator No melody 2 data
# AlanisMorissette_YouOughtaKnow
# Anberlin_TheFeelGoodDrag
#     AlanisMorissette_YouOughtaKnow No melody 2 data
# AllThatRemains_Chiron
#     AllThatRemains_Chiron No melody 2 data
# AnEndlessSporadic_Anything
#     AnEndlessSporadic_Anything No melody 2 data
#     Anberlin_TheFeelGoodDrag No melody 2 data
# ArcadeFire_BlackMirror
# ArcticMonkeys_Brainstorm
#     ArcadeFire_BlackMirror No melody 2 data
#     ArcticMonkeys_Brainstorm No melody 2 data
# BillyIdol_WhiteWedding
#     BillyIdol_WhiteWedding No melody 2 data
# BillySquier_TheStroke
#     BillySquier_TheStroke No melody 2 data
# BlackEyedPeas_IGottaFeeling
#     Blink182_AllTheSmallThings No melody 2 data
#     BlackEyedPeas_IGottaFeeling No melody 2 data
# BlackSabbath_WarPigs
#     BlackSabbath_WarPigs No melody 2 data
# Blink182_AllTheSmallThings
# Blondie_OneWayOrAnother
#     Blondie_OneWayOrAnother No melody 2 data
# BlueOysterCult_DontFearTheReaper
#     BradPaisley_MudOnTheTires No melody 2 data
#     BlueOysterCult_DontFearTheReaper No melody 2 data
# BobSeger_OldTimeRockAndRoll
#     BobSeger_OldTimeRockAndRoll No melody 2 data
# Boston_MoreThanAFeeling
#     Boston_MoreThanAFeeling No melody 2 data
# BradPaisley_MudOnTheTires
# BrooksDunn_HillbillyDeluxe
#     BrunoMars_MarryYou No melody 2 data
#     BrooksDunn_HillbillyDeluxe No melody 2 data
# BrunoMars_Grenade
#     BrunoMars_Grenade No melody 2 data
# BrunoMars_JustTheWayYouAre
#     BrunoMars_JustTheWayYouAre No melody 2 data
# BrunoMars_MarryYou
# BryanAdams_SummerOf69
#     CarrieUnderwood_HomeSweetHome No melody 2 data
#     BryanAdams_SummerOf69 No melody 2 data
# Bush_Machinehead
#     Bush_Machinehead No melody 2 data
# CarlDouglas_KungFuFighting
#     CarlDouglas_KungFuFighting No melody 2 data
# CarrieUnderwood_HomeSweetHome
# CeeloGreen_ForgetYou
#     CherryPoppinDaddies_ZootSuitRiot No melody 2 data
#     CeeloGreen_ForgetYou No melody 2 data
# CheapTrick_IWantYouToWantMe
#     CheapTrick_IWantYouToWantMe No melody 2 data
# CherryPoppinDaddies_ZootSuitRiot
# ChrisBrown_Yeah
#     ChrisBrown_Yeah No melody 2 data
# ChristinaAguilera_GenieInABottle
#     ChristinaAguilera_GenieInABottle No melody 2 data
#     ColdWarKids_HangMeUpToDry No melody 2 data
# Chromeo_Tenderoni
#     Chromeo_Tenderoni No melody 2 data
# Chumbawamba_Tubthumping
#     Chumbawamba_Tubthumping No melody 2 data
# ColdWarKids_HangMeUpToDry
# Coldplay_InMyPlace
#     CorinneBaileyRae_PutYourRecordsOn No melody 2 data
#     Coldplay_InMyPlace No melody 2 data
# Coldplay_Shiver
#     Coldplay_Shiver No melody 2 data
# CorinneBaileyRae_PutYourRecordsOn
# CountZero_Shake
#     CountZero_Shake No melody 2 data
# CountingCrows_AccidentallyInLove
#     CountingCrows_AccidentallyInLove No melody 2 data
# CrazyFrog_JingleBells
#     CrazyFrog_JingleBells No melody 2 data
# FleetwoodMac_Rhiannon
#     FleetwoodMac_Rhiannon No melody 2 data
# FlightOfTheConcords_BusinessTime
#     FlightOfTheConcords_BusinessTime No melody 2 data
# FooFighters_AllMyLife
#     FooFighters_AllMyLife No melody 2 data
# Incubus_Drive
#     Incubus_Drive No melody 2 data
# Inxs_NeedYouTonight
#     KaiserChiefs_Ruby No melody 2 data
#     Inxs_NeedYouTonight No melody 2 data
# KaiserChiefs_Ruby
# Kansas_CarryOnMyWaywardSon
# KanyeWest_LoveLockdown
#     Kansas_CarryOnMyWaywardSon No melody 2 data
#     KanyeWest_LoveLockdown No melody 2 data
# KeithUrban_IToldYouSo
#     KeithUrban_IToldYouSo No melody 2 data
#     KennyChesney_SheThinksMyTractorsSexy No melody 2 data
# KennyChesney_SheThinksMyTractorsSexy
# KingsOfLeon_SexOnFire
#     KingsOfLeon_SexOnFire No melody 2 data
# Kiss_RockAndRollAllNite
#     Kiss_RockAndRollAllNite No melody 2 data
# Knack_MySharona
#     Knack_MySharona No melody 2 data
# Korn_FreakOnALeash
#     Korn_FreakOnALeash No melody 2 data
# KtTunstall_BlackHorseAndTheCherryTree
#     LadyGagaFeaturingBeyonce_Telephone No melody 2 data
#     KtTunstall_BlackHorseAndTheCherryTree No melody 2 data
# KtTunstall_SuddenlyISee
#     KtTunstall_SuddenlyISee No melody 2 data
# LaRoux_Bulletproof
#     LaRoux_Bulletproof No melody 2 data
# LadyGagaFeaturingBeyonce_Telephone
# LadyGaga_BadRomance
#     LadyGaga_BadRomance No melody 2 data
# LadyGaga_BornThisWay
#     LadyGaga_BornThisWay No melody 2 data
#     LennyKravitz_AreYouGonnaGoMyWay No melody 2 data
# LambOfGod_Requiem
#     LambOfGod_Requiem No melody 2 data
# LennyKravitz_AreYouGonnaGoMyWay
# LilyAllen_NotFair
#     LinkinPark_InTheEnd No melody 2 data
#     LilyAllen_NotFair No melody 2 data
# LinkinPark_InTheEnd
# Lit_MyOwnWorstEnemy
#     Lit_MyOwnWorstEnemy No melody 2 data
# Live_IAlone
#     Live_IAlone No melody 2 data
# LoquilloYLosTrogloditas_CadillacSolitario
# LosLobos_LaBamba
#     LoquilloYLosTrogloditas_CadillacSolitario No melody 2 data
#     LosLobos_LaBamba No melody 2 data
# LynyrdSkynyrd_FreeBird
#     LynyrdSkynyrd_FreeBird No melody 2 data
# Maroon5_ThisLove
#     Maroon5_ThisLove No melody 2 data
# MartinaMcbride_ThisOnesForTheGirls
#     MartinaMcbride_ThisOnesForTheGirls No melody 2 data
# MarvinGaye_IHeardItThroughTheGrapevine
#     MarvinGaye_IHeardItThroughTheGrapevine No melody 2 data
#     McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe No melody 2 data
# MarvinGaye_WhatsGoingOn
#     MarvinGaye_WhatsGoingOn No melody 2 data
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
# MichaelJackson_BeatIt
#     MichaelJackson_BeatIt No melody 2 data
# MightyMightyBosstones_WheredYouGo
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  5.4min
#     MightyMightyBosstones_WheredYouGo No melody 2 data
# MikeOldfield_Quicksilver
#     MileyCyrus_7Things No melody 2 data
#     MikeOldfield_Quicksilver No melody 2 data
# MileyCyrus_7Things
# MirandaCosgrove_HeadphonesOn
#     Muffs_KidsInAmerica No melody 2 data
#     MirandaCosgrove_HeadphonesOn No melody 2 data
# Misfits_AstroZombies
#     Misfits_AstroZombies No melody 2 data
# ModestMouse_FloatOn
#     ModestMouse_FloatOn No melody 2 data
# Muffs_KidsInAmerica
# Muse_Hysteria
#     Muse_Hysteria No melody 2 data
# TPain_Bartender
#     TPain_Bartender No melody 2 data
# TalkingHeads_PsychoKiller
#     TalkingHeads_PsychoKiller No melody 2 data
# TaylorSwift_LoveStory
#     TaylorSwift_LoveStory No melody 2 data
# TaylorSwift_YouBelongWithMe
#     TheAllAmericanRejects_DirtyLittleSecret No melody 2 data
#     TaylorSwift_YouBelongWithMe No melody 2 data
# TearsForFears_EverybodyWantsToRuleTheWorld
#     TearsForFears_EverybodyWantsToRuleTheWorld No melody 2 data
# Tesla_ModernDayCowboy
#     Tesla_ModernDayCowboy No melody 2 data
# TheAllAmericanRejects_DirtyLittleSecret
# TheAllmanBrothersBand_RamblinMan
#     TheBeatles_WhatGoesOn No melody 2 data
#     TheAllmanBrothersBand_RamblinMan No melody 2 data
# TheBeatles_TwistAndShout
#     TheBeatles_TwistAndShout No melody 2 data
# TheBeatles_Wait
#     TheBeatles_Wait No melody 2 data
# TheBeatles_WhatGoesOn
# TheBeatles_WhenIm64
# TheBeatles_WhileMyGuitarGentlyWeeps
#     TheBeatles_WhenIm64 No melody 2 data
#     TheBeatles_WhileMyGuitarGentlyWeeps No melody 2 data
#     TheBeatles_WithinYouWithoutYou No melody 2 data
# TheBeatles_WithALittleHelpFromMyFriends
#     TheBeatles_WithALittleHelpFromMyFriends No melody 2 data
# TheBeatles_WithinYouWithoutYou
# TheBeatles_YellowSubmarine
#     TheBeatles_YouWontSeeMe No melody 2 data
#     TheBeatles_YellowSubmarine No melody 2 data
# TheBeatles_YouWontSeeMe
# TheBlackKeys_YourTouch
#     TheBlackKeys_YourTouch No melody 2 data
# TheBravery_Believe
#     TheBravery_Believe No melody 2 data
# TheBronx_FalseAlarm
#     TheBronx_FalseAlarm No melody 2 data
#     TheKooks_Naive No melody 2 data
# TheBronx_SixDaysAWeek
#     TheBronx_SixDaysAWeek No melody 2 data
# TheKillers_SomebodyToldMe
#     TheKillers_SomebodyToldMe No melody 2 data
# TheKooks_Naive
# TheLastGoodnight_PicturesOfYou
#     TheLastGoodnight_PicturesOfYou No melody 2 data
# TheTurtles_HappyTogether
#     TheTurtles_HappyTogether No melody 2 data
# ThinLizzy_TheBoysAreBackInTown
#     ThinLizzy_TheBoysAreBackInTown No melody 2 data
# ThirdEyeBlind_Jumper
#     ThirdEyeBlind_Jumper No melody 2 data
# ThirdEyeBlind_NeverLetYouGo
# TomPettyAndTheHeartbreakers_IWontBackDown
#     ThirdEyeBlind_NeverLetYouGo No melody 2 data
#     TomPettyAndTheHeartbreakers_IWontBackDown No melody 2 data
# TomPetty_FreeFallin
#     TomPetty_FreeFallin No melody 2 data
# Tonic_IfYouCouldOnlySee
#     Tonic_IfYouCouldOnlySee No melody 2 data
# TvOnTheRadio_WolfLikeMe
#     VampireWeekend_Holiday No melody 2 data
#     TvOnTheRadio_WolfLikeMe No melody 2 data
# VampireWeekend_Cousins
#     VampireWeekend_Cousins No melody 2 data
# VampireWeekend_Holiday
# VanHalen_Jump
#     VanHalen_Jump No melody 2 data
# VanillaIce_IceIceBaby
#     VanillaIce_IceIceBaby No melody 2 data
# VillagePeople_Ymca
#     VillagePeople_Ymca No melody 2 data
# Weezer_IslandInTheSun
#     Weezer_IslandInTheSun No melody 2 data
# WildCherry_PlayThatFunkyMusic
#     WildCherry_PlayThatFunkyMusic No melody 2 data
#     Saved data for AimeeNorwich_Flying_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MusicDelta_LatinJazz_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_ModalJazz
#     > using precomputed CQT for MusicDelta_ModalJazz_MIX.wav
#     Saved data for MusicDelta_SpeedMetal_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_SwingJazz
#     > using precomputed CQT for MusicDelta_SwingJazz_MIX.wav
#     Saved data for MusicDelta_BebopJazz_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Beethoven
#     > using precomputed CQT for MusicDelta_Beethoven_MIX.wav
#     Saved data for MusicDelta_Beethoven_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Britpop
#     > using precomputed CQT for MusicDelta_Britpop_MIX.wav
#     Saved data for MusicDelta_Britpop_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_ChineseChaoZhou
#     > using precomputed CQT for MusicDelta_ChineseChaoZhou_MIX.wav
#     Saved data for Debussy_LenfantProdigue_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MusicDelta_ChineseHenan_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_ChineseJiangNan
#     > using precomputed CQT for MusicDelta_ChineseJiangNan_MIX.wav
#     Saved data for ClaraBerryAndWooldog_TheBadGuys_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for FacesOnFilm_WaitingForGa_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# FamilyBand_Again
#     > using precomputed CQT for FamilyBand_Again_MIX.wav
#     Saved data for ChrisJacoby_BoothShotLincoln_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for AvaLuna_Waterduct_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MusicDelta_ChineseChaoZhou_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for CelestialShore_DieForUs_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MusicDelta_Disco_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_FreeJazz
#     > using precomputed CQT for MusicDelta_FreeJazz_MIX.wav
#     Saved data for EthanHein_1930sSynthAndUprightBass_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for DreamersOfTheGhetto_HeavyLove_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MusicDelta_SwingJazz_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Vivaldi
#     > using precomputed CQT for MusicDelta_Vivaldi_MIX.wav
#     Saved data for MusicDelta_Vivaldi_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Zeppelin
#     > using precomputed CQT for MusicDelta_Zeppelin_MIX.wav
#     Saved data for MusicDelta_Zeppelin_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# NightPanther_Fire
#     > using precomputed CQT for NightPanther_Fire_MIX.wav
#     Saved data for MusicDelta_ChineseJiangNan_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_ChineseXinJing
#     > using precomputed CQT for MusicDelta_ChineseXinJing_MIX.wav
#     Saved data for Creepoid_OldTree_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for InvisibleFamiliars_DisturbingWildlife_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# JoelHelander_Definition
#     > using precomputed CQT for JoelHelander_Definition_MIX.wav
#     Saved data for MusicDelta_ModalJazz_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Pachelbel
#     > using precomputed CQT for MusicDelta_Pachelbel_MIX.wav
#     Saved data for Phoenix_ElzicsFarewell_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Phoenix_LarkOnTheStrandDrummondCastle
#     > using precomputed CQT for Phoenix_LarkOnTheStrandDrummondCastle_MIX.wav
#     Saved data for TheSoSoGlos_Emergency_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Wolf_DieBekherte
#     > using precomputed CQT for Wolf_DieBekherte_MIX.wav
#     Saved data for MusicDelta_ChineseXinJing_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_ChineseYaoZu
#     > using precomputed CQT for MusicDelta_ChineseYaoZu_MIX.wav
#     Saved data for ChrisJacoby_PigsFoot_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MusicDelta_FreeJazz_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_FunkJazz
#     > using precomputed CQT for MusicDelta_FunkJazz_MIX.wav
#     Saved data for TheDistricts_Vermont_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# TheScarletBrand_LesFleursDuMal
#     > using precomputed CQT for TheScarletBrand_LesFleursDuMal_MIX.wav
#     Saved data for LizNelson_Rainfall_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Lushlife_ToynbeeSuite
#     Lushlife_ToynbeeSuite No melody 2 data
# MatthewEntwistle_AnEveningWithOliver
#     MatthewEntwistle_AnEveningWithOliver No melody 2 data
# MatthewEntwistle_DontYouEver
#     > using precomputed CQT for MatthewEntwistle_DontYouEver_MIX.wav
#     Saved data for MusicDelta_ChineseYaoZu_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_CoolJazz
#     > using precomputed CQT for MusicDelta_CoolJazz_MIX.wav
#     Saved data for AlexanderRoss_GoodbyeBolero_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MusicDelta_FunkJazz_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_FusionJazz
#     > using precomputed CQT for MusicDelta_FusionJazz_MIX.wav
#     Saved data for FamilyBand_Again_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Grants_PunchDrunk
#     Grants_PunchDrunk No melody 2 data
# Handel_TornamiAVagheggiar
#     > using precomputed CQT for Handel_TornamiAVagheggiar_MIX.wav
#     Saved data for CroqueMadame_Oil_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MatthewEntwistle_TheFlaxenField_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Meaxic_TakeAStep
#     > using precomputed CQT for Meaxic_TakeAStep_MIX.wav
#     Saved data for MusicDelta_CoolJazz_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Country1
#     > using precomputed CQT for MusicDelta_Country1_MIX.wav
#     Saved data for CroqueMadame_Pilot_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for SecretMountains_HighHorse_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Snowmine_Curfews
#     > using precomputed CQT for Snowmine_Curfews_MIX.wav
#     Saved data for NightPanther_Fire_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Phoenix_BrokenPledgeChicagoReel
#     > using precomputed CQT for Phoenix_BrokenPledgeChicagoReel_MIX.wav
#     Saved data for MatthewEntwistle_DontYouEver_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MatthewEntwistle_FairerHopes
#     > using precomputed CQT for MatthewEntwistle_FairerHopes_MIX.wav
#     Saved data for MusicDelta_FusionJazz_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Gospel
#     > using precomputed CQT for MusicDelta_Gospel_MIX.wav
#     Saved data for MusicDelta_Country1_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Country2
#     > using precomputed CQT for MusicDelta_Country2_MIX.wav
#     Saved data for MusicDelta_Country2_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for Wolf_DieBekherte_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Allegria_MendelssohnMovement1
#     Allegria_MendelssohnMovement1 No melody 2 data
# AmadeusRedux_MozartAllegro
#     AmadeusRedux_MozartAllegro No melody 2 data
# AmadeusRedux_SchubertMovement2
#     AmadeusRedux_SchubertMovement2 No melody 2 data
# AmadeusRedux_SchubertMovement3
#     AmadeusRedux_SchubertMovement3 No melody 2 data
# BarefootSisters_RedJetta
#     BarefootSisters_RedJetta No melody 2 data
# CassandraJenkins_PerfectDay
#     CassandraJenkins_PerfectDay No melody 2 data
#     Saved data for MatthewEntwistle_FairerHopes_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MatthewEntwistle_ImpressionsOfSaturn
#     > using precomputed CQT for MatthewEntwistle_ImpressionsOfSaturn_MIX.wav
#     Saved data for JoelHelander_Definition_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for AlexanderRoss_VelvetCurtain_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# JoelHelander_ExcessiveResistancetoChange
#     > using precomputed CQT for JoelHelander_ExcessiveResistancetoChange_MIX.wav
#     Saved data for MatthewEntwistle_ImpressionsOfSaturn_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MatthewEntwistle_Lontano
#     > using precomputed CQT for MatthewEntwistle_Lontano_MIX.wav
#     Saved data for Phoenix_LarkOnTheStrandDrummondCastle_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Phoenix_ScotchMorris
#     > using precomputed CQT for Phoenix_ScotchMorris_MIX.wav
#     Saved data for MusicDelta_Gospel_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_GriegTrolltog
#     > using precomputed CQT for MusicDelta_GriegTrolltog_MIX.wav
#     Saved data for MusicDelta_Pachelbel_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Punk
#     > using precomputed CQT for MusicDelta_Punk_MIX.wav
#     Saved data for MusicDelta_Punk_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Reggae
#     > using precomputed CQT for MusicDelta_Reggae_MIX.wav
#     Saved data for MusicDelta_Reggae_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Rock
#     > using precomputed CQT for MusicDelta_Rock_MIX.wav
#     Saved data for MusicDelta_Rock_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Rockabilly
#     > using precomputed CQT for MusicDelta_Rockabilly_MIX.wav
#     Saved data for MusicDelta_Rockabilly_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MusicDelta_GriegTrolltog_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Grunge
#     > using precomputed CQT for MusicDelta_Grunge_MIX.wav
#     Saved data for Handel_TornamiAVagheggiar_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# HeladoNegro_MitadDelMundo
#     > using precomputed CQT for HeladoNegro_MitadDelMundo_MIX.wav
#     Saved data for TheScarletBrand_LesFleursDuMal_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for MusicDelta_Grunge_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Hendrix
#     > using precomputed CQT for MusicDelta_Hendrix_MIX.wav
#     Saved data for MusicDelta_Hendrix_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for Phoenix_BrokenPledgeChicagoReel_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Phoenix_ColliersDaughter
#     > using precomputed CQT for Phoenix_ColliersDaughter_MIX.wav
#     Saved data for Phoenix_ScotchMorris_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Phoenix_SeanCaughlinsTheScartaglen
#     > using precomputed CQT for Phoenix_SeanCaughlinsTheScartaglen_MIX.wav
#     Saved data for Meaxic_TakeAStep_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Meaxic_YouListen
#     > using precomputed CQT for Meaxic_YouListen_MIX.wav
#     Saved data for JoelHelander_ExcessiveResistancetoChange_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# JoelHelander_IntheAtticBedroom
#     > using precomputed CQT for JoelHelander_IntheAtticBedroom_MIX.wav
#     Saved data for Snowmine_Curfews_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# StevenClark_Bounty
#     > using precomputed CQT for StevenClark_Bounty_MIX.wav
#     Saved data for MatthewEntwistle_Lontano_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MatthewEntwistle_TheArch
#     > using precomputed CQT for MatthewEntwistle_TheArch_MIX.wav
#     Saved data for HeladoNegro_MitadDelMundo_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# HezekiahJones_BorrowedHeart
#     > using precomputed CQT for HezekiahJones_BorrowedHeart_MIX.wav
#     Saved data for Phoenix_ColliersDaughter_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for Phoenix_SeanCaughlinsTheScartaglen_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# PortStWillow_StayEven
#     > using precomputed CQT for PortStWillow_StayEven_MIX.wav
#     Saved data for JoelHelander_IntheAtticBedroom_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# KarimDouaidy_Hopscotch
#     > using precomputed CQT for KarimDouaidy_Hopscotch_MIX.wav
#     Saved data for StevenClark_Bounty_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# StrandOfOaks_Spacestation
#     > using precomputed CQT for StrandOfOaks_Spacestation_MIX.wav
#     Saved data for MatthewEntwistle_TheArch_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for HezekiahJones_BorrowedHeart_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# HopAlong_SisterCities
#     > using precomputed CQT for HopAlong_SisterCities_MIX.wav
#     Saved data for Meaxic_YouListen_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MichaelKropf_AllGoodThings
#     > using precomputed CQT for MichaelKropf_AllGoodThings_MIX.wav
#     Saved data for PortStWillow_StayEven_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# PurlingHiss_Lolita
#     > using precomputed CQT for PurlingHiss_Lolita_MIX.wav
#     Saved data for StrandOfOaks_Spacestation_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# SweetLights_YouLetMeDown
#     > using precomputed CQT for SweetLights_YouLetMeDown_MIX.wav
#     Saved data for KarimDouaidy_Hopscotch_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# KarimDouaidy_Yatora
#     > using precomputed CQT for KarimDouaidy_Yatora_MIX.wav
#     Saved data for MichaelKropf_AllGoodThings_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Mozart_BesterJungling
#     > using precomputed CQT for Mozart_BesterJungling_MIX.wav
#     Saved data for HopAlong_SisterCities_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for PurlingHiss_Lolita_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Schubert_Erstarrung
#     > using precomputed CQT for Schubert_Erstarrung_MIX.wav
#     Saved data for Mozart_BesterJungling_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Mozart_DiesBildnis
#     > using precomputed CQT for Mozart_DiesBildnis_MIX.wav
#     Saved data for KarimDouaidy_Yatora_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# LizNelson_Coldwar
#     > using precomputed CQT for LizNelson_Coldwar_MIX.wav
#     Saved data for Schubert_Erstarrung_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# Schumann_Mignon
#     > using precomputed CQT for Schumann_Mignon_MIX.wav
#     Saved data for SweetLights_YouLetMeDown_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# TablaBreakbeatScience_Animoog
#     TablaBreakbeatScience_Animoog No melody 2 data
# TablaBreakbeatScience_CaptainSky
#     TablaBreakbeatScience_CaptainSky No melody 2 data
# TablaBreakbeatScience_MiloVsMongo
#     TablaBreakbeatScience_MiloVsMongo No melody 2 data
#     Saved data for LizNelson_Coldwar_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# LizNelson_ImComingHome
#     > using precomputed CQT for LizNelson_ImComingHome_MIX.wav
#     Saved data for Mozart_DiesBildnis_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_80sRock
#     > using precomputed CQT for MusicDelta_80sRock_MIX.wav
#     Saved data for MusicDelta_80sRock_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# MusicDelta_Beatles
#     > using precomputed CQT for MusicDelta_Beatles_MIX.wav
#     Saved data for MusicDelta_Beatles_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for Schumann_Mignon_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
#     Saved data for LizNelson_ImComingHome_mel2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/
# [Parallel(n_jobs=-1)]: Done 320 out of 320 | elapsed: 48.5min finished
# Done!

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/" "melody3" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
#     > already done!
#     > already done!
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
# AmarLal_Rest
#     > already done!
#     > already done!
# AmarLal_SpringDay1
#     > already done!
# Auctioneer_OurFutureFaces
# BigTroubles_Phantom
#     > already done!
# BrandonWebster_YesSirICanFly
#     > already done!
# AlexanderRoss_VelvetCurtain
# AvaLuna_Waterduct
# ChrisJacoby_BoothShotLincoln
# BrandonWebster_DontHearAThing
#     > already done!
#     > already done!
# CelestialShore_DieForUs
# ClaraBerryAndWooldog_AirTraffic
#     > already done!
# ClaraBerryAndWooldog_Stella
#     > already done!
# ChrisJacoby_PigsFoot
#     > already done!
# ClaraBerryAndWooldog_WaltzForMyVictims
#     > already done!
# CroqueMadame_Oil
# ClaraBerryAndWooldog_Boys
#     > already done!
# ClaraBerryAndWooldog_TheBadGuys
#     > already done!
#     > already done!
# Debussy_LenfantProdigue
#     > already done!
# EthanHein_1930sSynthAndUprightBass
#     > already done!
#     > already done!
# Creepoid_OldTree
# EthanHein_GirlOnABridge
#     > already done!
#     > already done!
#     > already done!
#     > already done!
# DreamersOfTheGhetto_HeavyLove
# EthanHein_HarmonicaFigure
# CroqueMadame_Pilot
#    EthanHein_HarmonicaFigure No melody 3 data
# FacesOnFilm_WaitingForGa
#     > already done!
# EthanHein_BluesForNofi
#     > already done!
# Grants_PunchDrunk
#    EthanHein_BluesForNofi No melody 3 data
#    Grants_PunchDrunk No melody 3 data
# Handel_TornamiAVagheggiar
#     > already done!
# HeladoNegro_MitadDelMundo
# FamilyBand_Again
#     > already done!
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.1s
# HopAlong_SisterCities
#     > already done!
#     > already done!
# HezekiahJones_BorrowedHeart
#     > already done!
# JoelHelander_Definition
#     > already done!
# InvisibleFamiliars_DisturbingWildlife
#     > already done!
# JoelHelander_IntheAtticBedroom
#     > already done!
# KarimDouaidy_Yatora
# LizNelson_ImComingHome
#     > already done!
#     > already done!
#     > already done!
# JoelHelander_ExcessiveResistancetoChange
#     > already done!
# KarimDouaidy_Hopscotch
# LizNelson_Coldwar
#     > already done!
# LizNelson_Rainfall
# Lushlife_ToynbeeSuite
#    Lushlife_ToynbeeSuite No melody 3 data
# MatthewEntwistle_DontYouEver
# MatthewEntwistle_AnEveningWithOliver
#    MatthewEntwistle_AnEveningWithOliver No melody 3 data
#     > already done!
# MatthewEntwistle_ImpressionsOfSaturn
#     > already done!
#     > already done!
# MatthewEntwistle_FairerHopes
#     > already done!
#     > already done!
# MatthewEntwistle_TheArch
# MichaelKropf_AllGoodThings
# Meaxic_TakeAStep
# Mozart_DiesBildnis
#     > already done!
# MusicDelta_Beatles
# MatthewEntwistle_Lontano
#     > already done!
# MusicDelta_BebopJazz
#     > already done!
#     > already done!
# MusicDelta_Beethoven
# MusicDelta_80sRock
#     > already done!
# Mozart_BesterJungling
#     > already done!
# MusicDelta_ChineseChaoZhou
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_Britpop
# MusicDelta_ChineseHenan
#     > already done!
#     > already done!
#     > already done!
# Meaxic_YouListen
# MusicDelta_ChineseDrama
# MatthewEntwistle_TheFlaxenField
#     > already done!
# MusicDelta_ChineseXinJing
# MusicDelta_CoolJazz
#     > already done!
#     > already done!
# MusicDelta_ChineseYaoZu
# MusicDelta_ChineseJiangNan
# MusicDelta_Country2
#     > already done!
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_Country1
# MusicDelta_FreeJazz
# MusicDelta_Disco
#     > already done!
# MusicDelta_FusionJazz
#     > already done!
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_FunkJazz
# MusicDelta_GriegTrolltog
#     > already done!
#     > already done!
# MusicDelta_Gospel
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_Hendrix
#     > already done!
#     > already done!
# MusicDelta_Grunge
# MusicDelta_InTheHalloftheMountainKing
#     > already done!
#     > already done!
# MusicDelta_LatinJazz
# MusicDelta_Pachelbel
# MusicDelta_Reggae
#     > already done!
# MusicDelta_Rock
# MusicDelta_Rockabilly
#     > already done!
#     > already done!
# MusicDelta_Shadows
#     > already done!
# MusicDelta_SpeedMetal
# MusicDelta_Vivaldi
#     > already done!
# MusicDelta_SwingJazz
#     > already done!
# MusicDelta_Zeppelin
#     > already done!
# MusicDelta_ModalJazz
# NightPanther_Fire
#     > already done!
#     > already done!
# Phoenix_ColliersDaughter
# MusicDelta_Punk
# Phoenix_LarkOnTheStrandDrummondCastle
#     > already done!
#     > already done!
# Phoenix_SeanCaughlinsTheScartaglen
#     > already done!
#     > already done!
# Phoenix_ElzicsFarewell
# Phoenix_BrokenPledgeChicagoReel
#     > already done!
# PurlingHiss_Lolita
# Schubert_Erstarrung
#     > already done!
# SecretMountains_HighHorse
#     > already done!
#     > already done!
# PortStWillow_StayEven
#     > already done!
#     > already done!
# Phoenix_ScotchMorris
#     > already done!
# Schumann_Mignon
# StevenClark_Bounty
#     > already done!
#     > already done!
# Snowmine_Curfews
# SweetLights_YouLetMeDown
#     > already done!
#     > already done!
# TablaBreakbeatScience_CaptainSky
#    TablaBreakbeatScience_CaptainSky No melody 3 data
# TablaBreakbeatScience_MiloVsMongo
#    TablaBreakbeatScience_MiloVsMongo No melody 3 data
# TablaBreakbeatScience_MoodyPlucks
#     > already done!
# StrandOfOaks_Spacestation
#    TablaBreakbeatScience_MoodyPlucks No melody 3 data
# TablaBreakbeatScience_PhaseTransition
#    TablaBreakbeatScience_PhaseTransition No melody 3 data
# TablaBreakbeatScience_RockSteady
#    TablaBreakbeatScience_RockSteady No melody 3 data
# TablaBreakbeatScience_Scorpio
#    TablaBreakbeatScience_Scorpio No melody 3 data
#     > already done!
# TablaBreakbeatScience_Animoog
# TablaBreakbeatScience_Vger
#     > already done!
#    TablaBreakbeatScience_Animoog No melody 3 data
#    TablaBreakbeatScience_Vger No melody 3 data
# TablaBreakbeatScience_WhoIsIt
#    TablaBreakbeatScience_WhoIsIt No melody 3 data
#     > already done!
# TheDistricts_Vermont
# TheSoSoGlos_Emergency
# Allegria_MendelssohnMovement1
#     > already done!
# TheScarletBrand_LesFleursDuMal
#    Allegria_MendelssohnMovement1 No melody 3 data
#     > already done!
# Wolf_DieBekherte
# AmadeusRedux_MozartAllegro
#    AmadeusRedux_MozartAllegro No melody 3 data
# AmadeusRedux_SchubertMovement2
#    AmadeusRedux_SchubertMovement2 No melody 3 data
# AmadeusRedux_SchubertMovement3
#    AmadeusRedux_SchubertMovement3 No melody 3 data
#     > already done!
#     > already done!
# BarefootSisters_RedJetta
#    BarefootSisters_RedJetta No melody 3 data
# CassandraJenkins_PerfectDay
#    CassandraJenkins_PerfectDay No melody 3 data
# CatMartino_IPromise
#    CatMartino_IPromise No melody 3 data
# Cayetana_MissThing
#    Cayetana_MissThing No melody 3 data
# DahkaBand_SoldierMan
#    DahkaBand_SoldierMan No melody 3 data
#    DeadMilkmen_PrisonersCinema No melody 3 data
# DeadMilkmen_PrisonersCinema
# DeclareAString_MendelssohnPianoTrio1Movement1
#    DeclareAString_MendelssohnPianoTrio1Movement1 No melody 3 data
# DeclareAString_MendelssohnPianoTrio1Movement2
#    DeclareAString_MendelssohnPianoTrio1Movement2 No melody 3 data
# FallingSparks_Improvisation1
#    FallingSparks_Improvisation2 No melody 3 data
#    FallingSparks_Improvisation1 No melody 3 data
# FallingSparks_Improvisation2
# FallingSparks_Improvisation3
#    FallingSparks_PakKlongTalad No melody 3 data
#    FallingSparks_Improvisation3 No melody 3 data
# FallingSparks_PakKlongTalad
# FennelCartwright_DearTessie
#    FennelCartwright_DearTessie No melody 3 data
#    FennelCartwright_FlowerDrumSong No melody 3 data
# FennelCartwright_FlowerDrumSong
# FennelCartwright_WinterLake
#    FennelCartwright_WinterLake No melody 3 data
# FilthyBird_IdLikeToKnow
#    FilthyBird_IdLikeToKnow No melody 3 data
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    4.0s
# FruitCathedral_KeepMeRunnin
#    HopsNVinyl_ChickenFriedSteak No melody 3 data
#    FruitCathedral_KeepMeRunnin No melody 3 data
# HopsNVinyl_ChickenFriedSteak
# HopsNVinyl_HoneyBrown
#    HopsNVinyl_ReignCheck No melody 3 data
#    HopsNVinyl_HoneyBrown No melody 3 data
# HopsNVinyl_ReignCheck
# HopsNVinyl_WidowsWalk
#    Karachacha_Volamos No melody 3 data
#    HopsNVinyl_WidowsWalk No melody 3 data
# Karachacha_Volamos
# Katzn_CharlieKnox
#    LewisAndClarke_TheSilverSea No melody 3 data
#    Katzn_CharlieKnox No melody 3 data
# LewisAndClarke_TheSilverSea
# LittleTybee_TheAlchemist
#    MatthewEntwistle_ReturnToVenezia No melody 3 data
#    LittleTybee_TheAlchemist No melody 3 data
# MatthewEntwistle_ReturnToVenezia
# MidnightBlue_HuntingSeason
#    MidnightBlue_StarsAreScreaming No melody 3 data
#    MidnightBlue_HuntingSeason No melody 3 data
# MidnightBlue_StarsAreScreaming
# MutualBenefit_NotForNothing
#    PatternIsMovement_SaveMe No melody 3 data
#    MutualBenefit_NotForNothing No melody 3 data
# PatternIsMovement_SaveMe
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#    PeterMatthewBauer_YouAlwaysLookForSomeoneLost No melody 3 data
#    Plasma_GoodShout No melody 3 data
# Plasma_GoodShout
# PoliceHearingDepartment_Brahms
#    PoliceHearingDepartment_SchumannMovement1 No melody 3 data
#    PoliceHearingDepartment_Brahms No melody 3 data
# PoliceHearingDepartment_SchumannMovement1
# PoliceHearingDepartment_SchumannMovement2
#    PoliceHearingDepartment_SchumannMovement2 No melody 3 data
# PoliceHearingDepartment_VivaldiMovement1
#    PoliceHearingDepartment_VivaldiMovement1 No melody 3 data
# PoliceHearingDepartment_VivaldiMovement2
#    PoliceHearingDepartment_VivaldiMovement2 No melody 3 data
# PoliceHearingDepartment_VivaldiMovement3
#    PoliceHearingDepartment_VivaldiMovement3 No melody 3 data
# QuantumChromos_Circuits
#    RodrigoBonelli_BalladForLaura No melody 3 data
#    QuantumChromos_Circuits No melody 3 data
# RodrigoBonelli_BalladForLaura
# SasquatchConnection_BoomBoxing
#    SasquatchConnection_BoomBoxing No melody 3 data
# SasquatchConnection_HolyClamsBatman
#    SasquatchConnection_HolyClamsBatman No melody 3 data
# SasquatchConnection_Illuminati
#    SasquatchConnection_Struttin No melody 3 data
#    SasquatchConnection_Illuminati No melody 3 data
# SasquatchConnection_Struttin
# SasquatchConnection_ThanksALatte
# SlowGhost_FirstSnow
#    SasquatchConnection_ThanksALatte No melody 3 data
#    SlowGhost_FirstSnow No melody 3 data
# SlowGhost_MidnightGroove
#    SlowGhost_MidnightGroove No melody 3 data
#    SlowGhost_Peanut No melody 3 data
# SlowGhost_Peanut
# SlowGhost_YoureAMystery
#    SlowGhost_YoureAMystery No melody 3 data
# SongYiJeon_TwoMoons
#    SongYiJeon_TwoMoons No melody 3 data
# Sweat_AlmostAlways
#    Sweat_Anecdoche No melody 3 data
#    Sweat_AlmostAlways No melody 3 data
# Sweat_Anecdoche
# Sweat_Elegy
#    Sweat_Mesozoic No melody 3 data
#    Sweat_Elegy No melody 3 data
# Sweat_Mesozoic
# Sweat_Sn1572
#    Sweat_Tact No melody 3 data
#    Sweat_Sn1572 No melody 3 data
# Sweat_Tact
# TemperedElan_DorothyJeanne
#    TemperedElan_DorothyJeanne No melody 3 data
# TemperedElan_WiseOne
#    TemperedElan_WiseOne No melody 3 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#    TheFranckDuo_FranckViolinSonataInAMajorMovement1 No melody 3 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
#    TheFranckDuo_FranckViolinSonataInAMajorMovement2 No melody 3 data
# TheKitchenettes_Alive
#    TheKitchenettes_Alive No melody 3 data
# TheNoHoStringOrchestra_ElgarMovement1
#    TheNoHoStringOrchestra_ElgarMovement1 No melody 3 data
# TheNoHoStringOrchestra_ElgarMovement2
#    TheNoHoStringOrchestra_ElgarMovement2 No melody 3 data
#    TheNoHoStringOrchestra_ElgarMovement3 No melody 3 data
# TheNoHoStringOrchestra_ElgarMovement3
# TheTonTons_Lush
#    TheTonTons_Lush No melody 3 data
# TleilaxEnsemble_Late
#    TleilaxEnsemble_Late No melody 3 data
# TleilaxEnsemble_MelancholyFlowers
#    Torres_NewSkin No melody 3 data
#    TleilaxEnsemble_MelancholyFlowers No melody 3 data
# Torres_NewSkin
# TrevorAndTheSoundwaves_AloneAndSad
#    TrevorAndTheSoundwaves_AloneAndSad No melody 3 data
# Verdi_IlTrovatore
#    Verdi_IlTrovatore No melody 3 data
# AHa_TakeOnMe
#    AHa_TakeOnMe No melody 3 data
# AcDc_BackInBlack
#    AcDc_BackInBlack No melody 3 data
# Adele_SomeoneLikeYou
#    Adele_SomeoneLikeYou No melody 3 data
# Aerosmith_LoveInAnElevator
#    Aerosmith_LoveInAnElevator No melody 3 data
# AlanisMorissette_YouOughtaKnow
#    AllThatRemains_Chiron No melody 3 data
#    AlanisMorissette_YouOughtaKnow No melody 3 data
# AllThatRemains_Chiron
# AnEndlessSporadic_Anything
#    Anberlin_TheFeelGoodDrag No melody 3 data
#    AnEndlessSporadic_Anything No melody 3 data
# Anberlin_TheFeelGoodDrag
# ArcadeFire_BlackMirror
#    ArcticMonkeys_Brainstorm No melody 3 data
#    ArcadeFire_BlackMirror No melody 3 data
# ArcticMonkeys_Brainstorm
# BillyIdol_WhiteWedding
#    BillyIdol_WhiteWedding No melody 3 data
# BillySquier_TheStroke
#    BillySquier_TheStroke No melody 3 data
# BlackEyedPeas_IGottaFeeling
#    BlackEyedPeas_IGottaFeeling No melody 3 data
# BlackSabbath_WarPigs
#    BlackSabbath_WarPigs No melody 3 data
# Blink182_AllTheSmallThings
#    Blink182_AllTheSmallThings No melody 3 data
# Blondie_OneWayOrAnother
#    Blondie_OneWayOrAnother No melody 3 data
# BlueOysterCult_DontFearTheReaper
#    BlueOysterCult_DontFearTheReaper No melody 3 data
# BobSeger_OldTimeRockAndRoll
#    BobSeger_OldTimeRockAndRoll No melody 3 data
# Boston_MoreThanAFeeling
#    Boston_MoreThanAFeeling No melody 3 data
# BradPaisley_MudOnTheTires
#    BradPaisley_MudOnTheTires No melody 3 data
# BrooksDunn_HillbillyDeluxe
#    BrooksDunn_HillbillyDeluxe No melody 3 data
# BrunoMars_Grenade
#    BrunoMars_Grenade No melody 3 data
# BrunoMars_JustTheWayYouAre
#    BrunoMars_MarryYou No melody 3 data
#    BrunoMars_JustTheWayYouAre No melody 3 data
# BrunoMars_MarryYou
# BryanAdams_SummerOf69
#    BryanAdams_SummerOf69 No melody 3 data
# Bush_Machinehead
#    Bush_Machinehead No melody 3 data
# CarlDouglas_KungFuFighting
#    CarlDouglas_KungFuFighting No melody 3 data
# CarrieUnderwood_HomeSweetHome
#    CarrieUnderwood_HomeSweetHome No melody 3 data
# CeeloGreen_ForgetYou
# CheapTrick_IWantYouToWantMe
#    CeeloGreen_ForgetYou No melody 3 data
#    CheapTrick_IWantYouToWantMe No melody 3 data
# CherryPoppinDaddies_ZootSuitRiot
#    CherryPoppinDaddies_ZootSuitRiot No melody 3 data
# ChrisBrown_Yeah
#    ChrisBrown_Yeah No melody 3 data
# ChristinaAguilera_GenieInABottle
# Chromeo_Tenderoni
#    ChristinaAguilera_GenieInABottle No melody 3 data
#    Chromeo_Tenderoni No melody 3 data
# Chumbawamba_Tubthumping
#    Chumbawamba_Tubthumping No melody 3 data
# ColdWarKids_HangMeUpToDry
#    ColdWarKids_HangMeUpToDry No melody 3 data
# Coldplay_InMyPlace
#    Coldplay_InMyPlace No melody 3 data
# Coldplay_Shiver
#    Coldplay_Shiver No melody 3 data
# CorinneBaileyRae_PutYourRecordsOn
#    CorinneBaileyRae_PutYourRecordsOn No melody 3 data
# CountZero_Shake
#    CountZero_Shake No melody 3 data
# CountingCrows_AccidentallyInLove
#    CrazyFrog_JingleBells No melody 3 data
#    CountingCrows_AccidentallyInLove No melody 3 data
# CrazyFrog_JingleBells
# FleetwoodMac_Rhiannon
# FlightOfTheConcords_BusinessTime
#    FleetwoodMac_Rhiannon No melody 3 data
#    FlightOfTheConcords_BusinessTime No melody 3 data
# FooFighters_AllMyLife
# Incubus_Drive
#    FooFighters_AllMyLife No melody 3 data
#    Incubus_Drive No melody 3 data
# Inxs_NeedYouTonight
#    KaiserChiefs_Ruby No melody 3 data
#    Inxs_NeedYouTonight No melody 3 data
# KaiserChiefs_Ruby
# Kansas_CarryOnMyWaywardSon
#    Kansas_CarryOnMyWaywardSon No melody 3 data
# KanyeWest_LoveLockdown
#    KanyeWest_LoveLockdown No melody 3 data
# KeithUrban_IToldYouSo
# KennyChesney_SheThinksMyTractorsSexy
#    KeithUrban_IToldYouSo No melody 3 data
#    KennyChesney_SheThinksMyTractorsSexy No melody 3 data
# KingsOfLeon_SexOnFire
#    Kiss_RockAndRollAllNite No melody 3 data
#    KingsOfLeon_SexOnFire No melody 3 data
# Kiss_RockAndRollAllNite
# Knack_MySharona
#    Knack_MySharona No melody 3 data
# Korn_FreakOnALeash
#    Korn_FreakOnALeash No melody 3 data
# KtTunstall_BlackHorseAndTheCherryTree
#    KtTunstall_BlackHorseAndTheCherryTree No melody 3 data
# KtTunstall_SuddenlyISee
#    KtTunstall_SuddenlyISee No melody 3 data
# LaRoux_Bulletproof
#    LadyGagaFeaturingBeyonce_Telephone No melody 3 data
#    LaRoux_Bulletproof No melody 3 data
# LadyGagaFeaturingBeyonce_Telephone
# LadyGaga_BadRomance
#    LadyGaga_BadRomance No melody 3 data
# LadyGaga_BornThisWay
#    LadyGaga_BornThisWay No melody 3 data
# LambOfGod_Requiem
#    LambOfGod_Requiem No melody 3 data
# LennyKravitz_AreYouGonnaGoMyWay
#    LennyKravitz_AreYouGonnaGoMyWay No melody 3 data
# LilyAllen_NotFair
# LinkinPark_InTheEnd
#    LilyAllen_NotFair No melody 3 data
#    LinkinPark_InTheEnd No melody 3 data
# Lit_MyOwnWorstEnemy
#    Lit_MyOwnWorstEnemy No melody 3 data
# Live_IAlone
#    Live_IAlone No melody 3 data
# LoquilloYLosTrogloditas_CadillacSolitario
#    LoquilloYLosTrogloditas_CadillacSolitario No melody 3 data
# LosLobos_LaBamba
#    LosLobos_LaBamba No melody 3 data
# LynyrdSkynyrd_FreeBird
#    Maroon5_ThisLove No melody 3 data
#    LynyrdSkynyrd_FreeBird No melody 3 data
# Maroon5_ThisLove
# MartinaMcbride_ThisOnesForTheGirls
#    MarvinGaye_IHeardItThroughTheGrapevine No melody 3 data
#    MartinaMcbride_ThisOnesForTheGirls No melody 3 data
# MarvinGaye_IHeardItThroughTheGrapevine
# MarvinGaye_WhatsGoingOn
#    McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe No melody 3 data
#    MarvinGaye_WhatsGoingOn No melody 3 data
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
# MichaelJackson_BeatIt
# MightyMightyBosstones_WheredYouGo
#    MichaelJackson_BeatIt No melody 3 data
#    MightyMightyBosstones_WheredYouGo No melody 3 data
# MikeOldfield_Quicksilver
#    MikeOldfield_Quicksilver No melody 3 data
# MileyCyrus_7Things
#    MileyCyrus_7Things No melody 3 data
# MirandaCosgrove_HeadphonesOn
# Misfits_AstroZombies
#    MirandaCosgrove_HeadphonesOn No melody 3 data
#    Misfits_AstroZombies No melody 3 data
# ModestMouse_FloatOn
#    Muffs_KidsInAmerica No melody 3 data
#    ModestMouse_FloatOn No melody 3 data
# Muffs_KidsInAmerica
# Muse_Hysteria
# TPain_Bartender
#    Muse_Hysteria No melody 3 data
#    TPain_Bartender No melody 3 data
# TalkingHeads_PsychoKiller
#    TalkingHeads_PsychoKiller No melody 3 data
#    TaylorSwift_LoveStory No melody 3 data
# TaylorSwift_LoveStory
# TaylorSwift_YouBelongWithMe
# TearsForFears_EverybodyWantsToRuleTheWorld
#    TaylorSwift_YouBelongWithMe No melody 3 data
#    TearsForFears_EverybodyWantsToRuleTheWorld No melody 3 data
# Tesla_ModernDayCowboy
#    TheAllAmericanRejects_DirtyLittleSecret No melody 3 data
#    Tesla_ModernDayCowboy No melody 3 data
# TheAllAmericanRejects_DirtyLittleSecret
# TheAllmanBrothersBand_RamblinMan
# TheBeatles_TwistAndShout
#    TheAllmanBrothersBand_RamblinMan No melody 3 data
#    TheBeatles_TwistAndShout No melody 3 data
# TheBeatles_Wait
#    TheBeatles_WhatGoesOn No melody 3 data
#    TheBeatles_Wait No melody 3 data
# TheBeatles_WhatGoesOn
# TheBeatles_WhenIm64
#    TheBeatles_WhileMyGuitarGentlyWeeps No melody 3 data
#    TheBeatles_WhenIm64 No melody 3 data
# TheBeatles_WhileMyGuitarGentlyWeeps
# TheBeatles_WithALittleHelpFromMyFriends
#    TheBeatles_WithinYouWithoutYou No melody 3 data
#    TheBeatles_WithALittleHelpFromMyFriends No melody 3 data
# TheBeatles_WithinYouWithoutYou
# TheBeatles_YellowSubmarine
#    TheBeatles_YouWontSeeMe No melody 3 data
#    TheBeatles_YellowSubmarine No melody 3 data
# TheBeatles_YouWontSeeMe
# TheBlackKeys_YourTouch
#    TheBravery_Believe No melody 3 data
#    TheBlackKeys_YourTouch No melody 3 data
# TheBravery_Believe
# TheBronx_FalseAlarm
#    TheBronx_SixDaysAWeek No melody 3 data
#    TheBronx_FalseAlarm No melody 3 data
# TheBronx_SixDaysAWeek
# TheKillers_SomebodyToldMe
#    TheKooks_Naive No melody 3 data
#    TheKillers_SomebodyToldMe No melody 3 data
# TheKooks_Naive
# TheLastGoodnight_PicturesOfYou
# TheTurtles_HappyTogether
#    TheLastGoodnight_PicturesOfYou No melody 3 data
#    TheTurtles_HappyTogether No melody 3 data
# ThinLizzy_TheBoysAreBackInTown
#    ThinLizzy_TheBoysAreBackInTown No melody 3 data
# ThirdEyeBlind_Jumper
#    ThirdEyeBlind_Jumper No melody 3 data
# ThirdEyeBlind_NeverLetYouGo
#    TomPettyAndTheHeartbreakers_IWontBackDown No melody 3 data
#    ThirdEyeBlind_NeverLetYouGo No melody 3 data
# TomPettyAndTheHeartbreakers_IWontBackDown
# TomPetty_FreeFallin
#    TomPetty_FreeFallin No melody 3 data
#    Tonic_IfYouCouldOnlySee No melody 3 data
# Tonic_IfYouCouldOnlySee
# TvOnTheRadio_WolfLikeMe
#    TvOnTheRadio_WolfLikeMe No melody 3 data
# VampireWeekend_Cousins
#    VampireWeekend_Cousins No melody 3 data
# VampireWeekend_Holiday
#    VampireWeekend_Holiday No melody 3 data
# VanHalen_Jump
#    VanHalen_Jump No melody 3 data
# VanillaIce_IceIceBaby
#    VanillaIce_IceIceBaby No melody 3 data
# VillagePeople_Ymca
#    VillagePeople_Ymca No melody 3 data
# Weezer_IslandInTheSun
#    Weezer_IslandInTheSun No melody 3 data
# WildCherry_PlayThatFunkyMusic
#    WildCherry_PlayThatFunkyMusic No melody 3 data
# Done!
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 320 out of 320 | elapsed:    8.8s finished

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/" "multif0_incomplete" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
# AimeeNorwich_Flying
#     > using precomputed CQT for AimeeNorwich_Child_MIX.wav
# AlexanderRoss_GoodbyeBolero
# AmarLal_Rest
# AlexanderRoss_VelvetCurtain
# AmarLal_SpringDay1
#     > using precomputed CQT for AmarLal_Rest_MIX.wav
#     > using precomputed CQT for AmarLal_SpringDay1_MIX.wav
# Auctioneer_OurFutureFaces
#     > using precomputed CQT for AClassicEducation_NightOwl_MIX.wav
# AvaLuna_Waterduct
# BigTroubles_Phantom
# BrandonWebster_DontHearAThing
# BrandonWebster_YesSirICanFly
#     > using precomputed CQT for Auctioneer_OurFutureFaces_MIX.wav
# ChrisJacoby_BoothShotLincoln
#     > using precomputed CQT for AlexanderRoss_GoodbyeBolero_MIX.wav
#     > using precomputed CQT for BrandonWebster_YesSirICanFly_MIX.wav
#     > using precomputed CQT for BrandonWebster_DontHearAThing_MIX.wav
# CelestialShore_DieForUs
# ChrisJacoby_PigsFoot
#     > using precomputed CQT for AvaLuna_Waterduct_MIX.wav
# ClaraBerryAndWooldog_AirTraffic
#     > using precomputed CQT for AlexanderRoss_VelvetCurtain_MIX.wav
#     > using precomputed CQT for ChrisJacoby_BoothShotLincoln_MIX.wav
# ClaraBerryAndWooldog_Boys
#     > using precomputed CQT for AimeeNorwich_Flying_MIX.wav
#     > using precomputed CQT for BigTroubles_Phantom_MIX.wav
# ClaraBerryAndWooldog_Stella
# ClaraBerryAndWooldog_TheBadGuys
#     > using precomputed CQT for ClaraBerryAndWooldog_Boys_MIX.wav
#     > using precomputed CQT for ChrisJacoby_PigsFoot_MIX.wav
# ClaraBerryAndWooldog_WaltzForMyVictims
#     > using precomputed CQT for CelestialShore_DieForUs_MIX.wav
#     > using precomputed CQT for ClaraBerryAndWooldog_TheBadGuys_MIX.wav
# Creepoid_OldTree
# CroqueMadame_Oil
# CroqueMadame_Pilot
#     > using precomputed CQT for ClaraBerryAndWooldog_AirTraffic_MIX.wav
#     > using precomputed CQT for ClaraBerryAndWooldog_WaltzForMyVictims_MIX.wav
# Debussy_LenfantProdigue
#     > using precomputed CQT for ClaraBerryAndWooldog_Stella_MIX.wav
#     > using precomputed CQT for CroqueMadame_Pilot_MIX.wav
# DreamersOfTheGhetto_HeavyLove
# EthanHein_1930sSynthAndUprightBass
#     > using precomputed CQT for Debussy_LenfantProdigue_MIX.wav
# EthanHein_BluesForNofi
# EthanHein_GirlOnABridge
#     > using precomputed CQT for EthanHein_GirlOnABridge_MIX.wav
#     > using precomputed CQT for CroqueMadame_Oil_MIX.wav
#     > computing CQT for EthanHein_BluesForNofi_MIX.wav
#     > using precomputed CQT for DreamersOfTheGhetto_HeavyLove_MIX.wav
#     > using precomputed CQT for EthanHein_1930sSynthAndUprightBass_MIX.wav
#     > using precomputed CQT for Creepoid_OldTree_MIX.wav
#     Saved data for EthanHein_BluesForNofi_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# EthanHein_HarmonicaFigure
# FacesOnFilm_WaitingForGa
#     EthanHein_HarmonicaFigure No multif0 data
#     > using precomputed CQT for FacesOnFilm_WaitingForGa_MIX.wav
#     Saved data for BrandonWebster_YesSirICanFly_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# FamilyBand_Again
#     > using precomputed CQT for FamilyBand_Again_MIX.wav
#     Saved data for AmarLal_SpringDay1_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Grants_PunchDrunk
#     > computing CQT for Grants_PunchDrunk_MIX.wav
#     Saved data for EthanHein_GirlOnABridge_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Handel_TornamiAVagheggiar
#     > using precomputed CQT for Handel_TornamiAVagheggiar_MIX.wav
#     Saved data for BigTroubles_Phantom_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# HeladoNegro_MitadDelMundo
#     > using precomputed CQT for HeladoNegro_MitadDelMundo_MIX.wav
#     Saved data for Grants_PunchDrunk_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# HezekiahJones_BorrowedHeart
#     > using precomputed CQT for HezekiahJones_BorrowedHeart_MIX.wav
#     Saved data for ClaraBerryAndWooldog_Boys_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# HopAlong_SisterCities
#     > using precomputed CQT for HopAlong_SisterCities_MIX.wav
#     Saved data for AClassicEducation_NightOwl_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# InvisibleFamiliars_DisturbingWildlife
#     > using precomputed CQT for InvisibleFamiliars_DisturbingWildlife_MIX.wav
#     Saved data for BrandonWebster_DontHearAThing_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# JoelHelander_Definition
#     > using precomputed CQT for JoelHelander_Definition_MIX.wav
#     Saved data for ClaraBerryAndWooldog_AirTraffic_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# JoelHelander_ExcessiveResistancetoChange
#     > using precomputed CQT for JoelHelander_ExcessiveResistancetoChange_MIX.wav
#     Saved data for AmarLal_Rest_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# JoelHelander_IntheAtticBedroom
#     > using precomputed CQT for JoelHelander_IntheAtticBedroom_MIX.wav
#     Saved data for AimeeNorwich_Child_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# KarimDouaidy_Hopscotch
#     > using precomputed CQT for KarimDouaidy_Hopscotch_MIX.wav
#     Saved data for ClaraBerryAndWooldog_WaltzForMyVictims_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# KarimDouaidy_Yatora
#     > using precomputed CQT for KarimDouaidy_Yatora_MIX.wav
#     Saved data for ClaraBerryAndWooldog_Stella_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LizNelson_Coldwar
#     > using precomputed CQT for LizNelson_Coldwar_MIX.wav
#     Saved data for Auctioneer_OurFutureFaces_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LizNelson_ImComingHome
#     > using precomputed CQT for LizNelson_ImComingHome_MIX.wav
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  5.4min
#     Saved data for AimeeNorwich_Flying_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LizNelson_Rainfall
#     > using precomputed CQT for LizNelson_Rainfall_MIX.wav
#     Saved data for Debussy_LenfantProdigue_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Lushlife_ToynbeeSuite
#     > computing CQT for Lushlife_ToynbeeSuite_MIX.wav
#     Saved data for ClaraBerryAndWooldog_TheBadGuys_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MatthewEntwistle_AnEveningWithOliver
#     Saved data for AvaLuna_Waterduct_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MatthewEntwistle_DontYouEver
#     > using precomputed CQT for MatthewEntwistle_DontYouEver_MIX.wav
#     Saved data for ChrisJacoby_BoothShotLincoln_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MatthewEntwistle_FairerHopes
#     > computing CQT for MatthewEntwistle_AnEveningWithOliver_MIX.wav
#     > using precomputed CQT for MatthewEntwistle_FairerHopes_MIX.wav
#     Saved data for FacesOnFilm_WaitingForGa_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MatthewEntwistle_ImpressionsOfSaturn
#     > using precomputed CQT for MatthewEntwistle_ImpressionsOfSaturn_MIX.wav
#     Saved data for CelestialShore_DieForUs_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MatthewEntwistle_Lontano
#     > using precomputed CQT for MatthewEntwistle_Lontano_MIX.wav
#     Saved data for EthanHein_1930sSynthAndUprightBass_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MatthewEntwistle_TheArch
#     > using precomputed CQT for MatthewEntwistle_TheArch_MIX.wav
#     Saved data for FamilyBand_Again_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MatthewEntwistle_TheFlaxenField
#     > using precomputed CQT for MatthewEntwistle_TheFlaxenField_MIX.wav
#     Saved data for DreamersOfTheGhetto_HeavyLove_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Meaxic_TakeAStep
#     > using precomputed CQT for Meaxic_TakeAStep_MIX.wav
#     Saved data for Lushlife_ToynbeeSuite_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for Creepoid_OldTree_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Meaxic_YouListen
# MichaelKropf_AllGoodThings
#     > using precomputed CQT for MichaelKropf_AllGoodThings_MIX.wav
#     > using precomputed CQT for Meaxic_YouListen_MIX.wav
#     Saved data for HeladoNegro_MitadDelMundo_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Mozart_BesterJungling
#     > using precomputed CQT for Mozart_BesterJungling_MIX.wav
#     Saved data for Handel_TornamiAVagheggiar_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Mozart_DiesBildnis
#     > using precomputed CQT for Mozart_DiesBildnis_MIX.wav
#     Saved data for LizNelson_Coldwar_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_80sRock
#     > using precomputed CQT for MusicDelta_80sRock_MIX.wav
#     Saved data for MatthewEntwistle_DontYouEver_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Beatles
#     > using precomputed CQT for MusicDelta_Beatles_MIX.wav
#     Saved data for ChrisJacoby_PigsFoot_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_BebopJazz
#     > using precomputed CQT for MusicDelta_BebopJazz_MIX.wav
#     Saved data for MusicDelta_Beatles_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Beethoven
#     > using precomputed CQT for MusicDelta_Beethoven_MIX.wav
#     Saved data for MusicDelta_Beethoven_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Britpop
#     > using precomputed CQT for MusicDelta_Britpop_MIX.wav
#     Saved data for MusicDelta_Britpop_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_ChineseChaoZhou
#     > using precomputed CQT for MusicDelta_ChineseChaoZhou_MIX.wav
#     Saved data for LizNelson_ImComingHome_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_ChineseDrama
#     > using precomputed CQT for MusicDelta_ChineseDrama_MIX.wav
#     Saved data for HezekiahJones_BorrowedHeart_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_ChineseHenan
#     > using precomputed CQT for MusicDelta_ChineseHenan_MIX.wav
#     Saved data for InvisibleFamiliars_DisturbingWildlife_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_ChineseJiangNan
#     > using precomputed CQT for MusicDelta_ChineseJiangNan_MIX.wav
#     Saved data for MusicDelta_80sRock_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_ChineseXinJing
#     > using precomputed CQT for MusicDelta_ChineseXinJing_MIX.wav
#     Saved data for JoelHelander_IntheAtticBedroom_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_ChineseYaoZu
#     > using precomputed CQT for MusicDelta_ChineseYaoZu_MIX.wav
#     Saved data for JoelHelander_Definition_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_CoolJazz
#     > using precomputed CQT for MusicDelta_CoolJazz_MIX.wav
#     Saved data for KarimDouaidy_Yatora_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Country1
#     > using precomputed CQT for MusicDelta_Country1_MIX.wav
#     Saved data for MatthewEntwistle_AnEveningWithOliver_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Country2
#     > using precomputed CQT for MusicDelta_Country2_MIX.wav
#     Saved data for MusicDelta_Country2_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Disco
#     > using precomputed CQT for MusicDelta_Disco_MIX.wav
#     Saved data for MusicDelta_Disco_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_FreeJazz
#     > using precomputed CQT for MusicDelta_FreeJazz_MIX.wav
#     Saved data for MusicDelta_FreeJazz_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_FunkJazz
#     > using precomputed CQT for MusicDelta_FunkJazz_MIX.wav
#     Saved data for MusicDelta_FunkJazz_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_FusionJazz
#     > using precomputed CQT for MusicDelta_FusionJazz_MIX.wav
#     Saved data for MusicDelta_FusionJazz_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Gospel
#     > using precomputed CQT for MusicDelta_Gospel_MIX.wav
#     Saved data for MusicDelta_Gospel_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_GriegTrolltog
#     > using precomputed CQT for MusicDelta_GriegTrolltog_MIX.wav
#     Saved data for MusicDelta_GriegTrolltog_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Grunge
#     > using precomputed CQT for MusicDelta_Grunge_MIX.wav
#     Saved data for MusicDelta_Grunge_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Hendrix
#     > using precomputed CQT for MusicDelta_Hendrix_MIX.wav
#     Saved data for MusicDelta_Hendrix_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_InTheHalloftheMountainKing
#     > using precomputed CQT for MusicDelta_InTheHalloftheMountainKing_MIX.wav
#     Saved data for MusicDelta_InTheHalloftheMountainKing_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_LatinJazz
#     > using precomputed CQT for MusicDelta_LatinJazz_MIX.wav
#     Saved data for JoelHelander_ExcessiveResistancetoChange_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_ModalJazz
#     > using precomputed CQT for MusicDelta_ModalJazz_MIX.wav
#     Saved data for MusicDelta_LatinJazz_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Pachelbel
#     > using precomputed CQT for MusicDelta_Pachelbel_MIX.wav
#     Saved data for AlexanderRoss_GoodbyeBolero_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Punk
#     > using precomputed CQT for MusicDelta_Punk_MIX.wav
#     Saved data for MusicDelta_ChineseChaoZhou_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Reggae
#     > using precomputed CQT for MusicDelta_Reggae_MIX.wav
#     Saved data for MusicDelta_Reggae_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Rock
#     > using precomputed CQT for MusicDelta_Rock_MIX.wav
#     Saved data for HopAlong_SisterCities_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Rockabilly
#     > using precomputed CQT for MusicDelta_Rockabilly_MIX.wav
#     Saved data for MusicDelta_Rock_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Shadows
#     > using precomputed CQT for MusicDelta_Shadows_MIX.wav
#     Saved data for MusicDelta_Shadows_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_SpeedMetal
#     > using precomputed CQT for MusicDelta_SpeedMetal_MIX.wav
#     Saved data for MusicDelta_SpeedMetal_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_SwingJazz
#     > using precomputed CQT for MusicDelta_SwingJazz_MIX.wav
#     Saved data for MusicDelta_Country1_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Vivaldi
#     > using precomputed CQT for MusicDelta_Vivaldi_MIX.wav
#     Saved data for MusicDelta_Vivaldi_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MusicDelta_Zeppelin
#     > using precomputed CQT for MusicDelta_Zeppelin_MIX.wav
#     Saved data for MusicDelta_Zeppelin_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# NightPanther_Fire
#     > using precomputed CQT for NightPanther_Fire_MIX.wav
#     Saved data for MusicDelta_ChineseHenan_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Phoenix_BrokenPledgeChicagoReel
#     > using precomputed CQT for Phoenix_BrokenPledgeChicagoReel_MIX.wav
#     Saved data for MusicDelta_Rockabilly_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Phoenix_ColliersDaughter
#     > using precomputed CQT for Phoenix_ColliersDaughter_MIX.wav
#     Saved data for MusicDelta_ChineseDrama_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Phoenix_ElzicsFarewell
#     > using precomputed CQT for Phoenix_ElzicsFarewell_MIX.wav
#     Saved data for MusicDelta_ChineseJiangNan_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Phoenix_LarkOnTheStrandDrummondCastle
#     > using precomputed CQT for Phoenix_LarkOnTheStrandDrummondCastle_MIX.wav
#     Saved data for MusicDelta_Punk_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Phoenix_ScotchMorris
#     > using precomputed CQT for Phoenix_ScotchMorris_MIX.wav
#     Saved data for MusicDelta_ChineseXinJing_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Phoenix_SeanCaughlinsTheScartaglen
#     > using precomputed CQT for Phoenix_SeanCaughlinsTheScartaglen_MIX.wav
#     Saved data for MusicDelta_ChineseYaoZu_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# PortStWillow_StayEven
#     > using precomputed CQT for PortStWillow_StayEven_MIX.wav
#     Saved data for CroqueMadame_Oil_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# PurlingHiss_Lolita
#     > using precomputed CQT for PurlingHiss_Lolita_MIX.wav
#     Saved data for MusicDelta_BebopJazz_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Schubert_Erstarrung
#     > using precomputed CQT for Schubert_Erstarrung_MIX.wav
#     Saved data for KarimDouaidy_Hopscotch_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Schumann_Mignon
#     > using precomputed CQT for Schumann_Mignon_MIX.wav
#     Saved data for Mozart_BesterJungling_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# SecretMountains_HighHorse
#     > using precomputed CQT for SecretMountains_HighHorse_MIX.wav
#     Saved data for LizNelson_Rainfall_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Snowmine_Curfews
#     > using precomputed CQT for Snowmine_Curfews_MIX.wav
#     Saved data for MusicDelta_CoolJazz_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# StevenClark_Bounty
#     > using precomputed CQT for StevenClark_Bounty_MIX.wav
#     Saved data for MusicDelta_SwingJazz_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# StrandOfOaks_Spacestation
#     > using precomputed CQT for StrandOfOaks_Spacestation_MIX.wav
#     Saved data for MichaelKropf_AllGoodThings_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# SweetLights_YouLetMeDown
#     > using precomputed CQT for SweetLights_YouLetMeDown_MIX.wav
#     Saved data for MusicDelta_ModalJazz_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TablaBreakbeatScience_Animoog
#     > computing CQT for TablaBreakbeatScience_Animoog_MIX.wav
#     Saved data for AlexanderRoss_VelvetCurtain_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TablaBreakbeatScience_CaptainSky
#     > computing CQT for TablaBreakbeatScience_CaptainSky_MIX.wav
#     Saved data for CroqueMadame_Pilot_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TablaBreakbeatScience_MiloVsMongo
#     TablaBreakbeatScience_MiloVsMongo No multif0 data
# TablaBreakbeatScience_MoodyPlucks
#     TablaBreakbeatScience_MoodyPlucks No multif0 data
# TablaBreakbeatScience_PhaseTransition
#     > computing CQT for TablaBreakbeatScience_PhaseTransition_MIX.wav
#     Saved data for MatthewEntwistle_TheArch_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TablaBreakbeatScience_RockSteady
#     TablaBreakbeatScience_RockSteady No multif0 data
# TablaBreakbeatScience_Scorpio
# TablaBreakbeatScience_Vger
#     TablaBreakbeatScience_Scorpio No multif0 data
#     TablaBreakbeatScience_Vger No multif0 data
# TablaBreakbeatScience_WhoIsIt
#     > computing CQT for TablaBreakbeatScience_WhoIsIt_MIX.wav
#     Saved data for TablaBreakbeatScience_Animoog_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheDistricts_Vermont
#     > using precomputed CQT for TheDistricts_Vermont_MIX.wav
#     Saved data for MatthewEntwistle_FairerHopes_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheScarletBrand_LesFleursDuMal
#     > using precomputed CQT for TheScarletBrand_LesFleursDuMal_MIX.wav
#     Saved data for TablaBreakbeatScience_CaptainSky_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheSoSoGlos_Emergency
#     > using precomputed CQT for TheSoSoGlos_Emergency_MIX.wav
#     Saved data for Meaxic_TakeAStep_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Wolf_DieBekherte
#     > using precomputed CQT for Wolf_DieBekherte_MIX.wav
#     Saved data for Mozart_DiesBildnis_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Allegria_MendelssohnMovement1
#     Allegria_MendelssohnMovement1 No multif0 data
# AmadeusRedux_MozartAllegro
#     AmadeusRedux_MozartAllegro No multif0 data
# AmadeusRedux_SchubertMovement2
#     AmadeusRedux_SchubertMovement2 No multif0 data
# AmadeusRedux_SchubertMovement3
#     AmadeusRedux_SchubertMovement3 No multif0 data
# BarefootSisters_RedJetta
#     BarefootSisters_RedJetta No multif0 data
# CassandraJenkins_PerfectDay
#     > computing CQT for CassandraJenkins_PerfectDay_MIX.wav
#     Saved data for MatthewEntwistle_Lontano_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CatMartino_IPromise
#     > computing CQT for CatMartino_IPromise_MIX.wav
#     Saved data for TablaBreakbeatScience_PhaseTransition_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Cayetana_MissThing
#     > computing CQT for Cayetana_MissThing_MIX.wav
#     Saved data for TablaBreakbeatScience_WhoIsIt_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# DahkaBand_SoldierMan
#     DahkaBand_SoldierMan No multif0 data
# DeadMilkmen_PrisonersCinema
#     > computing CQT for DeadMilkmen_PrisonersCinema_MIX.wav
#     Saved data for Phoenix_BrokenPledgeChicagoReel_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# DeclareAString_MendelssohnPianoTrio1Movement1
#     DeclareAString_MendelssohnPianoTrio1Movement1 No multif0 data
# DeclareAString_MendelssohnPianoTrio1Movement2
#     DeclareAString_MendelssohnPianoTrio1Movement2 No multif0 data
# FallingSparks_Improvisation1
#     FallingSparks_Improvisation1 No multif0 data
# FallingSparks_Improvisation2
#     FallingSparks_Improvisation2 No multif0 data
# FallingSparks_Improvisation3
#     FallingSparks_Improvisation3 No multif0 data
# FallingSparks_PakKlongTalad
#     FallingSparks_PakKlongTalad No multif0 data
# FennelCartwright_DearTessie
#     FennelCartwright_DearTessie No multif0 data
# FennelCartwright_FlowerDrumSong
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed: 19.9min
#     FennelCartwright_FlowerDrumSong No multif0 data
# FennelCartwright_WinterLake
#     FennelCartwright_WinterLake No multif0 data
# FilthyBird_IdLikeToKnow
#     > computing CQT for FilthyBird_IdLikeToKnow_MIX.wav
#     Saved data for CassandraJenkins_PerfectDay_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# FruitCathedral_KeepMeRunnin
#     > computing CQT for FruitCathedral_KeepMeRunnin_MIX.wav
#     Saved data for Phoenix_ColliersDaughter_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# HopsNVinyl_ChickenFriedSteak
#     HopsNVinyl_ChickenFriedSteak No multif0 data
# HopsNVinyl_HoneyBrown
#     HopsNVinyl_HoneyBrown No multif0 data
# HopsNVinyl_ReignCheck
#     HopsNVinyl_ReignCheck No multif0 data
# HopsNVinyl_WidowsWalk
#     HopsNVinyl_WidowsWalk No multif0 data
# Karachacha_Volamos
#     Karachacha_Volamos No multif0 data
# Katzn_CharlieKnox
#     Katzn_CharlieKnox No multif0 data
# LewisAndClarke_TheSilverSea
#     LewisAndClarke_TheSilverSea No multif0 data
# LittleTybee_TheAlchemist
#     > computing CQT for LittleTybee_TheAlchemist_MIX.wav
#     Saved data for Phoenix_ScotchMorris_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MatthewEntwistle_ReturnToVenezia
#     MatthewEntwistle_ReturnToVenezia No multif0 data
# MidnightBlue_HuntingSeason
#     > computing CQT for MidnightBlue_HuntingSeason_MIX.wav
#     Saved data for Phoenix_ElzicsFarewell_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MidnightBlue_StarsAreScreaming
#     > computing CQT for MidnightBlue_StarsAreScreaming_MIX.wav
#     Saved data for Cayetana_MissThing_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MutualBenefit_NotForNothing
#     > computing CQT for MutualBenefit_NotForNothing_MIX.wav
#     Saved data for MatthewEntwistle_ImpressionsOfSaturn_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# PatternIsMovement_SaveMe
#     > computing CQT for PatternIsMovement_SaveMe_MIX.wav
#     Saved data for DeadMilkmen_PrisonersCinema_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#     > computing CQT for PeterMatthewBauer_YouAlwaysLookForSomeoneLost_MIX.wav
#     Saved data for CatMartino_IPromise_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Plasma_GoodShout
#     > computing CQT for Plasma_GoodShout_MIX.wav
#     Saved data for Phoenix_SeanCaughlinsTheScartaglen_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# PoliceHearingDepartment_Brahms
#     PoliceHearingDepartment_Brahms No multif0 data
# PoliceHearingDepartment_SchumannMovement1
#     PoliceHearingDepartment_SchumannMovement1 No multif0 data
# PoliceHearingDepartment_SchumannMovement2
#     PoliceHearingDepartment_SchumannMovement2 No multif0 data
# PoliceHearingDepartment_VivaldiMovement1
#     PoliceHearingDepartment_VivaldiMovement1 No multif0 data
# PoliceHearingDepartment_VivaldiMovement2
#     PoliceHearingDepartment_VivaldiMovement2 No multif0 data
# PoliceHearingDepartment_VivaldiMovement3
#     PoliceHearingDepartment_VivaldiMovement3 No multif0 data
# QuantumChromos_Circuits
#     QuantumChromos_Circuits No multif0 data
# RodrigoBonelli_BalladForLaura
#     RodrigoBonelli_BalladForLaura No multif0 data
# SasquatchConnection_BoomBoxing
#     SasquatchConnection_BoomBoxing No multif0 data
# SasquatchConnection_HolyClamsBatman
#     SasquatchConnection_HolyClamsBatman No multif0 data
# SasquatchConnection_Illuminati
#     SasquatchConnection_Illuminati No multif0 data
# SasquatchConnection_Struttin
#     SasquatchConnection_Struttin No multif0 data
# SasquatchConnection_ThanksALatte
#     SasquatchConnection_ThanksALatte No multif0 data
# SlowGhost_FirstSnow
#     > computing CQT for SlowGhost_FirstSnow_MIX.wav
#     Saved data for MutualBenefit_NotForNothing_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# SlowGhost_MidnightGroove
#     > computing CQT for SlowGhost_MidnightGroove_MIX.wav
#     Saved data for MatthewEntwistle_TheFlaxenField_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# SlowGhost_Peanut
#     > computing CQT for SlowGhost_Peanut_MIX.wav
#     Saved data for NightPanther_Fire_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# SlowGhost_YoureAMystery
#     > computing CQT for SlowGhost_YoureAMystery_MIX.wav
#     Saved data for Phoenix_LarkOnTheStrandDrummondCastle_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for Schubert_Erstarrung_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# SongYiJeon_TwoMoons
# Sweat_AlmostAlways
#     SongYiJeon_TwoMoons No multif0 data
# Sweat_Anecdoche
#     Sweat_AlmostAlways No multif0 data
# Sweat_Elegy
#     Sweat_Anecdoche No multif0 data
# Sweat_Mesozoic
#     Sweat_Elegy No multif0 data
#     Sweat_Mesozoic No multif0 data
# Sweat_Sn1572
#     Sweat_Sn1572 No multif0 data
# Sweat_Tact
#     Sweat_Tact No multif0 data
# TemperedElan_DorothyJeanne
# TemperedElan_WiseOne
#     TemperedElan_WiseOne No multif0 data
#     TemperedElan_DorothyJeanne No multif0 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
#     TheFranckDuo_FranckViolinSonataInAMajorMovement2 No multif0 data
# TheKitchenettes_Alive
#     > computing CQT for TheFranckDuo_FranckViolinSonataInAMajorMovement1_MIX.wav
#     > computing CQT for TheKitchenettes_Alive_MIX.wav
#     Saved data for FilthyBird_IdLikeToKnow_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheNoHoStringOrchestra_ElgarMovement1
#     TheNoHoStringOrchestra_ElgarMovement1 No multif0 data
# TheNoHoStringOrchestra_ElgarMovement2
#     TheNoHoStringOrchestra_ElgarMovement2 No multif0 data
# TheNoHoStringOrchestra_ElgarMovement3
#     TheNoHoStringOrchestra_ElgarMovement3 No multif0 data
# TheTonTons_Lush
#     > computing CQT for TheTonTons_Lush_MIX.wav
#     Saved data for LittleTybee_TheAlchemist_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TleilaxEnsemble_Late
#     TleilaxEnsemble_Late No multif0 data
# TleilaxEnsemble_MelancholyFlowers
#     TleilaxEnsemble_MelancholyFlowers No multif0 data
# Torres_NewSkin
#     > computing CQT for Torres_NewSkin_MIX.wav
#     Saved data for MidnightBlue_HuntingSeason_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TrevorAndTheSoundwaves_AloneAndSad
#     > computing CQT for TrevorAndTheSoundwaves_AloneAndSad_MIX.wav
#     Saved data for MusicDelta_Pachelbel_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Verdi_IlTrovatore
#     Verdi_IlTrovatore No multif0 data
# AHa_TakeOnMe
#     > computing CQT for AHa_TakeOnMe_MIX.wav
#     Saved data for MidnightBlue_StarsAreScreaming_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# AcDc_BackInBlack
#     > computing CQT for AcDc_BackInBlack_MIX.wav
#     Saved data for PurlingHiss_Lolita_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Adele_SomeoneLikeYou
#     > computing CQT for Adele_SomeoneLikeYou_MIX.wav
#     Saved data for PeterMatthewBauer_YouAlwaysLookForSomeoneLost_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Aerosmith_LoveInAnElevator
#     > computing CQT for Aerosmith_LoveInAnElevator_MIX.wav
#     Saved data for TheSoSoGlos_Emergency_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# AlanisMorissette_YouOughtaKnow
#     > computing CQT for AlanisMorissette_YouOughtaKnow_MIX.wav
#     Saved data for StrandOfOaks_Spacestation_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# AllThatRemains_Chiron
#     > computing CQT for AllThatRemains_Chiron_MIX.wav
#     Saved data for Schumann_Mignon_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# AnEndlessSporadic_Anything
#     > computing CQT for AnEndlessSporadic_Anything_MIX.wav
#     Saved data for Wolf_DieBekherte_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Anberlin_TheFeelGoodDrag
#     > computing CQT for Anberlin_TheFeelGoodDrag_MIX.wav
#     Saved data for Snowmine_Curfews_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# ArcadeFire_BlackMirror
#     Saved data for Meaxic_YouListen_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# ArcticMonkeys_Brainstorm
#     > computing CQT for ArcticMonkeys_Brainstorm_MIX.wav
#     > computing CQT for ArcadeFire_BlackMirror_MIX.wav
#     Saved data for PortStWillow_StayEven_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BillyIdol_WhiteWedding
#     > computing CQT for BillyIdol_WhiteWedding_MIX.wav
#     Saved data for TheDistricts_Vermont_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BillySquier_TheStroke
#     > computing CQT for BillySquier_TheStroke_MIX.wav
#     Saved data for StevenClark_Bounty_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BlackEyedPeas_IGottaFeeling
#     > computing CQT for BlackEyedPeas_IGottaFeeling_MIX.wav
#     Saved data for FruitCathedral_KeepMeRunnin_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BlackSabbath_WarPigs
#     > computing CQT for BlackSabbath_WarPigs_MIX.wav
#     Saved data for TheScarletBrand_LesFleursDuMal_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Blink182_AllTheSmallThings
#     > computing CQT for Blink182_AllTheSmallThings_MIX.wav
#     Saved data for SecretMountains_HighHorse_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Blondie_OneWayOrAnother
#     > computing CQT for Blondie_OneWayOrAnother_MIX.wav
#     Saved data for SweetLights_YouLetMeDown_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BlueOysterCult_DontFearTheReaper
#     > computing CQT for BlueOysterCult_DontFearTheReaper_MIX.wav
#     Saved data for PatternIsMovement_SaveMe_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BobSeger_OldTimeRockAndRoll
#     > computing CQT for BobSeger_OldTimeRockAndRoll_MIX.wav
#     Saved data for AHa_TakeOnMe_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Boston_MoreThanAFeeling
#     > computing CQT for Boston_MoreThanAFeeling_MIX.wav
#     Saved data for SlowGhost_MidnightGroove_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BradPaisley_MudOnTheTires
#     > computing CQT for BradPaisley_MudOnTheTires_MIX.wav
#     Saved data for TheKitchenettes_Alive_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BrooksDunn_HillbillyDeluxe
#     > computing CQT for BrooksDunn_HillbillyDeluxe_MIX.wav
#     Saved data for ArcadeFire_BlackMirror_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BrunoMars_Grenade
#     > computing CQT for BrunoMars_Grenade_MIX.wav
#     Saved data for Boston_MoreThanAFeeling_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BrunoMars_JustTheWayYouAre
#     > computing CQT for BrunoMars_JustTheWayYouAre_MIX.wav
#     Saved data for TheTonTons_Lush_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BrunoMars_MarryYou
#     > computing CQT for BrunoMars_MarryYou_MIX.wav
#     Saved data for AcDc_BackInBlack_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# BryanAdams_SummerOf69
#     > computing CQT for BryanAdams_SummerOf69_MIX.wav
#     Saved data for Plasma_GoodShout_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bush_Machinehead
#     > computing CQT for Bush_Machinehead_MIX.wav
#     Saved data for BillyIdol_WhiteWedding_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CarlDouglas_KungFuFighting
#     > computing CQT for CarlDouglas_KungFuFighting_MIX.wav
#     Saved data for SlowGhost_YoureAMystery_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CarrieUnderwood_HomeSweetHome
#     > computing CQT for CarrieUnderwood_HomeSweetHome_MIX.wav
#     Saved data for BrunoMars_JustTheWayYouAre_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CeeloGreen_ForgetYou
#     > computing CQT for CeeloGreen_ForgetYou_MIX.wav
#     Saved data for ArcticMonkeys_Brainstorm_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CheapTrick_IWantYouToWantMe
#     > computing CQT for CheapTrick_IWantYouToWantMe_MIX.wav
#     Saved data for BlackEyedPeas_IGottaFeeling_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CherryPoppinDaddies_ZootSuitRiot
#     > computing CQT for CherryPoppinDaddies_ZootSuitRiot_MIX.wav
#     Saved data for BrunoMars_Grenade_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# ChrisBrown_Yeah
#     > computing CQT for ChrisBrown_Yeah_MIX.wav
#     Saved data for TheFranckDuo_FranckViolinSonataInAMajorMovement1_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# ChristinaAguilera_GenieInABottle
#     > computing CQT for ChristinaAguilera_GenieInABottle_MIX.wav
#     Saved data for BradPaisley_MudOnTheTires_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Chromeo_Tenderoni
#     > computing CQT for Chromeo_Tenderoni_MIX.wav
#     Saved data for CeeloGreen_ForgetYou_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Chumbawamba_Tubthumping
#     Chumbawamba_Tubthumping No multif0 data
# ColdWarKids_HangMeUpToDry
#     > computing CQT for ColdWarKids_HangMeUpToDry_MIX.wav
#     Saved data for TrevorAndTheSoundwaves_AloneAndSad_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Coldplay_InMyPlace
#     > computing CQT for Coldplay_InMyPlace_MIX.wav
#     Saved data for Blink182_AllTheSmallThings_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Coldplay_Shiver
#     > computing CQT for Coldplay_Shiver_MIX.wav
#     Saved data for BillySquier_TheStroke_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CorinneBaileyRae_PutYourRecordsOn
#     > computing CQT for CorinneBaileyRae_PutYourRecordsOn_MIX.wav
#     Saved data for SlowGhost_FirstSnow_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CountZero_Shake
#     > computing CQT for CountZero_Shake_MIX.wav
#     Saved data for Anberlin_TheFeelGoodDrag_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CountingCrows_AccidentallyInLove
#     > computing CQT for CountingCrows_AccidentallyInLove_MIX.wav
#     Saved data for BrooksDunn_HillbillyDeluxe_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# CrazyFrog_JingleBells
#     CrazyFrog_JingleBells No multif0 data
# FleetwoodMac_Rhiannon
#     > computing CQT for FleetwoodMac_Rhiannon_MIX.wav
#     Saved data for BobSeger_OldTimeRockAndRoll_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# FlightOfTheConcords_BusinessTime
#     > computing CQT for FlightOfTheConcords_BusinessTime_MIX.wav
#     Saved data for CheapTrick_IWantYouToWantMe_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# FooFighters_AllMyLife
#     > computing CQT for FooFighters_AllMyLife_MIX.wav
#     Saved data for BryanAdams_SummerOf69_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Incubus_Drive
#     > computing CQT for Incubus_Drive_MIX.wav
#     Saved data for Blondie_OneWayOrAnother_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Inxs_NeedYouTonight
#     > computing CQT for Inxs_NeedYouTonight_MIX.wav
#     Saved data for ColdWarKids_HangMeUpToDry_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# KaiserChiefs_Ruby
#     > computing CQT for KaiserChiefs_Ruby_MIX.wav
#     Saved data for AllThatRemains_Chiron_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Kansas_CarryOnMyWaywardSon
#     > computing CQT for Kansas_CarryOnMyWaywardSon_MIX.wav
#     Saved data for CarlDouglas_KungFuFighting_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# KanyeWest_LoveLockdown
#     > computing CQT for KanyeWest_LoveLockdown_MIX.wav
#     Saved data for Torres_NewSkin_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# KeithUrban_IToldYouSo
#     > computing CQT for KeithUrban_IToldYouSo_MIX.wav
#     Saved data for CherryPoppinDaddies_ZootSuitRiot_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# KennyChesney_SheThinksMyTractorsSexy
#     > computing CQT for KennyChesney_SheThinksMyTractorsSexy_MIX.wav
#     Saved data for AlanisMorissette_YouOughtaKnow_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# KingsOfLeon_SexOnFire
#     KingsOfLeon_SexOnFire No multif0 data
# Kiss_RockAndRollAllNite
#     > computing CQT for Kiss_RockAndRollAllNite_MIX.wav
#     Saved data for BlackSabbath_WarPigs_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Knack_MySharona
#     > computing CQT for Knack_MySharona_MIX.wav
#     Saved data for ChrisBrown_Yeah_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Korn_FreakOnALeash
#     > computing CQT for Korn_FreakOnALeash_MIX.wav
#     Saved data for Chromeo_Tenderoni_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# KtTunstall_BlackHorseAndTheCherryTree
#     > computing CQT for KtTunstall_BlackHorseAndTheCherryTree_MIX.wav
#     Saved data for Adele_SomeoneLikeYou_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# KtTunstall_SuddenlyISee
#     > computing CQT for KtTunstall_SuddenlyISee_MIX.wav
#     Saved data for KaiserChiefs_Ruby_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LaRoux_Bulletproof
#     > computing CQT for LaRoux_Bulletproof_MIX.wav
#     Saved data for Inxs_NeedYouTonight_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LadyGagaFeaturingBeyonce_Telephone
#     > computing CQT for LadyGagaFeaturingBeyonce_Telephone_MIX.wav
#     Saved data for SlowGhost_Peanut_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LadyGaga_BadRomance
#     > computing CQT for LadyGaga_BadRomance_MIX.wav
#     Saved data for FooFighters_AllMyLife_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LadyGaga_BornThisWay
#     > computing CQT for LadyGaga_BornThisWay_MIX.wav
#     Saved data for BrunoMars_MarryYou_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LambOfGod_Requiem
#     > computing CQT for LambOfGod_Requiem_MIX.wav
#     Saved data for Coldplay_InMyPlace_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LennyKravitz_AreYouGonnaGoMyWay
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed: 130.0min
#     > computing CQT for LennyKravitz_AreYouGonnaGoMyWay_MIX.wav
#     Saved data for FleetwoodMac_Rhiannon_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LilyAllen_NotFair
#     > computing CQT for LilyAllen_NotFair_MIX.wav
#     Saved data for KtTunstall_BlackHorseAndTheCherryTree_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LinkinPark_InTheEnd
#     > computing CQT for LinkinPark_InTheEnd_MIX.wav
#     Saved data for BlueOysterCult_DontFearTheReaper_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Lit_MyOwnWorstEnemy
#     > computing CQT for Lit_MyOwnWorstEnemy_MIX.wav
#     Saved data for Bush_Machinehead_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Live_IAlone
#     > computing CQT for Live_IAlone_MIX.wav
#     Saved data for AnEndlessSporadic_Anything_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LoquilloYLosTrogloditas_CadillacSolitario
#     LoquilloYLosTrogloditas_CadillacSolitario No multif0 data
# LosLobos_LaBamba
#     > computing CQT for LosLobos_LaBamba_MIX.wav
#     Saved data for ChristinaAguilera_GenieInABottle_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# LynyrdSkynyrd_FreeBird
#     > computing CQT for LynyrdSkynyrd_FreeBird_MIX.wav
#     Saved data for CarrieUnderwood_HomeSweetHome_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Maroon5_ThisLove
#     > computing CQT for Maroon5_ThisLove_MIX.wav
#     Saved data for KennyChesney_SheThinksMyTractorsSexy_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MartinaMcbride_ThisOnesForTheGirls
#     > computing CQT for MartinaMcbride_ThisOnesForTheGirls_MIX.wav
#     Saved data for LaRoux_Bulletproof_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MarvinGaye_IHeardItThroughTheGrapevine
#     > computing CQT for MarvinGaye_IHeardItThroughTheGrapevine_MIX.wav
#     Saved data for Knack_MySharona_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MarvinGaye_WhatsGoingOn
#     > computing CQT for MarvinGaye_WhatsGoingOn_MIX.wav
#     Saved data for Aerosmith_LoveInAnElevator_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
#     > computing CQT for McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe_MIX.wav
#     Saved data for LadyGagaFeaturingBeyonce_Telephone_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MichaelJackson_BeatIt
#     > computing CQT for MichaelJackson_BeatIt_MIX.wav
#     Saved data for CountingCrows_AccidentallyInLove_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MightyMightyBosstones_WheredYouGo
#     > computing CQT for MightyMightyBosstones_WheredYouGo_MIX.wav
#     Saved data for FlightOfTheConcords_BusinessTime_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MikeOldfield_Quicksilver
#     MikeOldfield_Quicksilver No multif0 data
# MileyCyrus_7Things
#     > computing CQT for MileyCyrus_7Things_MIX.wav
#     Saved data for CorinneBaileyRae_PutYourRecordsOn_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# MirandaCosgrove_HeadphonesOn
#     > computing CQT for MirandaCosgrove_HeadphonesOn_MIX.wav
#     Saved data for LilyAllen_NotFair_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Misfits_AstroZombies
#     > computing CQT for Misfits_AstroZombies_MIX.wav
#     Saved data for CountZero_Shake_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# ModestMouse_FloatOn
#     > computing CQT for ModestMouse_FloatOn_MIX.wav
#     Saved data for LambOfGod_Requiem_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Muffs_KidsInAmerica
#     > computing CQT for Muffs_KidsInAmerica_MIX.wav
#     Saved data for KtTunstall_SuddenlyISee_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Muse_Hysteria
#     > computing CQT for Muse_Hysteria_MIX.wav
#     Saved data for LennyKravitz_AreYouGonnaGoMyWay_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TPain_Bartender
#     > computing CQT for TPain_Bartender_MIX.wav
#     Saved data for Incubus_Drive_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TalkingHeads_PsychoKiller
#     > computing CQT for TalkingHeads_PsychoKiller_MIX.wav
#     Saved data for LinkinPark_InTheEnd_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TaylorSwift_LoveStory
#     > computing CQT for TaylorSwift_LoveStory_MIX.wav
#     Saved data for LadyGaga_BornThisWay_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TaylorSwift_YouBelongWithMe
#     > computing CQT for TaylorSwift_YouBelongWithMe_MIX.wav
#     Saved data for LosLobos_LaBamba_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TearsForFears_EverybodyWantsToRuleTheWorld
#     > computing CQT for TearsForFears_EverybodyWantsToRuleTheWorld_MIX.wav
#     Saved data for Coldplay_Shiver_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Tesla_ModernDayCowboy
#     > computing CQT for Tesla_ModernDayCowboy_MIX.wav
#     Saved data for MarvinGaye_IHeardItThroughTheGrapevine_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheAllAmericanRejects_DirtyLittleSecret
#     > computing CQT for TheAllAmericanRejects_DirtyLittleSecret_MIX.wav
#     Saved data for Kiss_RockAndRollAllNite_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheAllmanBrothersBand_RamblinMan
#     > computing CQT for TheAllmanBrothersBand_RamblinMan_MIX.wav
#     Saved data for Korn_FreakOnALeash_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheBeatles_TwistAndShout
#     TheBeatles_TwistAndShout No multif0 data
# TheBeatles_Wait
#     TheBeatles_Wait No multif0 data
# TheBeatles_WhatGoesOn
#     TheBeatles_WhatGoesOn No multif0 data
# TheBeatles_WhenIm64
#     TheBeatles_WhenIm64 No multif0 data
# TheBeatles_WhileMyGuitarGentlyWeeps
#     TheBeatles_WhileMyGuitarGentlyWeeps No multif0 data
# TheBeatles_WithALittleHelpFromMyFriends
#     TheBeatles_WithALittleHelpFromMyFriends No multif0 data
# TheBeatles_WithinYouWithoutYou
#     TheBeatles_WithinYouWithoutYou No multif0 data
# TheBeatles_YellowSubmarine
#     TheBeatles_YellowSubmarine No multif0 data
# TheBeatles_YouWontSeeMe
#     TheBeatles_YouWontSeeMe No multif0 data
# TheBlackKeys_YourTouch
#     TheBlackKeys_YourTouch No multif0 data
# TheBravery_Believe
#     TheBravery_Believe No multif0 data
# TheBronx_FalseAlarm
#     > computing CQT for TheBronx_FalseAlarm_MIX.wav
#     Saved data for KeithUrban_IToldYouSo_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheBronx_SixDaysAWeek
#     > computing CQT for TheBronx_SixDaysAWeek_MIX.wav
#     Saved data for MartinaMcbride_ThisOnesForTheGirls_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheKillers_SomebodyToldMe
#     > computing CQT for TheKillers_SomebodyToldMe_MIX.wav
#     Saved data for Lit_MyOwnWorstEnemy_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheKooks_Naive
#     > computing CQT for TheKooks_Naive_MIX.wav
#     Saved data for Maroon5_ThisLove_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheLastGoodnight_PicturesOfYou
#     > computing CQT for TheLastGoodnight_PicturesOfYou_MIX.wav
#     Saved data for Misfits_AstroZombies_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TheTurtles_HappyTogether
#     > computing CQT for TheTurtles_HappyTogether_MIX.wav
#     Saved data for Kansas_CarryOnMyWaywardSon_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# ThinLizzy_TheBoysAreBackInTown
#     > computing CQT for ThinLizzy_TheBoysAreBackInTown_MIX.wav
#     Saved data for KanyeWest_LoveLockdown_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# ThirdEyeBlind_Jumper
#     > computing CQT for ThirdEyeBlind_Jumper_MIX.wav
#     Saved data for MichaelJackson_BeatIt_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# ThirdEyeBlind_NeverLetYouGo
#     > computing CQT for ThirdEyeBlind_NeverLetYouGo_MIX.wav
#     Saved data for TheBronx_FalseAlarm_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TomPettyAndTheHeartbreakers_IWontBackDown
#     > computing CQT for TomPettyAndTheHeartbreakers_IWontBackDown_MIX.wav
#     Saved data for LadyGaga_BadRomance_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TomPetty_FreeFallin
#     > computing CQT for TomPetty_FreeFallin_MIX.wav
#     Saved data for TheLastGoodnight_PicturesOfYou_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Tonic_IfYouCouldOnlySee
#     > computing CQT for Tonic_IfYouCouldOnlySee_MIX.wav
#     Saved data for ModestMouse_FloatOn_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# TvOnTheRadio_WolfLikeMe
#     TvOnTheRadio_WolfLikeMe No multif0 data
# VampireWeekend_Cousins
#     > computing CQT for VampireWeekend_Cousins_MIX.wav
#     Saved data for TheKooks_Naive_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# VampireWeekend_Holiday
#     > computing CQT for VampireWeekend_Holiday_MIX.wav
#     Saved data for ThirdEyeBlind_Jumper_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# VanHalen_Jump
#     VanHalen_Jump No multif0 data
# VanillaIce_IceIceBaby
#     > computing CQT for VanillaIce_IceIceBaby_MIX.wav
#     Saved data for Muse_Hysteria_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# VillagePeople_Ymca
#     > computing CQT for VillagePeople_Ymca_MIX.wav
#     Saved data for MileyCyrus_7Things_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Weezer_IslandInTheSun
#     Weezer_IslandInTheSun No multif0 data
# WildCherry_PlayThatFunkyMusic
#     WildCherry_PlayThatFunkyMusic No multif0 data
#     Saved data for MirandaCosgrove_HeadphonesOn_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TPain_Bartender_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for VampireWeekend_Holiday_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TheKillers_SomebodyToldMe_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for VampireWeekend_Cousins_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for Live_IAlone_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for MarvinGaye_WhatsGoingOn_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TomPettyAndTheHeartbreakers_IWontBackDown_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for Muffs_KidsInAmerica_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TheTurtles_HappyTogether_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TheBronx_SixDaysAWeek_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for MightyMightyBosstones_WheredYouGo_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TaylorSwift_YouBelongWithMe_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for ThirdEyeBlind_NeverLetYouGo_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TheAllAmericanRejects_DirtyLittleSecret_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TaylorSwift_LoveStory_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for Tesla_ModernDayCowboy_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for VanillaIce_IceIceBaby_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TomPetty_FreeFallin_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for Tonic_IfYouCouldOnlySee_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TalkingHeads_PsychoKiller_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for VillagePeople_Ymca_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TearsForFears_EverybodyWantsToRuleTheWorld_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for ThinLizzy_TheBoysAreBackInTown_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for LynyrdSkynyrd_FreeBird_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
#     Saved data for TheAllmanBrothersBand_RamblinMan_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# [Parallel(n_jobs=-1)]: Done 320 out of 320 | elapsed: 169.8min finished
# Done!

# %%
data_dir = ("/scratch/rmb456/multif0_ismir2017/" +
    "training_data_with_blur/multif0_complete")

# %%
import medleydb as mdb
import glob
import shutil
import os

# %%
mtracks = list(mtracks)

# %%
new_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/bad_extras"

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['EXTRA'])
good_count = 0
bad_count = 0

for mtrack in mtracks:
    bad_mtrack = False
    for stem in mtrack.stems.values():
        if stem.pitch_estimate_pyin is not None:

            if 'p' in stem.f0_type:
                bad_mtrack = True
                print(stem.instrument)
    if bad_mtrack:
        bad_count += 1
        print mtrack.track_id
    else:
        good_count += 1
        
        
    if bad_mtrack:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                bname = os.path.basename(f)
                os.rename(f, os.path.join(new_dir, bname))

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['V1'])
for mtrack in mtracks:
    if mtrack.has_melody:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                print(f)
                os.remove(f)

# %%
rm /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/*/TrevorAndTheSoundwaves_AloneAndSad_multif0_complete*.npy

# %%
x = 5
print(x)
