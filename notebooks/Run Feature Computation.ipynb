# %% [markdown]
# Notebook used to compute input HCQTs and targets for every track for different task types
#
# In each cell we manually run a script with the given parameters

# %%
cd ../deepsalience
# Out:
# /scratch/rmb456/multif0/deepsalience

# %%
# import medleydb as mdb
# import numpy as np
# import os


# mel1_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/"
# mel2_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/"
# mel3_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/"
# mf0_incomplete = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/"
# mf0_complete = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/"

# mtracks = mdb.load_all_multitracks(
#     dataset_version=['V1', 'V2', 'EXTRA']
# )

# for mtrack in mtracks:
# #     print(mtrack.track_id)
#     fpath = os.path.join(mel1_dir, 'inputs', '{}_mel1_input.npy'.format(mtrack.track_id))
#     if not os.path.exists(fpath):
# #         print("   > no npy file")
#         continue

#     data = np.load(fpath, mmap_mode='r')

#     if data.shape[0] != 6:
#         print(mtrack.track_id)
#         print("   > {}".format(data.shape))
#         os.remove(fpath)
#         os.remove(os.path.join(mel2_dir, 'inputs', '{}_mel2_input.npy'.format(mtrack.track_id)))
#         os.remove(os.path.join(mel3_dir, 'inputs', '{}_mel3_input.npy'.format(mtrack.track_id)))
#         os.remove(os.path.join(mf0_incomplete, 'inputs', '{}_multif0_incomplete_input.npy'.format(mtrack.track_id)))

# %%
# %run compute_training_data.py --help
# Out:
# usage: compute_training_data.py [-h] [--use-mdb2] [--blur-labels]
#                                 save_dir option n_jobs precomputed_hcqt_path
#
# Generate feature files for multif0 learning.
#
# positional arguments:
#   save_dir              Path to save npy files.
#   option                Type of data to compute. One of 'solo_pitch'
#                         'melody1', 'melody2', 'melody3' 'multif0_incomplete',
#                         'multif0_complete'.
#   n_jobs                Number of jobs to run in parallel.
#   precomputed_hcqt_path
#                         Path to folder with hcqts precomputed
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --use-mdb2
#   --blur-labels

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/" "solo_pitch" -1 "" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
#     > computing CQT for AimeeNorwich_Child_STEM_04.wav
#     > computing CQT for AClassicEducation_NightOwl_STEM_04.wav
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
#     > computing CQT for AimeeNorwich_Flying_STEM_04.wav
#     > computing CQT for AlexanderRoss_GoodbyeBolero_STEM_03.wav
# AlexanderRoss_VelvetCurtain
# AmarLal_Rest
#     > computing CQT for AlexanderRoss_VelvetCurtain_STEM_01.wav
# AmarLal_SpringDay1
#     > computing CQT for AmarLal_Rest_STEM_01.wav
#     > computing CQT for AmarLal_SpringDay1_STEM_01.wav
# Auctioneer_OurFutureFaces
# AvaLuna_Waterduct
#     > computing CQT for Auctioneer_OurFutureFaces_STEM_06.wav
#     > computing CQT for AvaLuna_Waterduct_STEM_08.wav
# BigTroubles_Phantom
# BrandonWebster_DontHearAThing
#     > computing CQT for BigTroubles_Phantom_STEM_04.wav
# BrandonWebster_YesSirICanFly
#     > computing CQT for BrandonWebster_DontHearAThing_STEM_02.wav
# CelestialShore_DieForUs
# ChrisJacoby_BoothShotLincoln
#     > computing CQT for BrandonWebster_YesSirICanFly_STEM_02.wav
# ChrisJacoby_PigsFoot
#     > computing CQT for CelestialShore_DieForUs_STEM_01.wav
# ClaraBerryAndWooldog_AirTraffic
#     > computing CQT for ClaraBerryAndWooldog_AirTraffic_STEM_04.wav
#     > computing CQT for ChrisJacoby_BoothShotLincoln_STEM_02.wav
#     > computing CQT for ChrisJacoby_PigsFoot_STEM_02.wav
# ClaraBerryAndWooldog_Boys
# ClaraBerryAndWooldog_Stella
#     > computing CQT for ClaraBerryAndWooldog_Boys_STEM_05.wav
# ClaraBerryAndWooldog_WaltzForMyVictims
# ClaraBerryAndWooldog_TheBadGuys
#     > computing CQT for ClaraBerryAndWooldog_Stella_STEM_07.wav
#     > computing CQT for ClaraBerryAndWooldog_WaltzForMyVictims_STEM_03.wav
#     > computing CQT for ClaraBerryAndWooldog_TheBadGuys_STEM_02.wav
#     Saved data for BrandonWebster_YesSirICanFly_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# Creepoid_OldTree
#     > computing CQT for Creepoid_OldTree_STEM_01.wav
#     Saved data for BigTroubles_Phantom_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for BigTroubles_Phantom_STEM_05.wav
#     Saved data for AmarLal_Rest_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# CroqueMadame_Oil
#     > computing CQT for CroqueMadame_Oil_STEM_01.wav
#     Saved data for ClaraBerryAndWooldog_Boys_STEM_5 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for ClaraBerryAndWooldog_Boys_STEM_06.wav
#     Saved data for AmarLal_SpringDay1_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# CroqueMadame_Pilot
#     > computing CQT for CroqueMadame_Pilot_STEM_01.wav
#     Saved data for AClassicEducation_NightOwl_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for AClassicEducation_NightOwl_STEM_08.wav
#     Saved data for ClaraBerryAndWooldog_AirTraffic_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for ClaraBerryAndWooldog_AirTraffic_STEM_08.wav
#     Saved data for Auctioneer_OurFutureFaces_STEM_6 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Auctioneer_OurFutureFaces_STEM_08.wav
#     Saved data for BrandonWebster_DontHearAThing_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# Debussy_LenfantProdigue
#     > computing CQT for Debussy_LenfantProdigue_STEM_01.wav
#     Saved data for AimeeNorwich_Flying_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for AimeeNorwich_Flying_STEM_05.wav
#     Saved data for ClaraBerryAndWooldog_WaltzForMyVictims_STEM_3 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for ClaraBerryAndWooldog_WaltzForMyVictims_STEM_04.wav
#     Saved data for AimeeNorwich_Child_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# DreamersOfTheGhetto_HeavyLove
#     > computing CQT for DreamersOfTheGhetto_HeavyLove_STEM_06.wav
#     Saved data for ClaraBerryAndWooldog_Stella_STEM_7 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# EthanHein_1930sSynthAndUprightBass
#     > computing CQT for EthanHein_1930sSynthAndUprightBass_STEM_04.wav
#     Saved data for CelestialShore_DieForUs_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for CelestialShore_DieForUs_STEM_02.wav
#     Saved data for ClaraBerryAndWooldog_TheBadGuys_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# EthanHein_BluesForNofi
# EthanHein_GirlOnABridge
#     > computing CQT for EthanHein_GirlOnABridge_STEM_05.wav
#     Saved data for AvaLuna_Waterduct_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# EthanHein_HarmonicaFigure
# FacesOnFilm_WaitingForGa
#     > computing CQT for FacesOnFilm_WaitingForGa_STEM_03.wav
#     Saved data for ChrisJacoby_BoothShotLincoln_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# FamilyBand_Again
#     > computing CQT for FamilyBand_Again_STEM_09.wav
#     Saved data for BigTroubles_Phantom_STEM_5 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# Grants_PunchDrunk
# Handel_TornamiAVagheggiar
#     > computing CQT for Handel_TornamiAVagheggiar_STEM_01.wav
#     Saved data for ClaraBerryAndWooldog_Boys_STEM_6 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for ClaraBerryAndWooldog_Boys_STEM_08.wav
#     Saved data for AClassicEducation_NightOwl_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for AClassicEducation_NightOwl_STEM_13.wav
#     Saved data for ClaraBerryAndWooldog_AirTraffic_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# HeladoNegro_MitadDelMundo
#     > computing CQT for HeladoNegro_MitadDelMundo_STEM_08.wav
#     Saved data for Creepoid_OldTree_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Creepoid_OldTree_STEM_06.wav
#     Saved data for ClaraBerryAndWooldog_WaltzForMyVictims_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05.wav
#     Saved data for Auctioneer_OurFutureFaces_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# HezekiahJones_BorrowedHeart
#     > computing CQT for HezekiahJones_BorrowedHeart_STEM_02.wav
#     Saved data for ChrisJacoby_PigsFoot_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# HopAlong_SisterCities
#     > computing CQT for HopAlong_SisterCities_STEM_06.wav
#     Saved data for AimeeNorwich_Flying_STEM_5 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for AimeeNorwich_Flying_STEM_15.wav
#     Saved data for EthanHein_GirlOnABridge_STEM_5 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# InvisibleFamiliars_DisturbingWildlife
#     > computing CQT for InvisibleFamiliars_DisturbingWildlife_STEM_03.wav
#     Saved data for Debussy_LenfantProdigue_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Debussy_LenfantProdigue_STEM_02.wav
#     Saved data for AlexanderRoss_GoodbyeBolero_STEM_3 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for AlexanderRoss_GoodbyeBolero_STEM_06.wav
#     Saved data for ClaraBerryAndWooldog_Boys_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# JoelHelander_Definition
#     > computing CQT for JoelHelander_Definition_STEM_01.wav
#     Saved data for FamilyBand_Again_STEM_9 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# JoelHelander_ExcessiveResistancetoChange
#     > computing CQT for JoelHelander_ExcessiveResistancetoChange_STEM_01.wav
#     Saved data for DreamersOfTheGhetto_HeavyLove_STEM_6 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# JoelHelander_IntheAtticBedroom
#     > computing CQT for JoelHelander_IntheAtticBedroom_STEM_01.wav
#     Saved data for AClassicEducation_NightOwl_STEM_13 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# KarimDouaidy_Hopscotch
#     > computing CQT for KarimDouaidy_Hopscotch_STEM_07.wav
#     Saved data for Handel_TornamiAVagheggiar_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Handel_TornamiAVagheggiar_STEM_02.wav
#     Saved data for FacesOnFilm_WaitingForGa_STEM_3 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for FacesOnFilm_WaitingForGa_STEM_10.wav
#     Saved data for ClaraBerryAndWooldog_WaltzForMyVictims_STEM_5 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# KarimDouaidy_Yatora
#     > computing CQT for KarimDouaidy_Yatora_STEM_02.wav
#     Saved data for EthanHein_1930sSynthAndUprightBass_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# LizNelson_Coldwar
#     > computing CQT for LizNelson_Coldwar_STEM_01.wav
#     Saved data for HeladoNegro_MitadDelMundo_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# LizNelson_ImComingHome
#     > computing CQT for LizNelson_ImComingHome_STEM_01.wav
#     Saved data for AlexanderRoss_VelvetCurtain_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for AlexanderRoss_VelvetCurtain_STEM_06.wav
#     Saved data for CelestialShore_DieForUs_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for CelestialShore_DieForUs_STEM_07.wav
#     Saved data for AimeeNorwich_Flying_STEM_15 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# LizNelson_Rainfall
#     > computing CQT for LizNelson_Rainfall_STEM_01.wav
#     Saved data for CroqueMadame_Oil_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for CroqueMadame_Oil_STEM_02.wav
#     Saved data for InvisibleFamiliars_DisturbingWildlife_STEM_3 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for InvisibleFamiliars_DisturbingWildlife_STEM_08.wav
#     Saved data for Debussy_LenfantProdigue_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# Lushlife_ToynbeeSuite
#     > computing CQT for Lushlife_ToynbeeSuite_STEM_04.wav
#     Saved data for HezekiahJones_BorrowedHeart_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for HezekiahJones_BorrowedHeart_STEM_10.wav
#     Saved data for Creepoid_OldTree_STEM_6 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Creepoid_OldTree_STEM_07.wav
#     Saved data for CroqueMadame_Pilot_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for CroqueMadame_Pilot_STEM_02.wav
#     Saved data for HopAlong_SisterCities_STEM_6 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for HopAlong_SisterCities_STEM_07.wav
#     Saved data for JoelHelander_Definition_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for JoelHelander_Definition_STEM_02.wav
#     Saved data for LizNelson_Coldwar_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for LizNelson_Coldwar_STEM_02.wav
#     Saved data for LizNelson_ImComingHome_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for LizNelson_ImComingHome_STEM_04.wav
#     Saved data for KarimDouaidy_Yatora_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for KarimDouaidy_Yatora_STEM_03.wav
#     Saved data for JoelHelander_IntheAtticBedroom_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MatthewEntwistle_AnEveningWithOliver
# MatthewEntwistle_DontYouEver
#     > computing CQT for MatthewEntwistle_DontYouEver_STEM_02.wav
#     Saved data for JoelHelander_ExcessiveResistancetoChange_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for JoelHelander_ExcessiveResistancetoChange_STEM_03.wav
#     Saved data for Handel_TornamiAVagheggiar_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MatthewEntwistle_FairerHopes
#     > computing CQT for MatthewEntwistle_FairerHopes_STEM_10.wav
#     Saved data for FacesOnFilm_WaitingForGa_STEM_10 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MatthewEntwistle_ImpressionsOfSaturn
#     > computing CQT for MatthewEntwistle_ImpressionsOfSaturn_STEM_01.wav
#     Saved data for KarimDouaidy_Hopscotch_STEM_7 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for KarimDouaidy_Hopscotch_STEM_09.wav
#     Saved data for CelestialShore_DieForUs_STEM_7 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for CelestialShore_DieForUs_STEM_08.wav
#     Saved data for LizNelson_Coldwar_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MatthewEntwistle_Lontano
#     > computing CQT for MatthewEntwistle_Lontano_STEM_02.wav
#     Saved data for InvisibleFamiliars_DisturbingWildlife_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for InvisibleFamiliars_DisturbingWildlife_STEM_09.wav
#     Saved data for MatthewEntwistle_DontYouEver_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MatthewEntwistle_DontYouEver_STEM_07.wav
#     Saved data for AlexanderRoss_GoodbyeBolero_STEM_6 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for AlexanderRoss_GoodbyeBolero_STEM_07.wav
#     Saved data for HezekiahJones_BorrowedHeart_STEM_10 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for HezekiahJones_BorrowedHeart_STEM_12.wav
#     Saved data for LizNelson_Rainfall_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MatthewEntwistle_TheArch
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 53.1min
#     > computing CQT for MatthewEntwistle_TheArch_STEM_10.wav
#     Saved data for LizNelson_ImComingHome_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MatthewEntwistle_TheFlaxenField
#     > computing CQT for MatthewEntwistle_TheFlaxenField_STEM_01.wav
#     Saved data for HopAlong_SisterCities_STEM_7 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# Meaxic_TakeAStep
#     > computing CQT for Meaxic_TakeAStep_STEM_03.wav
#     Saved data for Creepoid_OldTree_STEM_7 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Creepoid_OldTree_STEM_08.wav
#     Saved data for MatthewEntwistle_DontYouEver_STEM_7 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# Meaxic_YouListen
#     Saved data for JoelHelander_ExcessiveResistancetoChange_STEM_3 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Meaxic_YouListen_STEM_01.wav
#     > computing CQT for JoelHelander_ExcessiveResistancetoChange_STEM_04.wav
#     Saved data for KarimDouaidy_Yatora_STEM_3 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for KarimDouaidy_Yatora_STEM_05.wav
#     Saved data for JoelHelander_Definition_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for JoelHelander_Definition_STEM_09.wav
#     Saved data for CelestialShore_DieForUs_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     Saved data for MatthewEntwistle_FairerHopes_STEM_10 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MichaelKropf_AllGoodThings
#     > computing CQT for MichaelKropf_AllGoodThings_STEM_01.wav
#     > computing CQT for MatthewEntwistle_FairerHopes_STEM_11.wav
#     Saved data for InvisibleFamiliars_DisturbingWildlife_STEM_9 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for InvisibleFamiliars_DisturbingWildlife_STEM_10.wav
#     Saved data for CroqueMadame_Oil_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# Mozart_BesterJungling
#     > computing CQT for Mozart_BesterJungling_STEM_01.wav
#     Saved data for HezekiahJones_BorrowedHeart_STEM_12 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# Mozart_DiesBildnis
#     > computing CQT for Mozart_DiesBildnis_STEM_01.wav
#     Saved data for AlexanderRoss_VelvetCurtain_STEM_6 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for AlexanderRoss_VelvetCurtain_STEM_07.wav
#     Saved data for MatthewEntwistle_ImpressionsOfSaturn_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MatthewEntwistle_ImpressionsOfSaturn_STEM_07.wav
#     Saved data for KarimDouaidy_Hopscotch_STEM_9 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_80sRock
#     > computing CQT for MusicDelta_80sRock_STEM_04.wav
#     Saved data for MatthewEntwistle_Lontano_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     Saved data for CroqueMadame_Pilot_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_Beatles
#     > computing CQT for MusicDelta_Beatles_STEM_07.wav
# MusicDelta_BebopJazz
#     > computing CQT for MusicDelta_BebopJazz_STEM_04.wav
#     Saved data for KarimDouaidy_Yatora_STEM_5 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_Beethoven
#     > computing CQT for MusicDelta_Beethoven_STEM_06.wav
#     Saved data for MusicDelta_80sRock_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_Britpop
#     > computing CQT for MusicDelta_Britpop_STEM_07.wav
#     Saved data for MatthewEntwistle_TheArch_STEM_10 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MatthewEntwistle_TheArch_STEM_13.wav
#     Saved data for MusicDelta_Beethoven_STEM_6 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     Saved data for MusicDelta_Beatles_STEM_7 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_Beethoven_STEM_08.wav
#     > computing CQT for MusicDelta_Beatles_STEM_08.wav
#     Saved data for Meaxic_TakeAStep_STEM_3 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Meaxic_TakeAStep_STEM_04.wav
#     Saved data for JoelHelander_Definition_STEM_9 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for JoelHelander_Definition_STEM_12.wav
#     Saved data for MusicDelta_Beethoven_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_Beethoven_STEM_10.wav
#     Saved data for MusicDelta_Britpop_STEM_7 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_Britpop_STEM_08.wav
#     Saved data for Creepoid_OldTree_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_ChineseChaoZhou
#     > computing CQT for MusicDelta_ChineseChaoZhou_STEM_01.wav
#     Saved data for JoelHelander_ExcessiveResistancetoChange_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for JoelHelander_ExcessiveResistancetoChange_STEM_08.wav
#     Saved data for MusicDelta_Beatles_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_ChineseDrama
#     > computing CQT for MusicDelta_ChineseDrama_STEM_01.wav
#     Saved data for MusicDelta_Beethoven_STEM_10 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_Beethoven_STEM_14.wav
#     Saved data for MatthewEntwistle_TheFlaxenField_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MatthewEntwistle_TheFlaxenField_STEM_02.wav
#     Saved data for Lushlife_ToynbeeSuite_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_ChineseHenan
#     > computing CQT for MusicDelta_ChineseHenan_STEM_01.wav
#     Saved data for MusicDelta_Britpop_STEM_8 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_ChineseJiangNan
#     > computing CQT for MusicDelta_ChineseJiangNan_STEM_01.wav
#     Saved data for MusicDelta_Beethoven_STEM_14 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_Beethoven_STEM_16.wav
#     Saved data for MusicDelta_Beethoven_STEM_16 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_ChineseXinJing
#     > computing CQT for MusicDelta_ChineseXinJing_STEM_01.wav
#     Saved data for MusicDelta_ChineseChaoZhou_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_ChineseChaoZhou_STEM_02.wav
#     Saved data for MusicDelta_ChineseDrama_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_ChineseDrama_STEM_02.wav
#     Saved data for Mozart_BesterJungling_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Mozart_BesterJungling_STEM_02.wav
#     Saved data for MusicDelta_ChineseHenan_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     Saved data for MusicDelta_ChineseJiangNan_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_ChineseHenan_STEM_02.wav
#     > computing CQT for MusicDelta_ChineseJiangNan_STEM_04.wav
#     Saved data for MusicDelta_BebopJazz_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_BebopJazz_STEM_05.wav
#     Saved data for MusicDelta_ChineseXinJing_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_ChineseXinJing_STEM_03.wav
#     Saved data for MusicDelta_ChineseChaoZhou_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_ChineseYaoZu
#     > computing CQT for MusicDelta_ChineseYaoZu_STEM_01.wav
#     Saved data for MusicDelta_ChineseDrama_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_ChineseDrama_STEM_03.wav
#     Saved data for MusicDelta_ChineseHenan_STEM_2 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_ChineseHenan_STEM_03.wav
#     Saved data for MusicDelta_ChineseJiangNan_STEM_4 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MusicDelta_ChineseJiangNan_STEM_05.wav
#     Saved data for AlexanderRoss_GoodbyeBolero_STEM_7 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for AlexanderRoss_GoodbyeBolero_STEM_08.wav
#     Saved data for InvisibleFamiliars_DisturbingWildlife_STEM_10 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
# MusicDelta_CoolJazz
#     > computing CQT for MusicDelta_CoolJazz_STEM_04.wav
#     Saved data for MichaelKropf_AllGoodThings_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for MichaelKropf_AllGoodThings_STEM_02.wav
#     Saved data for Mozart_DiesBildnis_STEM_1 to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/
#     > computing CQT for Mozart_DiesBildnis_STEM_02.wav

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/" "melody1" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs/" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
#     > AClassicEducation_NightOwl already done!
#     > AimeeNorwich_Child already done!
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
#     > AimeeNorwich_Flying already done!
# AlexanderRoss_VelvetCurtain
#     > AlexanderRoss_GoodbyeBolero already done!
# AmarLal_SpringDay1
#     > AmarLal_SpringDay1 already done!
# Auctioneer_OurFutureFaces
# AvaLuna_Waterduct
#     > AlexanderRoss_VelvetCurtain already done!
# AmarLal_Rest
# BrandonWebster_DontHearAThing
#     > Auctioneer_OurFutureFaces already done!
# CelestialShore_DieForUs
#     > AvaLuna_Waterduct already done!
#     > BrandonWebster_DontHearAThing already done!
# BigTroubles_Phantom
# BrandonWebster_YesSirICanFly
# ChrisJacoby_PigsFoot
#     > BigTroubles_Phantom already done!
#     > AmarLal_Rest already done!
#     > CelestialShore_DieForUs already done!
# ChrisJacoby_BoothShotLincoln
#     > BrandonWebster_YesSirICanFly already done!
# ClaraBerryAndWooldog_Boys
# ClaraBerryAndWooldog_TheBadGuys
#     > ClaraBerryAndWooldog_Boys already done!
# ClaraBerryAndWooldog_Stella
#     > ChrisJacoby_PigsFoot already done!
#     > ChrisJacoby_BoothShotLincoln already done!
# Creepoid_OldTree
# ClaraBerryAndWooldog_AirTraffic
# CroqueMadame_Pilot
#     > ClaraBerryAndWooldog_TheBadGuys already done!
#     > ClaraBerryAndWooldog_Stella already done!
# ClaraBerryAndWooldog_WaltzForMyVictims
#     > ClaraBerryAndWooldog_AirTraffic already done!
#     > Creepoid_OldTree already done!
# CroqueMadame_Oil
# DreamersOfTheGhetto_HeavyLove
# EthanHein_BluesForNofi
#     > ClaraBerryAndWooldog_WaltzForMyVictims already done!
#     EthanHein_BluesForNofi No melody 1 data
# EthanHein_GirlOnABridge
# EthanHein_HarmonicaFigure
#     > CroqueMadame_Pilot already done!
#     EthanHein_HarmonicaFigure No melody 1 data
# Debussy_LenfantProdigue
# FacesOnFilm_WaitingForGa
#     > EthanHein_GirlOnABridge already done!
#     > DreamersOfTheGhetto_HeavyLove already done!
# EthanHein_1930sSynthAndUprightBass
# FamilyBand_Again
#     > CroqueMadame_Oil already done!
#     > FacesOnFilm_WaitingForGa already done!
# Handel_TornamiAVagheggiar
#     > Debussy_LenfantProdigue already done!
#     > FamilyBand_Again already done!
# Grants_PunchDrunk
#     Grants_PunchDrunk No melody 1 data
#     > EthanHein_1930sSynthAndUprightBass already done!
# HezekiahJones_BorrowedHeart
#     > Handel_TornamiAVagheggiar already done!
# HeladoNegro_MitadDelMundo
#     > HeladoNegro_MitadDelMundo already done!
#     > HezekiahJones_BorrowedHeart already done!
# HopAlong_SisterCities
# InvisibleFamiliars_DisturbingWildlife
#     > InvisibleFamiliars_DisturbingWildlife already done!
# JoelHelander_ExcessiveResistancetoChange
# JoelHelander_Definition
#     > HopAlong_SisterCities already done!
# KarimDouaidy_Hopscotch
#     > JoelHelander_ExcessiveResistancetoChange already done!
# LizNelson_Coldwar
# JoelHelander_IntheAtticBedroom
#     > JoelHelander_Definition already done!
#     > KarimDouaidy_Hopscotch already done!
# KarimDouaidy_Yatora
#     > LizNelson_Coldwar already done!
# LizNelson_ImComingHome
# LizNelson_Rainfall
#     > JoelHelander_IntheAtticBedroom already done!
# MatthewEntwistle_DontYouEver
# MatthewEntwistle_AnEveningWithOliver
#     MatthewEntwistle_AnEveningWithOliver No melody 1 data
#     > MatthewEntwistle_DontYouEver already done!
#     > KarimDouaidy_Yatora already done!
#     > LizNelson_ImComingHome already done!
# MatthewEntwistle_FairerHopes
#     > LizNelson_Rainfall already done!
# Lushlife_ToynbeeSuite
#     Lushlife_ToynbeeSuite No melody 1 data
# MatthewEntwistle_Lontano
#     > MatthewEntwistle_FairerHopes already done!
# MatthewEntwistle_ImpressionsOfSaturn
# MatthewEntwistle_TheFlaxenField
# Meaxic_YouListen
# Mozart_BesterJungling
#     > MatthewEntwistle_Lontano already done!
# MatthewEntwistle_TheArch
# MusicDelta_80sRock
#     > MusicDelta_80sRock already done!
# MusicDelta_Beatles
#     > Mozart_BesterJungling already done!
# MusicDelta_BebopJazz
# Mozart_DiesBildnis
#     > MusicDelta_Beatles already done!
#     > MatthewEntwistle_ImpressionsOfSaturn already done!
#     > MatthewEntwistle_TheFlaxenField already done!
# MichaelKropf_AllGoodThings
#     > Meaxic_YouListen already done!
# Meaxic_TakeAStep
#     > MusicDelta_BebopJazz already done!
# MusicDelta_Beethoven
#     > Mozart_DiesBildnis already done!
#     > MusicDelta_Beethoven already done!
#     > MatthewEntwistle_TheArch already done!
# MusicDelta_Britpop
#     > MusicDelta_Britpop already done!
# MusicDelta_ChineseDrama
# MusicDelta_ChineseChaoZhou
#     > MusicDelta_ChineseChaoZhou already done!
#     > MusicDelta_ChineseDrama already done!
# MusicDelta_ChineseJiangNan
# MusicDelta_ChineseHenan
#     > MichaelKropf_AllGoodThings already done!
#     > MusicDelta_ChineseHenan already done!
#     > MusicDelta_ChineseJiangNan already done!
# MusicDelta_ChineseXinJing
# MusicDelta_ChineseYaoZu
#     > MusicDelta_ChineseXinJing already done!
#     > MusicDelta_ChineseYaoZu already done!
# MusicDelta_CoolJazz
# MusicDelta_Country1
#     > MusicDelta_Country1 already done!
#     > MusicDelta_CoolJazz already done!
# MusicDelta_Country2
# MusicDelta_Disco
#     > Meaxic_TakeAStep already done!
#     > MusicDelta_Country2 already done!
# MusicDelta_FunkJazz
#     > MusicDelta_Disco already done!
# MusicDelta_FreeJazz
# MusicDelta_Gospel
#     > MusicDelta_FunkJazz already done!
# MusicDelta_FusionJazz
# MusicDelta_Grunge
#     > MusicDelta_FreeJazz already done!
# MusicDelta_GriegTrolltog
#     > MusicDelta_Gospel already done!
#     > MusicDelta_Grunge already done!
# MusicDelta_Hendrix
#     > MusicDelta_GriegTrolltog already done!
#     > MusicDelta_FusionJazz already done!
# MusicDelta_InTheHalloftheMountainKing
#     > MusicDelta_Hendrix already done!
# MusicDelta_ModalJazz
# MusicDelta_Punk
#     > MusicDelta_InTheHalloftheMountainKing already done!
# MusicDelta_LatinJazz
#     > MusicDelta_ModalJazz already done!
# MusicDelta_Pachelbel
#     > MusicDelta_Punk already done!
# MusicDelta_Reggae
#     > MusicDelta_Reggae already done!
#     > MusicDelta_LatinJazz already done!
# MusicDelta_Rock
#     > MusicDelta_Rock already done!
# MusicDelta_Rockabilly
#     > MusicDelta_Rockabilly already done!
# MusicDelta_Shadows
#     > MusicDelta_Shadows already done!
# MusicDelta_SpeedMetal
# MusicDelta_SwingJazz
#     > MusicDelta_SpeedMetal already done!
#     > MusicDelta_Vivaldi already done!
#     > MusicDelta_SwingJazz already done!
# MusicDelta_Vivaldi
#     > MusicDelta_Pachelbel already done!
# MusicDelta_Zeppelin
#     > MusicDelta_Zeppelin already done!
# NightPanther_Fire
# Phoenix_BrokenPledgeChicagoReel
# Phoenix_ElzicsFarewell
# Phoenix_ScotchMorris
# Phoenix_ColliersDaughter
#     > Phoenix_BrokenPledgeChicagoReel already done!
#     > Phoenix_ElzicsFarewell already done!
#     > NightPanther_Fire already done!
# Phoenix_LarkOnTheStrandDrummondCastle
#     > Phoenix_ScotchMorris already done!
# Phoenix_SeanCaughlinsTheScartaglen
# PortStWillow_StayEven
#     > Phoenix_ColliersDaughter already done!
# Schubert_Erstarrung
#     > Phoenix_LarkOnTheStrandDrummondCastle already done!
#     > Phoenix_SeanCaughlinsTheScartaglen already done!
# SecretMountains_HighHorse
#     > PortStWillow_StayEven already done!
# PurlingHiss_Lolita
# StevenClark_Bounty
#     > Schubert_Erstarrung already done!
# Schumann_Mignon
#     > PurlingHiss_Lolita already done!
# SweetLights_YouLetMeDown
#     > SecretMountains_HighHorse already done!
# Snowmine_Curfews
#     > Schumann_Mignon already done!
#     TablaBreakbeatScience_MiloVsMongo No melody 1 data
# TablaBreakbeatScience_CaptainSky
#     TablaBreakbeatScience_CaptainSky No melody 1 data
# TablaBreakbeatScience_MiloVsMongo
# TablaBreakbeatScience_MoodyPlucks
#     TablaBreakbeatScience_MoodyPlucks No melody 1 data
#     > StevenClark_Bounty already done!
# StrandOfOaks_Spacestation
# TablaBreakbeatScience_PhaseTransition
#     > Snowmine_Curfews already done!
#     TablaBreakbeatScience_PhaseTransition No melody 1 data
# TablaBreakbeatScience_RockSteady
#     > SweetLights_YouLetMeDown already done!
#     TablaBreakbeatScience_Scorpio No melody 1 data
# TablaBreakbeatScience_Animoog
#     TablaBreakbeatScience_Animoog No melody 1 data
#     TablaBreakbeatScience_RockSteady No melody 1 data
# TablaBreakbeatScience_Scorpio
# TablaBreakbeatScience_Vger
#     > StrandOfOaks_Spacestation already done!
#     TablaBreakbeatScience_Vger No melody 1 data
# TablaBreakbeatScience_WhoIsIt
#     TablaBreakbeatScience_WhoIsIt No melody 1 data
# TheDistricts_Vermont
# TheSoSoGlos_Emergency
#     > TheDistricts_Vermont already done!
# TheScarletBrand_LesFleursDuMal
# Allegria_MendelssohnMovement1
#     Allegria_MendelssohnMovement1 No melody 1 data
# AmadeusRedux_MozartAllegro
#     > TheSoSoGlos_Emergency already done!
#     AmadeusRedux_MozartAllegro No melody 1 data
# AmadeusRedux_SchubertMovement2
#     AmadeusRedux_SchubertMovement2 No melody 1 data
# Wolf_DieBekherte
# AmadeusRedux_SchubertMovement3
#     AmadeusRedux_SchubertMovement3 No melody 1 data
#     > Wolf_DieBekherte already done!
#     > TheScarletBrand_LesFleursDuMal already done!
# BarefootSisters_RedJetta
#     CassandraJenkins_PerfectDay No melody 1 data
#     BarefootSisters_RedJetta No melody 1 data
# CassandraJenkins_PerfectDay
# CatMartino_IPromise
#     Cayetana_MissThing No melody 1 data
#     CatMartino_IPromise No melody 1 data
# Cayetana_MissThing
# DahkaBand_SoldierMan
#     DeadMilkmen_PrisonersCinema No melody 1 data
#     DahkaBand_SoldierMan No melody 1 data
# DeadMilkmen_PrisonersCinema
# DeclareAString_MendelssohnPianoTrio1Movement1
#     DeclareAString_MendelssohnPianoTrio1Movement2 No melody 1 data
#     DeclareAString_MendelssohnPianoTrio1Movement1 No melody 1 data
# DeclareAString_MendelssohnPianoTrio1Movement2
# FallingSparks_Improvisation1
#     FallingSparks_Improvisation2 No melody 1 data
#     FallingSparks_Improvisation1 No melody 1 data
# FallingSparks_Improvisation2
# FallingSparks_Improvisation3
#     FallingSparks_PakKlongTalad No melody 1 data
#     FallingSparks_Improvisation3 No melody 1 data
# FallingSparks_PakKlongTalad
# FennelCartwright_DearTessie
#     FennelCartwright_FlowerDrumSong No melody 1 data
#     FennelCartwright_DearTessie No melody 1 data
# FennelCartwright_FlowerDrumSong
# FennelCartwright_WinterLake
#     FilthyBird_IdLikeToKnow No melody 1 data
#     FennelCartwright_WinterLake No melody 1 data
# FilthyBird_IdLikeToKnow
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:    3.9s
# FruitCathedral_KeepMeRunnin
#     HopsNVinyl_ChickenFriedSteak No melody 1 data
#     FruitCathedral_KeepMeRunnin No melody 1 data
# HopsNVinyl_ChickenFriedSteak
# HopsNVinyl_HoneyBrown
#     HopsNVinyl_ReignCheck No melody 1 data
#     HopsNVinyl_HoneyBrown No melody 1 data
# HopsNVinyl_ReignCheck
# HopsNVinyl_WidowsWalk
#     Karachacha_Volamos No melody 1 data
#     HopsNVinyl_WidowsWalk No melody 1 data
# Karachacha_Volamos
# Katzn_CharlieKnox
#     LewisAndClarke_TheSilverSea No melody 1 data
#     Katzn_CharlieKnox No melody 1 data
# LewisAndClarke_TheSilverSea
# LittleTybee_TheAlchemist
#     MatthewEntwistle_ReturnToVenezia No melody 1 data
#     LittleTybee_TheAlchemist No melody 1 data
# MatthewEntwistle_ReturnToVenezia
# MidnightBlue_HuntingSeason
#     MidnightBlue_StarsAreScreaming No melody 1 data
#     MidnightBlue_HuntingSeason No melody 1 data
# MidnightBlue_StarsAreScreaming
# MutualBenefit_NotForNothing
#     PatternIsMovement_SaveMe No melody 1 data
#     MutualBenefit_NotForNothing No melody 1 data
# PatternIsMovement_SaveMe
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#     PeterMatthewBauer_YouAlwaysLookForSomeoneLost No melody 1 data
# Plasma_GoodShout
#     Plasma_GoodShout No melody 1 data
# PoliceHearingDepartment_Brahms
#     PoliceHearingDepartment_SchumannMovement1 No melody 1 data
#     PoliceHearingDepartment_Brahms No melody 1 data
# PoliceHearingDepartment_SchumannMovement1
# PoliceHearingDepartment_SchumannMovement2
#     PoliceHearingDepartment_VivaldiMovement1 No melody 1 data
#     PoliceHearingDepartment_SchumannMovement2 No melody 1 data
# PoliceHearingDepartment_VivaldiMovement1
# PoliceHearingDepartment_VivaldiMovement2
#     PoliceHearingDepartment_VivaldiMovement2 No melody 1 data
# PoliceHearingDepartment_VivaldiMovement3
#     PoliceHearingDepartment_VivaldiMovement3 No melody 1 data
# QuantumChromos_Circuits
#     RodrigoBonelli_BalladForLaura No melody 1 data
#     QuantumChromos_Circuits No melody 1 data
# RodrigoBonelli_BalladForLaura
# SasquatchConnection_BoomBoxing
#     SasquatchConnection_HolyClamsBatman No melody 1 data
#     SasquatchConnection_BoomBoxing No melody 1 data
# SasquatchConnection_HolyClamsBatman
# SasquatchConnection_Illuminati
#     SasquatchConnection_Struttin No melody 1 data
#     SasquatchConnection_Illuminati No melody 1 data
# SasquatchConnection_Struttin
# SasquatchConnection_ThanksALatte
#     SlowGhost_FirstSnow No melody 1 data
#     SasquatchConnection_ThanksALatte No melody 1 data
# SlowGhost_FirstSnow
# SlowGhost_MidnightGroove
#     SlowGhost_MidnightGroove No melody 1 data
# SlowGhost_Peanut
#     SlowGhost_Peanut No melody 1 data
# SlowGhost_YoureAMystery
#     SlowGhost_YoureAMystery No melody 1 data
# SongYiJeon_TwoMoons
#     SongYiJeon_TwoMoons No melody 1 data
# Sweat_AlmostAlways
#     Sweat_Anecdoche No melody 1 data
#     Sweat_AlmostAlways No melody 1 data
# Sweat_Anecdoche
# Sweat_Elegy
#     Sweat_Mesozoic No melody 1 data
#     Sweat_Elegy No melody 1 data
# Sweat_Mesozoic
# Sweat_Sn1572
#     Sweat_Tact No melody 1 data
#     Sweat_Sn1572 No melody 1 data
# Sweat_Tact
# TemperedElan_DorothyJeanne
#     TemperedElan_WiseOne No melody 1 data
#     TemperedElan_DorothyJeanne No melody 1 data
# TemperedElan_WiseOne
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#     TheFranckDuo_FranckViolinSonataInAMajorMovement2 No melody 1 data
#     TheFranckDuo_FranckViolinSonataInAMajorMovement1 No melody 1 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
# TheKitchenettes_Alive
#     TheNoHoStringOrchestra_ElgarMovement1 No melody 1 data
#     TheKitchenettes_Alive No melody 1 data
# TheNoHoStringOrchestra_ElgarMovement1
# TheNoHoStringOrchestra_ElgarMovement2
#     TheNoHoStringOrchestra_ElgarMovement3 No melody 1 data
#     TheNoHoStringOrchestra_ElgarMovement2 No melody 1 data
# TheNoHoStringOrchestra_ElgarMovement3
# TheTonTons_Lush
#     TleilaxEnsemble_Late No melody 1 data
#     TheTonTons_Lush No melody 1 data
# TleilaxEnsemble_Late
# TleilaxEnsemble_MelancholyFlowers
#     Torres_NewSkin No melody 1 data
#     TleilaxEnsemble_MelancholyFlowers No melody 1 data
# Torres_NewSkin
# TrevorAndTheSoundwaves_AloneAndSad
#     Verdi_IlTrovatore No melody 1 data
#     TrevorAndTheSoundwaves_AloneAndSad No melody 1 data
# Verdi_IlTrovatore
# AHa_TakeOnMe
#     AcDc_BackInBlack No melody 1 data
#     AHa_TakeOnMe No melody 1 data
# AcDc_BackInBlack
# Adele_SomeoneLikeYou
#     Aerosmith_LoveInAnElevator No melody 1 data
#     Adele_SomeoneLikeYou No melody 1 data
# Aerosmith_LoveInAnElevator
# AlanisMorissette_YouOughtaKnow
#     AllThatRemains_Chiron No melody 1 data
#     AlanisMorissette_YouOughtaKnow No melody 1 data
# AllThatRemains_Chiron
# AnEndlessSporadic_Anything
#     Anberlin_TheFeelGoodDrag No melody 1 data
#     AnEndlessSporadic_Anything No melody 1 data
# Anberlin_TheFeelGoodDrag
# ArcadeFire_BlackMirror
#     ArcticMonkeys_Brainstorm No melody 1 data
#     ArcadeFire_BlackMirror No melody 1 data
# ArcticMonkeys_Brainstorm
# BillyIdol_WhiteWedding
#     BillyIdol_WhiteWedding No melody 1 data
# BillySquier_TheStroke
#     BillySquier_TheStroke No melody 1 data
# BlackEyedPeas_IGottaFeeling
#     BlackSabbath_WarPigs No melody 1 data
#     BlackEyedPeas_IGottaFeeling No melody 1 data
# BlackSabbath_WarPigs
# Blink182_AllTheSmallThings
#     Blink182_AllTheSmallThings No melody 1 data
# Blondie_OneWayOrAnother
#     Blondie_OneWayOrAnother No melody 1 data
# BlueOysterCult_DontFearTheReaper
#     BlueOysterCult_DontFearTheReaper No melody 1 data
# BobSeger_OldTimeRockAndRoll
#     BobSeger_OldTimeRockAndRoll No melody 1 data
# Boston_MoreThanAFeeling
#     BradPaisley_MudOnTheTires No melody 1 data
#     Boston_MoreThanAFeeling No melody 1 data
# BradPaisley_MudOnTheTires
# BrooksDunn_HillbillyDeluxe
#     BrunoMars_Grenade No melody 1 data
#     BrooksDunn_HillbillyDeluxe No melody 1 data
# BrunoMars_Grenade
# BrunoMars_JustTheWayYouAre
#     BrunoMars_JustTheWayYouAre No melody 1 data
# BrunoMars_MarryYou
#     BrunoMars_MarryYou No melody 1 data
# BryanAdams_SummerOf69
#     Bush_Machinehead No melody 1 data
#     BryanAdams_SummerOf69 No melody 1 data
# Bush_Machinehead
# CarlDouglas_KungFuFighting
#     CarrieUnderwood_HomeSweetHome No melody 1 data
#     CarlDouglas_KungFuFighting No melody 1 data
# CarrieUnderwood_HomeSweetHome
# CeeloGreen_ForgetYou
#     CheapTrick_IWantYouToWantMe No melody 1 data
#     CeeloGreen_ForgetYou No melody 1 data
# CheapTrick_IWantYouToWantMe
# CherryPoppinDaddies_ZootSuitRiot
#     ChrisBrown_Yeah No melody 1 data
#     CherryPoppinDaddies_ZootSuitRiot No melody 1 data
# ChrisBrown_Yeah
# ChristinaAguilera_GenieInABottle
#     Chromeo_Tenderoni No melody 1 data
#     ChristinaAguilera_GenieInABottle No melody 1 data
# Chromeo_Tenderoni
# Chumbawamba_Tubthumping
#     ColdWarKids_HangMeUpToDry No melody 1 data
#     Chumbawamba_Tubthumping No melody 1 data
# ColdWarKids_HangMeUpToDry
# Coldplay_InMyPlace
#     Coldplay_Shiver No melody 1 data
#     Coldplay_InMyPlace No melody 1 data
# Coldplay_Shiver
# CorinneBaileyRae_PutYourRecordsOn
#     CountZero_Shake No melody 1 data
#     CorinneBaileyRae_PutYourRecordsOn No melody 1 data
# CountZero_Shake
# CountingCrows_AccidentallyInLove
#     CrazyFrog_JingleBells No melody 1 data
#     CountingCrows_AccidentallyInLove No melody 1 data
# CrazyFrog_JingleBells
# FleetwoodMac_Rhiannon
#     FleetwoodMac_Rhiannon No melody 1 data
#     FlightOfTheConcords_BusinessTime No melody 1 data
# FlightOfTheConcords_BusinessTime
# FooFighters_AllMyLife
#     Incubus_Drive No melody 1 data
#     FooFighters_AllMyLife No melody 1 data
# Incubus_Drive
# Inxs_NeedYouTonight
#     KaiserChiefs_Ruby No melody 1 data
#     Inxs_NeedYouTonight No melody 1 data
# KaiserChiefs_Ruby
# Kansas_CarryOnMyWaywardSon
#     KanyeWest_LoveLockdown No melody 1 data
#     Kansas_CarryOnMyWaywardSon No melody 1 data
# KanyeWest_LoveLockdown
# KeithUrban_IToldYouSo
#     KennyChesney_SheThinksMyTractorsSexy No melody 1 data
#     KeithUrban_IToldYouSo No melody 1 data
# KennyChesney_SheThinksMyTractorsSexy
# KingsOfLeon_SexOnFire
#     Kiss_RockAndRollAllNite No melody 1 data
#     KingsOfLeon_SexOnFire No melody 1 data
# Kiss_RockAndRollAllNite
# Knack_MySharona
#     Korn_FreakOnALeash No melody 1 data
#     Knack_MySharona No melody 1 data
# Korn_FreakOnALeash
# KtTunstall_BlackHorseAndTheCherryTree
#     KtTunstall_SuddenlyISee No melody 1 data
#     KtTunstall_BlackHorseAndTheCherryTree No melody 1 data
# KtTunstall_SuddenlyISee
# LaRoux_Bulletproof
#     LadyGagaFeaturingBeyonce_Telephone No melody 1 data
#     LaRoux_Bulletproof No melody 1 data
# LadyGagaFeaturingBeyonce_Telephone
# LadyGaga_BadRomance
#     LadyGaga_BadRomance No melody 1 data
# LadyGaga_BornThisWay
#     LadyGaga_BornThisWay No melody 1 data
# LambOfGod_Requiem
#     LennyKravitz_AreYouGonnaGoMyWay No melody 1 data
#     LambOfGod_Requiem No melody 1 data
# LennyKravitz_AreYouGonnaGoMyWay
# LilyAllen_NotFair
#     LinkinPark_InTheEnd No melody 1 data
#     LilyAllen_NotFair No melody 1 data
# LinkinPark_InTheEnd
# Lit_MyOwnWorstEnemy
#     Lit_MyOwnWorstEnemy No melody 1 data
# Live_IAlone
#     Live_IAlone No melody 1 data
# LoquilloYLosTrogloditas_CadillacSolitario
#     LosLobos_LaBamba No melody 1 data
#     LoquilloYLosTrogloditas_CadillacSolitario No melody 1 data
# LosLobos_LaBamba
# LynyrdSkynyrd_FreeBird
#     Maroon5_ThisLove No melody 1 data
#     LynyrdSkynyrd_FreeBird No melody 1 data
# Maroon5_ThisLove
# MartinaMcbride_ThisOnesForTheGirls
#     MarvinGaye_IHeardItThroughTheGrapevine No melody 1 data
#     MartinaMcbride_ThisOnesForTheGirls No melody 1 data
# MarvinGaye_IHeardItThroughTheGrapevine
# MarvinGaye_WhatsGoingOn
#     McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe No melody 1 data
#     MarvinGaye_WhatsGoingOn No melody 1 data
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
# MichaelJackson_BeatIt
#     MightyMightyBosstones_WheredYouGo No melody 1 data
#     MichaelJackson_BeatIt No melody 1 data
# MightyMightyBosstones_WheredYouGo
# MikeOldfield_Quicksilver
#     MileyCyrus_7Things No melody 1 data
#     MikeOldfield_Quicksilver No melody 1 data
# MileyCyrus_7Things
# MirandaCosgrove_HeadphonesOn
#     Misfits_AstroZombies No melody 1 data
#     MirandaCosgrove_HeadphonesOn No melody 1 data
# Misfits_AstroZombies
# ModestMouse_FloatOn
#     Muffs_KidsInAmerica No melody 1 data
#     ModestMouse_FloatOn No melody 1 data
# Muffs_KidsInAmerica
# Muse_Hysteria
#     TPain_Bartender No melody 1 data
#     Muse_Hysteria No melody 1 data
# TPain_Bartender
# TalkingHeads_PsychoKiller
#     TaylorSwift_LoveStory No melody 1 data
#     TalkingHeads_PsychoKiller No melody 1 data
# TaylorSwift_LoveStory
# TaylorSwift_YouBelongWithMe
#     TearsForFears_EverybodyWantsToRuleTheWorld No melody 1 data
#     TaylorSwift_YouBelongWithMe No melody 1 data
# TearsForFears_EverybodyWantsToRuleTheWorld
# Tesla_ModernDayCowboy
#     TheAllAmericanRejects_DirtyLittleSecret No melody 1 data
#     Tesla_ModernDayCowboy No melody 1 data
# TheAllAmericanRejects_DirtyLittleSecret
# TheAllmanBrothersBand_RamblinMan
#     TheBeatles_TwistAndShout No melody 1 data
#     TheAllmanBrothersBand_RamblinMan No melody 1 data
# TheBeatles_TwistAndShout
# TheBeatles_Wait
#     TheBeatles_WhatGoesOn No melody 1 data
#     TheBeatles_Wait No melody 1 data
# TheBeatles_WhatGoesOn
# TheBeatles_WhenIm64
#     TheBeatles_WhileMyGuitarGentlyWeeps No melody 1 data
#     TheBeatles_WhenIm64 No melody 1 data
# TheBeatles_WhileMyGuitarGentlyWeeps
# TheBeatles_WithALittleHelpFromMyFriends
#     TheBeatles_WithinYouWithoutYou No melody 1 data
#     TheBeatles_WithALittleHelpFromMyFriends No melody 1 data
# TheBeatles_WithinYouWithoutYou
# TheBeatles_YellowSubmarine
#     TheBeatles_YouWontSeeMe No melody 1 data
#     TheBeatles_YellowSubmarine No melody 1 data
# TheBeatles_YouWontSeeMe
# TheBlackKeys_YourTouch
#     TheBravery_Believe No melody 1 data
#     TheBlackKeys_YourTouch No melody 1 data
# TheBravery_Believe
# TheBronx_FalseAlarm
#     TheBronx_SixDaysAWeek No melody 1 data
#     TheBronx_FalseAlarm No melody 1 data
# TheBronx_SixDaysAWeek
# TheKillers_SomebodyToldMe
#     TheKooks_Naive No melody 1 data
#     TheKillers_SomebodyToldMe No melody 1 data
# TheKooks_Naive
# TheLastGoodnight_PicturesOfYou
#     TheTurtles_HappyTogether No melody 1 data
#     TheLastGoodnight_PicturesOfYou No melody 1 data
# TheTurtles_HappyTogether
# ThinLizzy_TheBoysAreBackInTown
#     ThinLizzy_TheBoysAreBackInTown No melody 1 data
# ThirdEyeBlind_Jumper
#     ThirdEyeBlind_Jumper No melody 1 data
# ThirdEyeBlind_NeverLetYouGo
#     TomPettyAndTheHeartbreakers_IWontBackDown No melody 1 data
#     ThirdEyeBlind_NeverLetYouGo No melody 1 data
# TomPettyAndTheHeartbreakers_IWontBackDown
# TomPetty_FreeFallin
#     Tonic_IfYouCouldOnlySee No melody 1 data
#     TomPetty_FreeFallin No melody 1 data
# Tonic_IfYouCouldOnlySee
# TvOnTheRadio_WolfLikeMe
#     TvOnTheRadio_WolfLikeMe No melody 1 data
# VampireWeekend_Cousins
#     VampireWeekend_Cousins No melody 1 data
# VampireWeekend_Holiday
#     VanHalen_Jump No melody 1 data
#     VampireWeekend_Holiday No melody 1 data
# VanHalen_Jump
# VanillaIce_IceIceBaby
#     VanillaIce_IceIceBaby No melody 1 data
# VillagePeople_Ymca
#     VillagePeople_Ymca No melody 1 data
# Weezer_IslandInTheSun
#     WildCherry_PlayThatFunkyMusic No melody 1 data
#     Weezer_IslandInTheSun No melody 1 data
# WildCherry_PlayThatFunkyMusic
# Bach10_01AchGottundHerr
#     Bach10_01AchGottundHerr No melody 1 data
# Bach10_02AchLiebenChristen
#     Bach10_02AchLiebenChristen No melody 1 data
# Bach10_03ChristederdubistTagundLicht
#     Bach10_04ChristeDuBeistand No melody 1 data
#     Bach10_03ChristederdubistTagundLicht No melody 1 data
# Bach10_04ChristeDuBeistand
# Bach10_05DieNacht
#     Bach10_06DieSonne No melody 1 data
#     Bach10_05DieNacht No melody 1 data
# Bach10_06DieSonne
# Bach10_07HerrGott
#     Bach10_08FuerDeinenThron No melody 1 data
#     Bach10_07HerrGott No melody 1 data
# Bach10_08FuerDeinenThron
# Bach10_09Jesus
#     Bach10_09Jesus No melody 1 data
# Bach10_10NunBitten
#     Bach10_10NunBitten No melody 1 data
# [Parallel(n_jobs=-1)]: Done 276 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 330 out of 330 | elapsed:    8.6s finished
# Done!

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/" "multif0_complete" -1 '' "--blur-labels"
# Out:
# AClassicEducation_NightOwl
#     > already done!
# AimeeNorwich_Child
#     > already done!
# AimeeNorwich_Flying
# AmarLal_SpringDay1
#     > already done!
# AlexanderRoss_GoodbyeBolero
#     > already done!
# AlexanderRoss_VelvetCurtain
#     > already done!
# AmarLal_Rest
#     > already done!
#     > already done!
# Auctioneer_OurFutureFaces
#     > already done!
# AvaLuna_Waterduct
#     > already done!
# BigTroubles_Phantom
#     > already done!
#     > already done!
# BrandonWebster_DontHearAThing
#     > already done!
# BrandonWebster_YesSirICanFly
#     > already done!
# CelestialShore_DieForUs
#     > already done!
# ChrisJacoby_BoothShotLincoln
#     > already done!
# ChrisJacoby_PigsFoot
#     > already done!
# ClaraBerryAndWooldog_AirTraffic
# ClaraBerryAndWooldog_Boys
# EthanHein_1930sSynthAndUprightBass
#     > already done!
# ClaraBerryAndWooldog_Stella
#     > already done!
# ClaraBerryAndWooldog_TheBadGuys
#     > already done!
# ClaraBerryAndWooldog_WaltzForMyVictims
#     > already done!
# Creepoid_OldTree
#     > already done!
# CroqueMadame_Oil
#     > already done!
# CroqueMadame_Pilot
#     > already done!
# Debussy_LenfantProdigue
#     > already done!
# DreamersOfTheGhetto_HeavyLove
#     > already done!
#     > already done!
# EthanHein_BluesForNofi
#     > already done!
# EthanHein_GirlOnABridge
#     > already done!
# EthanHein_HarmonicaFigure
#     EthanHein_HarmonicaFigure No multif0 data
# FacesOnFilm_WaitingForGa
#     > already done!
# FamilyBand_Again
#     > already done!
#     > already done!
# Grants_PunchDrunk
# Handel_TornamiAVagheggiar
#     > already done!
# JoelHelander_IntheAtticBedroom
# HeladoNegro_MitadDelMundo
#     > already done!
# HezekiahJones_BorrowedHeart
#     > already done!
# HopAlong_SisterCities
#     > already done!
# InvisibleFamiliars_DisturbingWildlife
#     > already done!
# JoelHelander_Definition
#     > already done!
# JoelHelander_ExcessiveResistancetoChange
#     > already done!
#     > already done!
#     > already done!
# KarimDouaidy_Hopscotch
#     > already done!
# KarimDouaidy_Yatora
#     > already done!
# LizNelson_Coldwar
#     > already done!
# LizNelson_ImComingHome
# LizNelson_Rainfall
# MatthewEntwistle_ImpressionsOfSaturn
#     > already done!
# Lushlife_ToynbeeSuite
#     > already done!
# MatthewEntwistle_AnEveningWithOliver
#     > already done!
# MatthewEntwistle_DontYouEver
#     > already done!
# MatthewEntwistle_FairerHopes
#     > already done!
#     > already done!
# MatthewEntwistle_Lontano
#     > already done!
# MatthewEntwistle_TheArch
#     > already done!
# MatthewEntwistle_TheFlaxenField
#     > already done!
# Meaxic_TakeAStep
#     > already done!
# Meaxic_YouListen
#     > already done!
# MichaelKropf_AllGoodThings
#     > already done!
# Mozart_BesterJungling
#     > already done!
# Mozart_DiesBildnis
#     > already done!
# MusicDelta_80sRock
# MusicDelta_Britpop
#     > already done!
# MusicDelta_Beatles
#     > already done!
# MusicDelta_BebopJazz
#     > already done!
# MusicDelta_Beethoven
#     > already done!
#     > already done!
# MusicDelta_ChineseChaoZhou
#     > already done!
# MusicDelta_ChineseDrama
#     > already done!
# MusicDelta_ChineseHenan
#     > already done!
#     > already done!
# MusicDelta_ChineseJiangNan
#     > already done!
# MusicDelta_ChineseXinJing
# MusicDelta_ChineseYaoZu
#     > already done!
#     > already done!
# MusicDelta_CoolJazz
#     > already done!
# MusicDelta_Country1
#     > already done!
# MusicDelta_Country2
# MusicDelta_Disco
#     > already done!
# MusicDelta_FreeJazz
#     > already done!
# MusicDelta_FunkJazz
#     > already done!
# MusicDelta_FusionJazz
#     > already done!
# MusicDelta_Gospel
#     > already done!
# MusicDelta_GriegTrolltog
#     > already done!
# MusicDelta_Grunge
#     > already done!
# MusicDelta_Hendrix
#     > already done!
# MusicDelta_InTheHalloftheMountainKing
#     > already done!
# MusicDelta_LatinJazz
#     > already done!
# MusicDelta_ModalJazz
#     > already done!
# MusicDelta_Pachelbel
#     > already done!
# MusicDelta_Punk
#     > already done!
# MusicDelta_Reggae
#     > already done!
# MusicDelta_Rock
#     > already done!
# MusicDelta_Rockabilly
#     > already done!
# MusicDelta_Shadows
#     > already done!
# MusicDelta_SpeedMetal
#     > already done!
# MusicDelta_SwingJazz
#     > already done!
# MusicDelta_Vivaldi
#     > already done!
# MusicDelta_Zeppelin
#     > already done!
# NightPanther_Fire
#     > already done!
# Phoenix_BrokenPledgeChicagoReel
#     > already done!
# Phoenix_ColliersDaughter
#     > already done!
# Phoenix_ElzicsFarewell
#     > already done!
# Phoenix_LarkOnTheStrandDrummondCastle
# SweetLights_YouLetMeDown
#     > already done!
# Phoenix_ScotchMorris
#     > already done!
# Phoenix_SeanCaughlinsTheScartaglen
#     > already done!
# PortStWillow_StayEven
#     > already done!
# PurlingHiss_Lolita
#     > already done!
# Schubert_Erstarrung
#     > already done!
# Schumann_Mignon
#     > already done!
# SecretMountains_HighHorse
#     > already done!
# Snowmine_Curfews
#     > already done!
# StevenClark_Bounty
#     > already done!
# StrandOfOaks_Spacestation
#     > already done!
#     > already done!
# TablaBreakbeatScience_Animoog
#     > already done!
# TablaBreakbeatScience_CaptainSky
# TablaBreakbeatScience_MoodyPlucks
#     > already done!
# TablaBreakbeatScience_MiloVsMongo
#     TablaBreakbeatScience_MiloVsMongo No multif0 data
#     TablaBreakbeatScience_MoodyPlucks No multif0 data
# TablaBreakbeatScience_PhaseTransition
#     > already done!
# TablaBreakbeatScience_RockSteady
#     TablaBreakbeatScience_RockSteady No multif0 data
# TablaBreakbeatScience_Scorpio
#     TablaBreakbeatScience_Scorpio No multif0 data
# TablaBreakbeatScience_Vger
#     TablaBreakbeatScience_Vger No multif0 data
# TablaBreakbeatScience_WhoIsIt
#     > already done!
# TheDistricts_Vermont
#     > already done!
# TheScarletBrand_LesFleursDuMal
#     > already done!
# TheSoSoGlos_Emergency
#     > already done!
# Wolf_DieBekherte
#     > already done!
# Allegria_MendelssohnMovement1
#     Allegria_MendelssohnMovement1 No multif0 data
# AmadeusRedux_MozartAllegro
#     AmadeusRedux_MozartAllegro No multif0 data
# AmadeusRedux_SchubertMovement2
#     > already done!
#     AmadeusRedux_SchubertMovement2 No multif0 data
# AmadeusRedux_SchubertMovement3
#     AmadeusRedux_SchubertMovement3 No multif0 data
# BarefootSisters_RedJetta
#     BarefootSisters_RedJetta No multif0 data
# CassandraJenkins_PerfectDay
#     > already done!
# CatMartino_IPromise
#     > already done!
# Cayetana_MissThing
# DahkaBand_SoldierMan
#     DahkaBand_SoldierMan No multif0 data
# DeadMilkmen_PrisonersCinema
#     > already done!
# DeclareAString_MendelssohnPianoTrio1Movement1
#     DeclareAString_MendelssohnPianoTrio1Movement1 No multif0 data
# DeclareAString_MendelssohnPianoTrio1Movement2
#     DeclareAString_MendelssohnPianoTrio1Movement2 No multif0 data
# FallingSparks_Improvisation1
#     FallingSparks_Improvisation1 No multif0 data
# FallingSparks_Improvisation2
#     FallingSparks_Improvisation2 No multif0 data
# FallingSparks_Improvisation3
#     FallingSparks_Improvisation3 No multif0 data
# FallingSparks_PakKlongTalad
#     FallingSparks_PakKlongTalad No multif0 data
# FennelCartwright_DearTessie
# HopsNVinyl_WidowsWalk
#     FennelCartwright_DearTessie No multif0 data
# FennelCartwright_FlowerDrumSong
#     FennelCartwright_FlowerDrumSong No multif0 data
# FennelCartwright_WinterLake
#     FennelCartwright_WinterLake No multif0 data
# FilthyBird_IdLikeToKnow
#     > already done!
# FruitCathedral_KeepMeRunnin
#     > already done!
# HopsNVinyl_ChickenFriedSteak
#     HopsNVinyl_ChickenFriedSteak No multif0 data
# HopsNVinyl_HoneyBrown
#     HopsNVinyl_HoneyBrown No multif0 data
# HopsNVinyl_ReignCheck
#     HopsNVinyl_ReignCheck No multif0 data
#     HopsNVinyl_WidowsWalk No multif0 data
# Karachacha_Volamos
# LittleTybee_TheAlchemist
#     Karachacha_Volamos No multif0 data
# Katzn_CharlieKnox
#     Katzn_CharlieKnox No multif0 data
# LewisAndClarke_TheSilverSea
#     LewisAndClarke_TheSilverSea No multif0 data
#     > already done!
# MatthewEntwistle_ReturnToVenezia
#     MatthewEntwistle_ReturnToVenezia No multif0 data
# MidnightBlue_HuntingSeason
# PoliceHearingDepartment_SchumannMovement1
#     > already done!
# MidnightBlue_StarsAreScreaming
#     > already done!
# MutualBenefit_NotForNothing
#     > already done!
# PatternIsMovement_SaveMe
#     > already done!
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#     > already done!
# Plasma_GoodShout
#     > already done!
# PoliceHearingDepartment_Brahms
#     PoliceHearingDepartment_Brahms No multif0 data
#     PoliceHearingDepartment_SchumannMovement1 No multif0 data
# PoliceHearingDepartment_SchumannMovement2
#     PoliceHearingDepartment_SchumannMovement2 No multif0 data
# PoliceHearingDepartment_VivaldiMovement1
#     PoliceHearingDepartment_VivaldiMovement1 No multif0 data
# PoliceHearingDepartment_VivaldiMovement2
#     PoliceHearingDepartment_VivaldiMovement2 No multif0 data
# PoliceHearingDepartment_VivaldiMovement3
#     PoliceHearingDepartment_VivaldiMovement3 No multif0 data
# QuantumChromos_Circuits
#     QuantumChromos_Circuits No multif0 data
# RodrigoBonelli_BalladForLaura
#     RodrigoBonelli_BalladForLaura No multif0 data
# SasquatchConnection_BoomBoxing
#     > already done!
#     SasquatchConnection_BoomBoxing No multif0 data
# SasquatchConnection_HolyClamsBatman
#     SasquatchConnection_HolyClamsBatman No multif0 data
# SasquatchConnection_Illuminati
#     SasquatchConnection_Illuminati No multif0 data
# SasquatchConnection_Struttin
#     SasquatchConnection_Struttin No multif0 data
# SasquatchConnection_ThanksALatte
#     SasquatchConnection_ThanksALatte No multif0 data
# SlowGhost_FirstSnow
#     > already done!
# SlowGhost_MidnightGroove
#     > already done!
# SlowGhost_Peanut
# SlowGhost_YoureAMystery
#     > already done!
# SongYiJeon_TwoMoons
#     SongYiJeon_TwoMoons No multif0 data
# Sweat_AlmostAlways
#     Sweat_AlmostAlways No multif0 data
# Sweat_Anecdoche
#     Sweat_Anecdoche No multif0 data
# Sweat_Elegy
#     Sweat_Elegy No multif0 data
# Sweat_Mesozoic
#     Sweat_Mesozoic No multif0 data
# Sweat_Sn1572
# TemperedElan_DorothyJeanne
#     Sweat_Sn1572 No multif0 data
# Sweat_Tact
#     Sweat_Tact No multif0 data
#     TemperedElan_DorothyJeanne No multif0 data
# TemperedElan_WiseOne
#     TemperedElan_WiseOne No multif0 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#     > already done!
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
#     TheFranckDuo_FranckViolinSonataInAMajorMovement2 No multif0 data
# TheKitchenettes_Alive
#     > already done!
# TheNoHoStringOrchestra_ElgarMovement1
#     TheNoHoStringOrchestra_ElgarMovement1 No multif0 data
# TheNoHoStringOrchestra_ElgarMovement2
#     TheNoHoStringOrchestra_ElgarMovement2 No multif0 data
# TheNoHoStringOrchestra_ElgarMovement3
#     TheNoHoStringOrchestra_ElgarMovement3 No multif0 data
# TheTonTons_Lush
#     > already done!
# TleilaxEnsemble_Late
#     TleilaxEnsemble_Late No multif0 data
# TleilaxEnsemble_MelancholyFlowers
#     TleilaxEnsemble_MelancholyFlowers No multif0 data
# Torres_NewSkin
#     > already done!
# TrevorAndTheSoundwaves_AloneAndSad
# AHa_TakeOnMe
#     > already done!
# Verdi_IlTrovatore
#     Verdi_IlTrovatore No multif0 data
# multitrack has stems with polyphonic instruments
# Aerosmith_LoveInAnElevator
# AcDc_BackInBlack
#     > already done!
# Adele_SomeoneLikeYou
#     > already done!
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:    5.6s
# multitrack has stems with polyphonic instruments
# ArcadeFire_BlackMirror
# AlanisMorissette_YouOughtaKnow
#     > already done!
# AllThatRemains_Chiron
#     > already done!
# AnEndlessSporadic_Anything
#     > already done!
# Anberlin_TheFeelGoodDrag
# multitrack has stems with polyphonic instruments
# BlackEyedPeas_IGottaFeeling
#     > already done!
# BlackSabbath_WarPigs
#     > already done!
# Blink182_AllTheSmallThings
# multitrack has stems with polyphonic instruments
# Blondie_OneWayOrAnother
# multitrack has stems with polyphonic instruments
# ArcticMonkeys_Brainstorm
# multitrack has stems with polyphonic instruments
# BlueOysterCult_DontFearTheReaper
# BillyIdol_WhiteWedding
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# CarlDouglas_KungFuFighting
# BillySquier_TheStroke
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# BobSeger_OldTimeRockAndRoll
# multitrack has stems with polyphonic instruments
# CherryPoppinDaddies_ZootSuitRiot
# CarrieUnderwood_HomeSweetHome
#     > already done!
# CeeloGreen_ForgetYou
#     > already done!
# CheapTrick_IWantYouToWantMe
#     > already done!
# multitrack has stems with polyphonic instruments
# Boston_MoreThanAFeeling
# multitrack has stems with polyphonic instruments
# ChrisBrown_Yeah
# multitrack has stems with polyphonic instruments
# BradPaisley_MudOnTheTires
#     > already done!
# BrooksDunn_HillbillyDeluxe
# multitrack has stems with polyphonic instruments
# ChristinaAguilera_GenieInABottle
# CountingCrows_AccidentallyInLove
#     > already done!
# FleetwoodMac_Rhiannon
# CrazyFrog_JingleBells
#     CrazyFrog_JingleBells No multif0 data
# multitrack has stems with polyphonic instruments
# BrunoMars_Grenade
# multitrack has stems with polyphonic instruments
# FlightOfTheConcords_BusinessTime
# multitrack has stems with polyphonic instruments
# Chromeo_Tenderoni
#     > already done!
# FooFighters_AllMyLife
# multitrack has stems with polyphonic instruments
#     > already done!
# Incubus_Drive
# Chumbawamba_Tubthumping
#     Chumbawamba_Tubthumping No multif0 data
# ColdWarKids_HangMeUpToDry
#     > already done!
# Coldplay_InMyPlace
#     > already done!
# Coldplay_Shiver
#     > already done!
# CorinneBaileyRae_PutYourRecordsOn
# multitrack has stems with polyphonic instruments
# BrunoMars_JustTheWayYouAre
# multitrack has stems with polyphonic instruments
# CountZero_Shake
#     > already done!
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# BrunoMars_MarryYou
# Inxs_NeedYouTonight
# multitrack has stems with polyphonic instruments
# KaiserChiefs_Ruby
# Knack_MySharona
#     > already done!
# Korn_FreakOnALeash
# multitrack has stems with polyphonic instruments
# BryanAdams_SummerOf69
#     > already done!
#     > already done!
# Bush_Machinehead
# KtTunstall_BlackHorseAndTheCherryTree
#     > already done!
# multitrack has stems with polyphonic instruments
# Kansas_CarryOnMyWaywardSon
#     > already done!
# KeithUrban_IToldYouSo
# KanyeWest_LoveLockdown
#     > already done!
#     > already done!
# KennyChesney_SheThinksMyTractorsSexy
#     > already done!
# KingsOfLeon_SexOnFire
# Kiss_RockAndRollAllNite
#     KingsOfLeon_SexOnFire No multif0 data
# multitrack has stems with polyphonic instruments
# KtTunstall_SuddenlyISee
#     > already done!
# LadyGaga_BadRomance
# LaRoux_Bulletproof
#     > already done!
# LadyGagaFeaturingBeyonce_Telephone
#     > already done!
# multitrack has stems with polyphonic instruments
# LadyGaga_BornThisWay
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# LinkinPark_InTheEnd
# LambOfGod_Requiem
#     > already done!
# LennyKravitz_AreYouGonnaGoMyWay
#     > already done!
# LilyAllen_NotFair
#     > already done!
# LoquilloYLosTrogloditas_CadillacSolitario
#     LoquilloYLosTrogloditas_CadillacSolitario No multif0 data
# LosLobos_LaBamba
# multitrack has stems with polyphonic instruments
# Lit_MyOwnWorstEnemy
#     > already done!
# Live_IAlone
# multitrack has stems with polyphonic instruments
# Maroon5_ThisLove
# LynyrdSkynyrd_FreeBird
#     > already done!
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# MartinaMcbride_ThisOnesForTheGirls
# ModestMouse_FloatOn
# MarvinGaye_IHeardItThroughTheGrapevine
# multitrack has stems with polyphonic instruments
# multitrack has stems with polyphonic instruments
# MarvinGaye_WhatsGoingOn
#     > already done!
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
# MichaelJackson_BeatIt
#     > already done!
# multitrack has stems with polyphonic instruments
# Muffs_KidsInAmerica
#     > already done!
# Muse_Hysteria
#     > already done!
# TPain_Bartender
# multitrack has stems with polyphonic instruments
# MightyMightyBosstones_WheredYouGo
#     > already done!
# MikeOldfield_Quicksilver
#     MikeOldfield_Quicksilver No multif0 data
# MileyCyrus_7Things
# multitrack has stems with polyphonic instruments
# TalkingHeads_PsychoKiller
#     > already done!
# TaylorSwift_LoveStory
# TheBeatles_WhenIm64
# multitrack has stems with polyphonic instruments
# MirandaCosgrove_HeadphonesOn
#     > already done!
# Misfits_AstroZombies
#     TheBeatles_WhenIm64 No multif0 data
# TheBeatles_WhileMyGuitarGentlyWeeps
#     TheBeatles_WhileMyGuitarGentlyWeeps No multif0 data
# TheBeatles_WithALittleHelpFromMyFriends
#     > already done!
#     TheBeatles_WithALittleHelpFromMyFriends No multif0 data
# TheBeatles_WithinYouWithoutYou
#     TheBeatles_WithinYouWithoutYou No multif0 data
# TheBeatles_YellowSubmarine
#     TheBeatles_YellowSubmarine No multif0 data
# TheBeatles_YouWontSeeMe
#     TheBeatles_YouWontSeeMe No multif0 data
# TheBlackKeys_YourTouch
#     TheBlackKeys_YourTouch No multif0 data
# TheBravery_Believe
#     TheBravery_Believe No multif0 data
# TheBronx_FalseAlarm
#     > already done!
# TheBronx_SixDaysAWeek
#     > already done!
# TheKillers_SomebodyToldMe
# multitrack has stems with polyphonic instruments
# TaylorSwift_YouBelongWithMe
# multitrack has stems with polyphonic instruments
# TheKooks_Naive
# multitrack has stems with polyphonic instruments
# TheLastGoodnight_PicturesOfYou
#     > already done!
# TheTurtles_HappyTogether
# multitrack has stems with polyphonic instruments
# TearsForFears_EverybodyWantsToRuleTheWorld
# multitrack has stems with polyphonic instruments
# Tesla_ModernDayCowboy
# multitrack has stems with polyphonic instruments
# TheAllAmericanRejects_DirtyLittleSecret
# ThinLizzy_TheBoysAreBackInTown
#     > already done!
# multitrack has stems with polyphonic instruments
# ThirdEyeBlind_NeverLetYouGo
# ThirdEyeBlind_Jumper
#     > already done!
# Bach10_01AchGottundHerr
# multitrack has stems with polyphonic instruments
# TheAllmanBrothersBand_RamblinMan
#     > already done!
# TheBeatles_TwistAndShout
#     TheBeatles_TwistAndShout No multif0 data
# TheBeatles_Wait
#     TheBeatles_Wait No multif0 data
# TheBeatles_WhatGoesOn
#     TheBeatles_WhatGoesOn No multif0 data
# multitrack has stems with polyphonic instruments
# TomPettyAndTheHeartbreakers_IWontBackDown
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# multitrack has stems with polyphonic instruments
# TomPetty_FreeFallin
# multitrack has stems with polyphonic instruments
# Tonic_IfYouCouldOnlySee
# multitrack has stems with polyphonic instruments
# TvOnTheRadio_WolfLikeMe
#     TvOnTheRadio_WolfLikeMe No multif0 data
# VampireWeekend_Cousins
#     > already done!
# VampireWeekend_Holiday
#     > already done!
# VanHalen_Jump
#     VanHalen_Jump No multif0 data
# VanillaIce_IceIceBaby
# multitrack has stems with polyphonic instruments
# VillagePeople_Ymca
# multitrack has stems with polyphonic instruments
# Weezer_IslandInTheSun
#     Weezer_IslandInTheSun No multif0 data
# WildCherry_PlayThatFunkyMusic
#     WildCherry_PlayThatFunkyMusic No multif0 data
#     > computing CQT for Bach10_01AchGottundHerr_multif0_MIX.wav
#     Saved data for Bach10_01AchGottundHerr_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Bach10_02AchLiebenChristen
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
#     > computing CQT for Bach10_02AchLiebenChristen_multif0_MIX.wav
#     Saved data for Bach10_02AchLiebenChristen_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Bach10_03ChristederdubistTagundLicht
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
#     > computing CQT for Bach10_03ChristederdubistTagundLicht_multif0_MIX.wav
#     Saved data for Bach10_03ChristederdubistTagundLicht_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Bach10_04ChristeDuBeistand
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
#     > computing CQT for Bach10_04ChristeDuBeistand_multif0_MIX.wav
#     Saved data for Bach10_04ChristeDuBeistand_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Bach10_05DieNacht
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
#     > computing CQT for Bach10_05DieNacht_multif0_MIX.wav
#     Saved data for Bach10_05DieNacht_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Bach10_06DieSonne
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
#     > computing CQT for Bach10_06DieSonne_multif0_MIX.wav
#     Saved data for Bach10_06DieSonne_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Bach10_07HerrGott
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
#     > computing CQT for Bach10_07HerrGott_multif0_MIX.wav
#     Saved data for Bach10_07HerrGott_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Bach10_08FuerDeinenThron
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
#     > computing CQT for Bach10_08FuerDeinenThron_multif0_MIX.wav
#     Saved data for Bach10_08FuerDeinenThron_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Bach10_09Jesus
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
#     > computing CQT for Bach10_09Jesus_multif0_MIX.wav
#     Saved data for Bach10_09Jesus_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Bach10_10NunBitten
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
# [Warning] Multitrack does not have mixing coefficients. Using uniform stem weights.
#     > computing CQT for Bach10_10NunBitten_multif0_MIX.wav
#     Saved data for Bach10_10NunBitten_multif0_complete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/
# Done!
# [Parallel(n_jobs=-1)]: Done 330 out of 330 | elapsed:  1.5min finished

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/" "melody2" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs/" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
#     > already done!
# AimeeNorwich_Flying
#     > already done!
#     > already done!
# AlexanderRoss_GoodbyeBolero
#     > already done!
# AlexanderRoss_VelvetCurtain
# Auctioneer_OurFutureFaces
# BrandonWebster_YesSirICanFly
#     > already done!
# AvaLuna_Waterduct
#     > already done!
# CelestialShore_DieForUs
# ClaraBerryAndWooldog_AirTraffic
#     > already done!
#     > already done!
# BigTroubles_Phantom
# AmarLal_Rest
#     > already done!
# ChrisJacoby_BoothShotLincoln
#     > already done!
# ClaraBerryAndWooldog_Boys
#     > already done!
# ClaraBerryAndWooldog_WaltzForMyVictims
# AmarLal_SpringDay1
#     > already done!
# ClaraBerryAndWooldog_Stella
#     > already done!
# BrandonWebster_DontHearAThing
# Debussy_LenfantProdigue
#     > already done!
#     > already done!
#     > already done!
# Creepoid_OldTree
# ChrisJacoby_PigsFoot
#     > already done!
# ClaraBerryAndWooldog_TheBadGuys
#     > already done!
#     > already done!
# DreamersOfTheGhetto_HeavyLove
# EthanHein_GirlOnABridge
#     > already done!
# CroqueMadame_Oil
#     > already done!
#     > already done!
#     > already done!
# EthanHein_1930sSynthAndUprightBass
# EthanHein_HarmonicaFigure
#     EthanHein_HarmonicaFigure No melody 2 data
# FacesOnFilm_WaitingForGa
#     > already done!
# Grants_PunchDrunk
#     Grants_PunchDrunk No melody 2 data
# Handel_TornamiAVagheggiar
#     > already done!
# FamilyBand_Again
#     > already done!
#     > already done!
# CroqueMadame_Pilot
# EthanHein_BluesForNofi
#     EthanHein_BluesForNofi No melody 2 data
#     > already done!
# HeladoNegro_MitadDelMundo
#     > already done!
#     > already done!
# HezekiahJones_BorrowedHeart
# HopAlong_SisterCities
# JoelHelander_IntheAtticBedroom
#     > already done!
#     > already done!
#     > already done!
# InvisibleFamiliars_DisturbingWildlife
# LizNelson_ImComingHome
# JoelHelander_Definition
#     > already done!
# KarimDouaidy_Hopscotch
#     > already done!
# MatthewEntwistle_DontYouEver
#     > already done!
# LizNelson_Rainfall
#     > already done!
# KarimDouaidy_Yatora
#     > already done!
# MatthewEntwistle_FairerHopes
#     > already done!
# JoelHelander_ExcessiveResistancetoChange
# MatthewEntwistle_TheArch
# MichaelKropf_AllGoodThings
#     > already done!
#     > already done!
# LizNelson_Coldwar
# Lushlife_ToynbeeSuite
#     Lushlife_ToynbeeSuite No melody 2 data
#     > already done!
# MatthewEntwistle_AnEveningWithOliver
#     > already done!
# MatthewEntwistle_TheFlaxenField
#     MatthewEntwistle_AnEveningWithOliver No melody 2 data
#     > already done!
# MatthewEntwistle_ImpressionsOfSaturn
#     > already done!
#     > already done!
# Mozart_BesterJungling
# MusicDelta_Beatles
#     > already done!
# MusicDelta_BebopJazz
# MusicDelta_ChineseChaoZhou
#     > already done!
# Mozart_DiesBildnis
#     > already done!
#     > already done!
# MusicDelta_ChineseDrama
# Meaxic_TakeAStep
# MusicDelta_ChineseXinJing
# MusicDelta_Country2
#     > already done!
#     > already done!
# MusicDelta_ChineseHenan
# MatthewEntwistle_Lontano
#     > already done!
# MusicDelta_Beethoven
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_ChineseYaoZu
#     > already done!
# MusicDelta_ChineseJiangNan
# MusicDelta_Britpop
#     > already done!
#     > already done!
# Meaxic_YouListen
# MusicDelta_80sRock
# MusicDelta_Disco
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_CoolJazz
#     > already done!
# MusicDelta_Gospel
#     > already done!
#     > already done!
# MusicDelta_FreeJazz
#     > already done!
# MusicDelta_GriegTrolltog
#     > already done!
# MusicDelta_Country1
#     > already done!
# MusicDelta_Grunge
#     > already done!
#     > already done!
# MusicDelta_FunkJazz
#     > already done!
# MusicDelta_Hendrix
# MusicDelta_InTheHalloftheMountainKing
#     > already done!
#     > already done!
# MusicDelta_LatinJazz
#     > already done!
# MusicDelta_FusionJazz
#     > already done!
# MusicDelta_Punk
#     > already done!
# MusicDelta_ModalJazz
#     > already done!
# MusicDelta_Reggae
#     > already done!
# MusicDelta_Rock
#     > already done!
# MusicDelta_Shadows
# MusicDelta_Pachelbel
#     > already done!
#     > already done!
# MusicDelta_Rockabilly
#     > already done!
# MusicDelta_SpeedMetal
#     > already done!
#     > already done!
# MusicDelta_SwingJazz
# MusicDelta_Zeppelin
#     > already done!
# NightPanther_Fire
#     > already done!
# MusicDelta_Vivaldi
#     > already done!
# Phoenix_ElzicsFarewell
#     > already done!
#     > already done!
# Phoenix_BrokenPledgeChicagoReel
#     > already done!
# Phoenix_LarkOnTheStrandDrummondCastle
# PortStWillow_StayEven
#     > already done!
# Phoenix_ColliersDaughter
#     > already done!
# PurlingHiss_Lolita
#     > already done!
# Phoenix_ScotchMorris
#     > already done!
#     > already done!
# Phoenix_SeanCaughlinsTheScartaglen
#     > already done!
#     > already done!
# Schubert_Erstarrung
# SecretMountains_HighHorse
#     > already done!
# Schumann_Mignon
# SweetLights_YouLetMeDown
#     > already done!
#     > already done!
# Snowmine_Curfews
# TablaBreakbeatScience_MoodyPlucks
#     TablaBreakbeatScience_MoodyPlucks No melody 2 data
# TablaBreakbeatScience_PhaseTransition
#     TablaBreakbeatScience_PhaseTransition No melody 2 data
# TablaBreakbeatScience_RockSteady
#     TablaBreakbeatScience_RockSteady No melody 2 data
# TablaBreakbeatScience_Scorpio
#     TablaBreakbeatScience_Scorpio No melody 2 data
#     > already done!
#     > already done!
# StevenClark_Bounty
# TablaBreakbeatScience_Animoog
#     TablaBreakbeatScience_Animoog No melody 2 data
# TablaBreakbeatScience_CaptainSky
#     TablaBreakbeatScience_CaptainSky No melody 2 data
# TablaBreakbeatScience_MiloVsMongo
#     TablaBreakbeatScience_MiloVsMongo No melody 2 data
# TablaBreakbeatScience_Vger
#     TablaBreakbeatScience_Vger No melody 2 data
# TablaBreakbeatScience_WhoIsIt
#     TablaBreakbeatScience_WhoIsIt No melody 2 data
# TheDistricts_Vermont
#     > already done!
# StrandOfOaks_Spacestation
# TheSoSoGlos_Emergency
#     > already done!
# TheScarletBrand_LesFleursDuMal
# Wolf_DieBekherte
#     > already done!
#     > already done!
# AmadeusRedux_SchubertMovement2
# CassandraJenkins_PerfectDay
#     AmadeusRedux_SchubertMovement2 No melody 2 data
# AmadeusRedux_SchubertMovement3
#     > already done!
#     AmadeusRedux_SchubertMovement3 No melody 2 data
# BarefootSisters_RedJetta
#     BarefootSisters_RedJetta No melody 2 data
#     CassandraJenkins_PerfectDay No melody 2 data
#     > already done!
# Allegria_MendelssohnMovement1
#     Allegria_MendelssohnMovement1 No melody 2 data
# AmadeusRedux_MozartAllegro
#     AmadeusRedux_MozartAllegro No melody 2 data
#     DeadMilkmen_PrisonersCinema No melody 2 data
# DeadMilkmen_PrisonersCinema
#     DahkaBand_SoldierMan No melody 2 data
# DahkaBand_SoldierMan
#     Cayetana_MissThing No melody 2 data
# Cayetana_MissThing
#     CatMartino_IPromise No melody 2 data
# CatMartino_IPromise
# DeclareAString_MendelssohnPianoTrio1Movement1
#     FallingSparks_Improvisation2 No melody 2 data
#     DeclareAString_MendelssohnPianoTrio1Movement1 No melody 2 data
# DeclareAString_MendelssohnPianoTrio1Movement2
#     DeclareAString_MendelssohnPianoTrio1Movement2 No melody 2 data
# FallingSparks_Improvisation1
#     FallingSparks_Improvisation1 No melody 2 data
# FallingSparks_Improvisation2
# FallingSparks_Improvisation3
#     FennelCartwright_FlowerDrumSong No melody 2 data
#     FallingSparks_Improvisation3 No melody 2 data
# FallingSparks_PakKlongTalad
#     FallingSparks_PakKlongTalad No melody 2 data
# FennelCartwright_DearTessie
#     FennelCartwright_DearTessie No melody 2 data
# FennelCartwright_FlowerDrumSong
# FennelCartwright_WinterLake
#     HopsNVinyl_ChickenFriedSteak No melody 2 data
#     FennelCartwright_WinterLake No melody 2 data
# FilthyBird_IdLikeToKnow
#     FilthyBird_IdLikeToKnow No melody 2 data
# FruitCathedral_KeepMeRunnin
#     FruitCathedral_KeepMeRunnin No melody 2 data
# HopsNVinyl_ChickenFriedSteak
# HopsNVinyl_HoneyBrown
#     Karachacha_Volamos No melody 2 data
#     HopsNVinyl_HoneyBrown No melody 2 data
# HopsNVinyl_ReignCheck
#     HopsNVinyl_ReignCheck No melody 2 data
# HopsNVinyl_WidowsWalk
#     HopsNVinyl_WidowsWalk No melody 2 data
# Karachacha_Volamos
# Katzn_CharlieKnox
#     MatthewEntwistle_ReturnToVenezia No melody 2 data
#     Katzn_CharlieKnox No melody 2 data
# LewisAndClarke_TheSilverSea
#     LewisAndClarke_TheSilverSea No melody 2 data
# LittleTybee_TheAlchemist
#     LittleTybee_TheAlchemist No melody 2 data
# MatthewEntwistle_ReturnToVenezia
# MidnightBlue_HuntingSeason
#     MidnightBlue_HuntingSeason No melody 2 data
# MidnightBlue_StarsAreScreaming
#     MidnightBlue_StarsAreScreaming No melody 2 data
# MutualBenefit_NotForNothing
#     MutualBenefit_NotForNothing No melody 2 data
# PatternIsMovement_SaveMe
#     PatternIsMovement_SaveMe No melody 2 data
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#     PoliceHearingDepartment_SchumannMovement1 No melody 2 data
#     PeterMatthewBauer_YouAlwaysLookForSomeoneLost No melody 2 data
# Plasma_GoodShout
#     Plasma_GoodShout No melody 2 data
# PoliceHearingDepartment_Brahms
#     PoliceHearingDepartment_Brahms No melody 2 data
# PoliceHearingDepartment_SchumannMovement1
# PoliceHearingDepartment_SchumannMovement2
#     PoliceHearingDepartment_VivaldiMovement3 No melody 2 data
#     PoliceHearingDepartment_SchumannMovement2 No melody 2 data
# PoliceHearingDepartment_VivaldiMovement1
#     PoliceHearingDepartment_VivaldiMovement1 No melody 2 data
# PoliceHearingDepartment_VivaldiMovement2
#     PoliceHearingDepartment_VivaldiMovement2 No melody 2 data
# PoliceHearingDepartment_VivaldiMovement3
# QuantumChromos_Circuits
#     QuantumChromos_Circuits No melody 2 data
# RodrigoBonelli_BalladForLaura
#     SasquatchConnection_HolyClamsBatman No melody 2 data
#     RodrigoBonelli_BalladForLaura No melody 2 data
# SasquatchConnection_BoomBoxing
#     SasquatchConnection_BoomBoxing No melody 2 data
# SasquatchConnection_HolyClamsBatman
# SasquatchConnection_Illuminati
#     SlowGhost_FirstSnow No melody 2 data
#     SasquatchConnection_Illuminati No melody 2 data
# SasquatchConnection_Struttin
#     SasquatchConnection_Struttin No melody 2 data
# SasquatchConnection_ThanksALatte
#     SasquatchConnection_ThanksALatte No melody 2 data
# SlowGhost_FirstSnow
# SlowGhost_MidnightGroove
#     SongYiJeon_TwoMoons No melody 2 data
#     SlowGhost_MidnightGroove No melody 2 data
# SlowGhost_Peanut
#     SlowGhost_Peanut No melody 2 data
# SlowGhost_YoureAMystery
#     SlowGhost_YoureAMystery No melody 2 data
# SongYiJeon_TwoMoons
# Sweat_AlmostAlways
#     Sweat_Mesozoic No melody 2 data
#     Sweat_AlmostAlways No melody 2 data
# Sweat_Anecdoche
#     Sweat_Anecdoche No melody 2 data
# Sweat_Elegy
#     Sweat_Elegy No melody 2 data
# Sweat_Mesozoic
# Sweat_Sn1572
# TemperedElan_DorothyJeanne
#     Sweat_Sn1572 No melody 2 data
# Sweat_Tact
#     Sweat_Tact No melody 2 data
#     TemperedElan_DorothyJeanne No melody 2 data
# TemperedElan_WiseOne
#     TemperedElan_WiseOne No melody 2 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#     TheNoHoStringOrchestra_ElgarMovement1 No melody 2 data
#     TheFranckDuo_FranckViolinSonataInAMajorMovement1 No melody 2 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
#     TheFranckDuo_FranckViolinSonataInAMajorMovement2 No melody 2 data
# TheKitchenettes_Alive
#     TheKitchenettes_Alive No melody 2 data
# TheNoHoStringOrchestra_ElgarMovement1
# TheNoHoStringOrchestra_ElgarMovement2
# TleilaxEnsemble_Late
#     TheNoHoStringOrchestra_ElgarMovement2 No melody 2 data
# TheNoHoStringOrchestra_ElgarMovement3
#     TheNoHoStringOrchestra_ElgarMovement3 No melody 2 data
# TheTonTons_Lush
#     TheTonTons_Lush No melody 2 data
#     TleilaxEnsemble_Late No melody 2 data
# TleilaxEnsemble_MelancholyFlowers
#     Verdi_IlTrovatore No melody 2 data
#     TleilaxEnsemble_MelancholyFlowers No melody 2 data
# Torres_NewSkin
#     Torres_NewSkin No melody 2 data
# TrevorAndTheSoundwaves_AloneAndSad
#     TrevorAndTheSoundwaves_AloneAndSad No melody 2 data
# Verdi_IlTrovatore
#     Aerosmith_LoveInAnElevator No melody 2 data
# Aerosmith_LoveInAnElevator
#     Adele_SomeoneLikeYou No melody 2 data
# Adele_SomeoneLikeYou
#     AcDc_BackInBlack No melody 2 data
# AcDc_BackInBlack
#     AHa_TakeOnMe No melody 2 data
# AHa_TakeOnMe
# AlanisMorissette_YouOughtaKnow
#     Anberlin_TheFeelGoodDrag No melody 2 data
#     AlanisMorissette_YouOughtaKnow No melody 2 data
# AllThatRemains_Chiron
#     AllThatRemains_Chiron No melody 2 data
# AnEndlessSporadic_Anything
#     AnEndlessSporadic_Anything No melody 2 data
# Anberlin_TheFeelGoodDrag
# ArcadeFire_BlackMirror
#     BillySquier_TheStroke No melody 2 data
#     ArcadeFire_BlackMirror No melody 2 data
# ArcticMonkeys_Brainstorm
#     ArcticMonkeys_Brainstorm No melody 2 data
# BillyIdol_WhiteWedding
#     BillyIdol_WhiteWedding No melody 2 data
# BillySquier_TheStroke
# BlackEyedPeas_IGottaFeeling
#     Blondie_OneWayOrAnother No melody 2 data
#     BlackEyedPeas_IGottaFeeling No melody 2 data
# BlackSabbath_WarPigs
#     BlackSabbath_WarPigs No melody 2 data
# Blink182_AllTheSmallThings
#     Blink182_AllTheSmallThings No melody 2 data
# Blondie_OneWayOrAnother
# BlueOysterCult_DontFearTheReaper
#     BradPaisley_MudOnTheTires No melody 2 data
#     BlueOysterCult_DontFearTheReaper No melody 2 data
# BobSeger_OldTimeRockAndRoll
#     BobSeger_OldTimeRockAndRoll No melody 2 data
# Boston_MoreThanAFeeling
#     Boston_MoreThanAFeeling No melody 2 data
# BradPaisley_MudOnTheTires
# BrooksDunn_HillbillyDeluxe
#     BrunoMars_MarryYou No melody 2 data
#     BrooksDunn_HillbillyDeluxe No melody 2 data
# BrunoMars_Grenade
#     BrunoMars_Grenade No melody 2 data
# BrunoMars_JustTheWayYouAre
#     BrunoMars_JustTheWayYouAre No melody 2 data
# BrunoMars_MarryYou
# BryanAdams_SummerOf69
#     CarrieUnderwood_HomeSweetHome No melody 2 data
#     BryanAdams_SummerOf69 No melody 2 data
# Bush_Machinehead
#     Bush_Machinehead No melody 2 data
# CarlDouglas_KungFuFighting
#     CarlDouglas_KungFuFighting No melody 2 data
# CarrieUnderwood_HomeSweetHome
# CeeloGreen_ForgetYou
#     ChrisBrown_Yeah No melody 2 data
#     CeeloGreen_ForgetYou No melody 2 data
# CheapTrick_IWantYouToWantMe
#     CheapTrick_IWantYouToWantMe No melody 2 data
# CherryPoppinDaddies_ZootSuitRiot
#     CherryPoppinDaddies_ZootSuitRiot No melody 2 data
# ChrisBrown_Yeah
# ChristinaAguilera_GenieInABottle
#     ColdWarKids_HangMeUpToDry No melody 2 data
#     ChristinaAguilera_GenieInABottle No melody 2 data
# Chromeo_Tenderoni
#     Chromeo_Tenderoni No melody 2 data
# Chumbawamba_Tubthumping
#     Chumbawamba_Tubthumping No melody 2 data
# ColdWarKids_HangMeUpToDry
# Coldplay_InMyPlace
#     CountZero_Shake No melody 2 data
#     Coldplay_InMyPlace No melody 2 data
# Coldplay_Shiver
#     Coldplay_Shiver No melody 2 data
# CorinneBaileyRae_PutYourRecordsOn
#     CorinneBaileyRae_PutYourRecordsOn No melody 2 data
# CountZero_Shake
# CountingCrows_AccidentallyInLove
#     FlightOfTheConcords_BusinessTime No melody 2 data
#     CountingCrows_AccidentallyInLove No melody 2 data
# CrazyFrog_JingleBells
#     CrazyFrog_JingleBells No melody 2 data
# FleetwoodMac_Rhiannon
#     FleetwoodMac_Rhiannon No melody 2 data
# FlightOfTheConcords_BusinessTime
# FooFighters_AllMyLife
#     KaiserChiefs_Ruby No melody 2 data
#     FooFighters_AllMyLife No melody 2 data
# Incubus_Drive
#     Incubus_Drive No melody 2 data
# Inxs_NeedYouTonight
#     Inxs_NeedYouTonight No melody 2 data
# KaiserChiefs_Ruby
# Kansas_CarryOnMyWaywardSon
#     KennyChesney_SheThinksMyTractorsSexy No melody 2 data
#     Kansas_CarryOnMyWaywardSon No melody 2 data
# KanyeWest_LoveLockdown
#     KanyeWest_LoveLockdown No melody 2 data
# KeithUrban_IToldYouSo
#     KeithUrban_IToldYouSo No melody 2 data
# KennyChesney_SheThinksMyTractorsSexy
# KingsOfLeon_SexOnFire
#     Korn_FreakOnALeash No melody 2 data
#     KingsOfLeon_SexOnFire No melody 2 data
# Kiss_RockAndRollAllNite
#     Kiss_RockAndRollAllNite No melody 2 data
# Knack_MySharona
#     Knack_MySharona No melody 2 data
# Korn_FreakOnALeash
# KtTunstall_BlackHorseAndTheCherryTree
#     KtTunstall_BlackHorseAndTheCherryTree No melody 2 data
# KtTunstall_SuddenlyISee
#     KtTunstall_SuddenlyISee No melody 2 data
# LaRoux_Bulletproof
#     LaRoux_Bulletproof No melody 2 data
# LadyGagaFeaturingBeyonce_Telephone
#     LadyGagaFeaturingBeyonce_Telephone No melody 2 data
# LadyGaga_BadRomance
#     LennyKravitz_AreYouGonnaGoMyWay No melody 2 data
#     LadyGaga_BadRomance No melody 2 data
# LadyGaga_BornThisWay
#     LadyGaga_BornThisWay No melody 2 data
# LambOfGod_Requiem
#     LambOfGod_Requiem No melody 2 data
# LennyKravitz_AreYouGonnaGoMyWay
# LilyAllen_NotFair
#     Live_IAlone No melody 2 data
#     LilyAllen_NotFair No melody 2 data
# LinkinPark_InTheEnd
#     LinkinPark_InTheEnd No melody 2 data
# Lit_MyOwnWorstEnemy
#     Lit_MyOwnWorstEnemy No melody 2 data
# Live_IAlone
# LoquilloYLosTrogloditas_CadillacSolitario
#     Maroon5_ThisLove No melody 2 data
#     LoquilloYLosTrogloditas_CadillacSolitario No melody 2 data
# LosLobos_LaBamba
#     LosLobos_LaBamba No melody 2 data
# LynyrdSkynyrd_FreeBird
#     LynyrdSkynyrd_FreeBird No melody 2 data
# Maroon5_ThisLove
# MartinaMcbride_ThisOnesForTheGirls
#     McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe No melody 2 data
#     MartinaMcbride_ThisOnesForTheGirls No melody 2 data
# MarvinGaye_IHeardItThroughTheGrapevine
#     MarvinGaye_IHeardItThroughTheGrapevine No melody 2 data
# MarvinGaye_WhatsGoingOn
#     MarvinGaye_WhatsGoingOn No melody 2 data
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
# MichaelJackson_BeatIt
#     MileyCyrus_7Things No melody 2 data
#     MichaelJackson_BeatIt No melody 2 data
# MightyMightyBosstones_WheredYouGo
#     MightyMightyBosstones_WheredYouGo No melody 2 data
# MikeOldfield_Quicksilver
#     MikeOldfield_Quicksilver No melody 2 data
# MileyCyrus_7Things
# MirandaCosgrove_HeadphonesOn
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:    7.2s
#     Muffs_KidsInAmerica No melody 2 data
#     MirandaCosgrove_HeadphonesOn No melody 2 data
# Misfits_AstroZombies
#     Misfits_AstroZombies No melody 2 data
# ModestMouse_FloatOn
#     ModestMouse_FloatOn No melody 2 data
# Muffs_KidsInAmerica
# Muse_Hysteria
#     TaylorSwift_LoveStory No melody 2 data
#     Muse_Hysteria No melody 2 data
# TPain_Bartender
#     TPain_Bartender No melody 2 data
# TalkingHeads_PsychoKiller
#     TalkingHeads_PsychoKiller No melody 2 data
# TaylorSwift_LoveStory
# TaylorSwift_YouBelongWithMe
#     TheAllAmericanRejects_DirtyLittleSecret No melody 2 data
#     TaylorSwift_YouBelongWithMe No melody 2 data
# TearsForFears_EverybodyWantsToRuleTheWorld
#     TearsForFears_EverybodyWantsToRuleTheWorld No melody 2 data
# Tesla_ModernDayCowboy
#     Tesla_ModernDayCowboy No melody 2 data
# TheAllAmericanRejects_DirtyLittleSecret
# TheAllmanBrothersBand_RamblinMan
#     TheBeatles_WhatGoesOn No melody 2 data
#     TheAllmanBrothersBand_RamblinMan No melody 2 data
# TheBeatles_TwistAndShout
#     TheBeatles_TwistAndShout No melody 2 data
# TheBeatles_Wait
#     TheBeatles_Wait No melody 2 data
# TheBeatles_WhatGoesOn
# TheBeatles_WhenIm64
#     TheBeatles_WithinYouWithoutYou No melody 2 data
#     TheBeatles_WhenIm64 No melody 2 data
# TheBeatles_WhileMyGuitarGentlyWeeps
#     TheBeatles_WhileMyGuitarGentlyWeeps No melody 2 data
# TheBeatles_WithALittleHelpFromMyFriends
#     TheBeatles_WithALittleHelpFromMyFriends No melody 2 data
# TheBeatles_WithinYouWithoutYou
# TheBeatles_YellowSubmarine
#     TheBeatles_YellowSubmarine No melody 2 data
# TheBeatles_YouWontSeeMe
#     TheBeatles_YouWontSeeMe No melody 2 data
# TheBlackKeys_YourTouch
#     TheBlackKeys_YourTouch No melody 2 data
# TheBravery_Believe
#     TheBravery_Believe No melody 2 data
# TheBronx_FalseAlarm
#     TheKooks_Naive No melody 2 data
#     TheBronx_FalseAlarm No melody 2 data
# TheBronx_SixDaysAWeek
#     TheBronx_SixDaysAWeek No melody 2 data
# TheKillers_SomebodyToldMe
#     TheKillers_SomebodyToldMe No melody 2 data
# TheKooks_Naive
# TheLastGoodnight_PicturesOfYou
# ThirdEyeBlind_Jumper
#     TheLastGoodnight_PicturesOfYou No melody 2 data
# TheTurtles_HappyTogether
#     TheTurtles_HappyTogether No melody 2 data
# ThinLizzy_TheBoysAreBackInTown
#     ThinLizzy_TheBoysAreBackInTown No melody 2 data
#     ThirdEyeBlind_Jumper No melody 2 data
# ThirdEyeBlind_NeverLetYouGo
#     Tonic_IfYouCouldOnlySee No melody 2 data
#     ThirdEyeBlind_NeverLetYouGo No melody 2 data
# TomPettyAndTheHeartbreakers_IWontBackDown
#     TomPettyAndTheHeartbreakers_IWontBackDown No melody 2 data
# TomPetty_FreeFallin
#     TomPetty_FreeFallin No melody 2 data
# Tonic_IfYouCouldOnlySee
# TvOnTheRadio_WolfLikeMe
#     VanHalen_Jump No melody 2 data
#     TvOnTheRadio_WolfLikeMe No melody 2 data
# VampireWeekend_Cousins
#     VampireWeekend_Cousins No melody 2 data
# VampireWeekend_Holiday
#     VampireWeekend_Holiday No melody 2 data
# VanHalen_Jump
# VanillaIce_IceIceBaby
#     WildCherry_PlayThatFunkyMusic No melody 2 data
#     VanillaIce_IceIceBaby No melody 2 data
# VillagePeople_Ymca
#     VillagePeople_Ymca No melody 2 data
# Weezer_IslandInTheSun
#     Weezer_IslandInTheSun No melody 2 data
# WildCherry_PlayThatFunkyMusic
# Bach10_01AchGottundHerr
#     Bach10_04ChristeDuBeistand No melody 2 data
#     Bach10_01AchGottundHerr No melody 2 data
# Bach10_02AchLiebenChristen
#     Bach10_02AchLiebenChristen No melody 2 data
# Bach10_03ChristederdubistTagundLicht
#     Bach10_03ChristederdubistTagundLicht No melody 2 data
# Bach10_04ChristeDuBeistand
# Bach10_05DieNacht
#     Bach10_08FuerDeinenThron No melody 2 data
#     Bach10_05DieNacht No melody 2 data
# Bach10_06DieSonne
#     Bach10_06DieSonne No melody 2 data
# Bach10_07HerrGott
#     Bach10_07HerrGott No melody 2 data
# Bach10_08FuerDeinenThron
# Bach10_09Jesus
#     Bach10_09Jesus No melody 2 data
# Bach10_10NunBitten
#     Bach10_10NunBitten No melody 2 data
# Done!
# [Parallel(n_jobs=-1)]: Done 330 out of 330 | elapsed:    8.3s finished

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/" "melody3" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
# AimeeNorwich_Child
#     > already done!
# AimeeNorwich_Flying
#     > already done!
# AlexanderRoss_GoodbyeBolero
#     > already done!
# Auctioneer_OurFutureFaces
# BrandonWebster_YesSirICanFly
#     > already done!
#     > already done!
# AlexanderRoss_VelvetCurtain
# AvaLuna_Waterduct
#     > already done!
# CelestialShore_DieForUs
#     > already done!
# ClaraBerryAndWooldog_AirTraffic
# BigTroubles_Phantom
#     > already done!
# ClaraBerryAndWooldog_WaltzForMyVictims
#     > already done!
# ChrisJacoby_BoothShotLincoln
# ClaraBerryAndWooldog_Boys
#     > already done!
#     > already done!
# BrandonWebster_DontHearAThing
# Debussy_LenfantProdigue
# ClaraBerryAndWooldog_Stella
#     > already done!
#     > already done!
# Creepoid_OldTree
#     > already done!
#     > already done!
# ChrisJacoby_PigsFoot
# AmarLal_Rest
#     > already done!
#     > already done!
# DreamersOfTheGhetto_HeavyLove
# ClaraBerryAndWooldog_TheBadGuys
# EthanHein_GirlOnABridge
#     > already done!
#     > already done!
# EthanHein_HarmonicaFigure
#    EthanHein_HarmonicaFigure No melody 3 data
# FacesOnFilm_WaitingForGa
#     > already done!
# AmarLal_SpringDay1
#     > already done!
# EthanHein_1930sSynthAndUprightBass
#     > already done!
# CroqueMadame_Oil
#     > already done!
# Grants_PunchDrunk
#    Grants_PunchDrunk No melody 3 data
#     > already done!
# Handel_TornamiAVagheggiar
#     > already done!
# FamilyBand_Again
#     > already done!
#    EthanHein_BluesForNofi No melody 3 data
#     > already done!
# HeladoNegro_MitadDelMundo
# EthanHein_BluesForNofi
# HopAlong_SisterCities
#     > already done!
# HezekiahJones_BorrowedHeart
#     > already done!
# JoelHelander_IntheAtticBedroom
#     > already done!
# CroqueMadame_Pilot
#     > already done!
# InvisibleFamiliars_DisturbingWildlife
#     > already done!
#     > already done!
# KarimDouaidy_Hopscotch
# LizNelson_ImComingHome
#     > already done!
# JoelHelander_Definition
# MatthewEntwistle_DontYouEver
#     > already done!
#     > already done!
#     > already done!
# KarimDouaidy_Yatora
#     > already done!
# LizNelson_Rainfall
# MatthewEntwistle_FairerHopes
# MatthewEntwistle_TheArch
# MichaelKropf_AllGoodThings
#     > already done!
# LizNelson_Coldwar
# MusicDelta_Beatles
#     > already done!
#     > already done!
# Lushlife_ToynbeeSuite
# JoelHelander_ExcessiveResistancetoChange
#    Lushlife_ToynbeeSuite No melody 3 data
# MatthewEntwistle_AnEveningWithOliver
# MusicDelta_ChineseChaoZhou
#    MatthewEntwistle_AnEveningWithOliver No melody 3 data
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_ChineseXinJing
# Mozart_BesterJungling
# MusicDelta_BebopJazz
#     > already done!
#     > already done!
#     > already done!
# MatthewEntwistle_TheFlaxenField
# MusicDelta_ChineseDrama
# MatthewEntwistle_ImpressionsOfSaturn
#     > already done!
# Mozart_DiesBildnis
#     > already done!
# MusicDelta_ChineseHenan
# MusicDelta_Country2
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_Beethoven
# MusicDelta_ChineseYaoZu
# MusicDelta_Disco
#     > already done!
#     > already done!
# MusicDelta_FusionJazz
#     > already done!
# MusicDelta_Hendrix
#     > already done!
# MusicDelta_Britpop
# MusicDelta_CoolJazz
#     > already done!
#     > already done!
# MusicDelta_ChineseJiangNan
#     > already done!
# MusicDelta_FreeJazz
#     > already done!
#     > already done!
# MusicDelta_FunkJazz
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_Country1
# MusicDelta_Gospel
# MusicDelta_80sRock
# MusicDelta_InTheHalloftheMountainKing
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_LatinJazz
#     > already done!
#     > already done!
#     > already done!
# Meaxic_TakeAStep
# MusicDelta_GriegTrolltog
# MusicDelta_Punk
#     > already done!
# MusicDelta_ModalJazz
#     > already done!
#     > already done!
#     > already done!
# MusicDelta_Grunge
# MatthewEntwistle_Lontano
# MusicDelta_Reggae
#     > already done!
#     > already done!
# MusicDelta_Pachelbel
#     > already done!
#     > already done!
# MusicDelta_Rock
# Meaxic_YouListen
# MusicDelta_Shadows
#     > already done!
# MusicDelta_Rockabilly
#     > already done!
# MusicDelta_SpeedMetal
#     > already done!
# MusicDelta_Zeppelin
#     > already done!
#     > already done!
# NightPanther_Fire
# MusicDelta_SwingJazz
# Phoenix_ElzicsFarewell
#     > already done!
#     > already done!
#     > already done!
# Phoenix_BrokenPledgeChicagoReel
# MusicDelta_Vivaldi
#     > already done!
#     > already done!
#     > already done!
# PortStWillow_StayEven
#     > already done!
# Phoenix_LarkOnTheStrandDrummondCastle
#     > already done!
# Phoenix_ColliersDaughter
#     > already done!
# PurlingHiss_Lolita
#     > already done!
#     > already done!
# Phoenix_ScotchMorris
# SecretMountains_HighHorse
#     > already done!
# Phoenix_SeanCaughlinsTheScartaglen
#     > already done!
# Schubert_Erstarrung
#     > already done!
#     > already done!
# Snowmine_Curfews
#     > already done!
# Schumann_Mignon
# SweetLights_YouLetMeDown
# TablaBreakbeatScience_MoodyPlucks
#     > already done!
#    TablaBreakbeatScience_MoodyPlucks No melody 3 data
# TablaBreakbeatScience_PhaseTransition
#     > already done!
# StevenClark_Bounty
#    TablaBreakbeatScience_PhaseTransition No melody 3 data
# TablaBreakbeatScience_RockSteady
#    TablaBreakbeatScience_RockSteady No melody 3 data
# TablaBreakbeatScience_Scorpio
#    TablaBreakbeatScience_Scorpio No melody 3 data
#     > already done!
# StrandOfOaks_Spacestation
# TheDistricts_Vermont
# TablaBreakbeatScience_Vger
#    TablaBreakbeatScience_Vger No melody 3 data
# TablaBreakbeatScience_WhoIsIt
#    TablaBreakbeatScience_WhoIsIt No melody 3 data
#     > already done!
# TablaBreakbeatScience_Animoog
# TheSoSoGlos_Emergency
#    TablaBreakbeatScience_Animoog No melody 3 data
# TablaBreakbeatScience_CaptainSky
#    TablaBreakbeatScience_CaptainSky No melody 3 data
# TablaBreakbeatScience_MiloVsMongo
#    TablaBreakbeatScience_MiloVsMongo No melody 3 data
#     > already done!
#     > already done!
# TheScarletBrand_LesFleursDuMal
# Wolf_DieBekherte
#     > already done!
# AmadeusRedux_SchubertMovement2
#    AmadeusRedux_SchubertMovement2 No melody 3 data
# AmadeusRedux_SchubertMovement3
#    AmadeusRedux_SchubertMovement3 No melody 3 data
# BarefootSisters_RedJetta
#    BarefootSisters_RedJetta No melody 3 data
# CassandraJenkins_PerfectDay
#    CassandraJenkins_PerfectDay No melody 3 data
#     > already done!
# Allegria_MendelssohnMovement1
#    Allegria_MendelssohnMovement1 No melody 3 data
# AmadeusRedux_MozartAllegro
#    AmadeusRedux_MozartAllegro No melody 3 data
#     > already done!
# CatMartino_IPromise
#    DeadMilkmen_PrisonersCinema No melody 3 data
#    CatMartino_IPromise No melody 3 data
# Cayetana_MissThing
#    Cayetana_MissThing No melody 3 data
# DahkaBand_SoldierMan
#    DahkaBand_SoldierMan No melody 3 data
# DeadMilkmen_PrisonersCinema
# DeclareAString_MendelssohnPianoTrio1Movement1
#    DeclareAString_MendelssohnPianoTrio1Movement1 No melody 3 data
# DeclareAString_MendelssohnPianoTrio1Movement2
#    DeclareAString_MendelssohnPianoTrio1Movement2 No melody 3 data
# FallingSparks_Improvisation1
#    FallingSparks_Improvisation1 No melody 3 data
# FallingSparks_Improvisation2
#    FallingSparks_Improvisation2 No melody 3 data
# FallingSparks_Improvisation3
#    FallingSparks_Improvisation3 No melody 3 data
# FallingSparks_PakKlongTalad
#    FallingSparks_PakKlongTalad No melody 3 data
# FennelCartwright_DearTessie
#    FennelCartwright_DearTessie No melody 3 data
# FennelCartwright_FlowerDrumSong
#    FennelCartwright_FlowerDrumSong No melody 3 data
#    HopsNVinyl_ChickenFriedSteak No melody 3 data
# HopsNVinyl_ChickenFriedSteak
#    FruitCathedral_KeepMeRunnin No melody 3 data
# FruitCathedral_KeepMeRunnin
#    FilthyBird_IdLikeToKnow No melody 3 data
# FilthyBird_IdLikeToKnow
#    FennelCartwright_WinterLake No melody 3 data
# FennelCartwright_WinterLake
# HopsNVinyl_HoneyBrown
#    Karachacha_Volamos No melody 3 data
#    HopsNVinyl_HoneyBrown No melody 3 data
# HopsNVinyl_ReignCheck
#    HopsNVinyl_ReignCheck No melody 3 data
# HopsNVinyl_WidowsWalk
#    HopsNVinyl_WidowsWalk No melody 3 data
# Karachacha_Volamos
# Katzn_CharlieKnox
#    MatthewEntwistle_ReturnToVenezia No melody 3 data
#    Katzn_CharlieKnox No melody 3 data
# LewisAndClarke_TheSilverSea
#    LewisAndClarke_TheSilverSea No melody 3 data
# LittleTybee_TheAlchemist
#    LittleTybee_TheAlchemist No melody 3 data
# MatthewEntwistle_ReturnToVenezia
# MidnightBlue_HuntingSeason
#    PatternIsMovement_SaveMe No melody 3 data
#    MidnightBlue_HuntingSeason No melody 3 data
# MidnightBlue_StarsAreScreaming
#    MidnightBlue_StarsAreScreaming No melody 3 data
# MutualBenefit_NotForNothing
#    MutualBenefit_NotForNothing No melody 3 data
# PatternIsMovement_SaveMe
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#    PoliceHearingDepartment_SchumannMovement1 No melody 3 data
#    PeterMatthewBauer_YouAlwaysLookForSomeoneLost No melody 3 data
# Plasma_GoodShout
#    Plasma_GoodShout No melody 3 data
# PoliceHearingDepartment_Brahms
#    PoliceHearingDepartment_Brahms No melody 3 data
# PoliceHearingDepartment_SchumannMovement1
# PoliceHearingDepartment_SchumannMovement2
#    PoliceHearingDepartment_VivaldiMovement3 No melody 3 data
#    PoliceHearingDepartment_SchumannMovement2 No melody 3 data
# PoliceHearingDepartment_VivaldiMovement1
#    PoliceHearingDepartment_VivaldiMovement1 No melody 3 data
# PoliceHearingDepartment_VivaldiMovement2
#    PoliceHearingDepartment_VivaldiMovement2 No melody 3 data
# PoliceHearingDepartment_VivaldiMovement3
# QuantumChromos_Circuits
#    QuantumChromos_Circuits No melody 3 data
# RodrigoBonelli_BalladForLaura
#    RodrigoBonelli_BalladForLaura No melody 3 data
# SasquatchConnection_BoomBoxing
#    SasquatchConnection_BoomBoxing No melody 3 data
# SasquatchConnection_HolyClamsBatman
#    SasquatchConnection_HolyClamsBatman No melody 3 data
# SasquatchConnection_Illuminati
#    SlowGhost_FirstSnow No melody 3 data
#    SasquatchConnection_Illuminati No melody 3 data
# SasquatchConnection_Struttin
#    SasquatchConnection_Struttin No melody 3 data
# SasquatchConnection_ThanksALatte
#    SasquatchConnection_ThanksALatte No melody 3 data
# SlowGhost_FirstSnow
# SlowGhost_MidnightGroove
#    SlowGhost_MidnightGroove No melody 3 data
# SlowGhost_Peanut
#    SlowGhost_Peanut No melody 3 data
# SlowGhost_YoureAMystery
#    SlowGhost_YoureAMystery No melody 3 data
# SongYiJeon_TwoMoons
#    SongYiJeon_TwoMoons No melody 3 data
# Sweat_AlmostAlways
#    Sweat_Mesozoic No melody 3 data
#    Sweat_AlmostAlways No melody 3 data
# Sweat_Anecdoche
#    Sweat_Anecdoche No melody 3 data
# Sweat_Elegy
#    Sweat_Elegy No melody 3 data
# Sweat_Mesozoic
# Sweat_Sn1572
# Sweat_Tact
#    Sweat_Sn1572 No melody 3 data
#    Sweat_Tact No melody 3 data
# TemperedElan_DorothyJeanne
#    TemperedElan_DorothyJeanne No melody 3 data
# TemperedElan_WiseOne
#    TemperedElan_WiseOne No melody 3 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#    TheFranckDuo_FranckViolinSonataInAMajorMovement1 No melody 3 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
#    TheFranckDuo_FranckViolinSonataInAMajorMovement2 No melody 3 data
# TheKitchenettes_Alive
#    TheKitchenettes_Alive No melody 3 data
# TheNoHoStringOrchestra_ElgarMovement1
#    TheNoHoStringOrchestra_ElgarMovement1 No melody 3 data
# TheNoHoStringOrchestra_ElgarMovement2
#    TheNoHoStringOrchestra_ElgarMovement2 No melody 3 data
# TheNoHoStringOrchestra_ElgarMovement3
#    TheNoHoStringOrchestra_ElgarMovement3 No melody 3 data
# TheTonTons_Lush
#    TheTonTons_Lush No melody 3 data
# TleilaxEnsemble_Late
#    TleilaxEnsemble_Late No melody 3 data
# TleilaxEnsemble_MelancholyFlowers
#    TleilaxEnsemble_MelancholyFlowers No melody 3 data
# Torres_NewSkin
#    Torres_NewSkin No melody 3 data
# TrevorAndTheSoundwaves_AloneAndSad
#    TrevorAndTheSoundwaves_AloneAndSad No melody 3 data
# Verdi_IlTrovatore
#    Verdi_IlTrovatore No melody 3 data
# AHa_TakeOnMe
#    AHa_TakeOnMe No melody 3 data
# AcDc_BackInBlack
#    AcDc_BackInBlack No melody 3 data
# Adele_SomeoneLikeYou
#    Adele_SomeoneLikeYou No melody 3 data
# Aerosmith_LoveInAnElevator
#    Aerosmith_LoveInAnElevator No melody 3 data
# AlanisMorissette_YouOughtaKnow
#    AlanisMorissette_YouOughtaKnow No melody 3 data
# AllThatRemains_Chiron
#    AllThatRemains_Chiron No melody 3 data
# AnEndlessSporadic_Anything
#    AnEndlessSporadic_Anything No melody 3 data
# Anberlin_TheFeelGoodDrag
#    Anberlin_TheFeelGoodDrag No melody 3 data
# ArcadeFire_BlackMirror
#    ArcadeFire_BlackMirror No melody 3 data
# ArcticMonkeys_Brainstorm
#    ArcticMonkeys_Brainstorm No melody 3 data
# BillyIdol_WhiteWedding
#    BillyIdol_WhiteWedding No melody 3 data
# BillySquier_TheStroke
#    BillySquier_TheStroke No melody 3 data
# BlackEyedPeas_IGottaFeeling
#    Blondie_OneWayOrAnother No melody 3 data
#    BlackEyedPeas_IGottaFeeling No melody 3 data
# BlackSabbath_WarPigs
#    BlackSabbath_WarPigs No melody 3 data
# Blink182_AllTheSmallThings
#    Blink182_AllTheSmallThings No melody 3 data
# Blondie_OneWayOrAnother
# BlueOysterCult_DontFearTheReaper
#    BlueOysterCult_DontFearTheReaper No melody 3 data
# BobSeger_OldTimeRockAndRoll
#    BobSeger_OldTimeRockAndRoll No melody 3 data
# Boston_MoreThanAFeeling
#    Boston_MoreThanAFeeling No melody 3 data
# BradPaisley_MudOnTheTires
#    BradPaisley_MudOnTheTires No melody 3 data
#    BrunoMars_MarryYou No melody 3 data
# BrunoMars_MarryYou
#    BrunoMars_JustTheWayYouAre No melody 3 data
# BrunoMars_JustTheWayYouAre
#    BrunoMars_Grenade No melody 3 data
# BrunoMars_Grenade
#    BrooksDunn_HillbillyDeluxe No melody 3 data
# BrooksDunn_HillbillyDeluxe
# BryanAdams_SummerOf69
#    CarrieUnderwood_HomeSweetHome No melody 3 data
#    BryanAdams_SummerOf69 No melody 3 data
# Bush_Machinehead
#    Bush_Machinehead No melody 3 data
# CarlDouglas_KungFuFighting
#    CarlDouglas_KungFuFighting No melody 3 data
# CarrieUnderwood_HomeSweetHome
# CeeloGreen_ForgetYou
#    ChrisBrown_Yeah No melody 3 data
#    CeeloGreen_ForgetYou No melody 3 data
# CheapTrick_IWantYouToWantMe
#    CheapTrick_IWantYouToWantMe No melody 3 data
# CherryPoppinDaddies_ZootSuitRiot
#    CherryPoppinDaddies_ZootSuitRiot No melody 3 data
# ChrisBrown_Yeah
# ChristinaAguilera_GenieInABottle
#    ColdWarKids_HangMeUpToDry No melody 3 data
#    ChristinaAguilera_GenieInABottle No melody 3 data
# Chromeo_Tenderoni
#    Chromeo_Tenderoni No melody 3 data
# Chumbawamba_Tubthumping
#    Chumbawamba_Tubthumping No melody 3 data
# ColdWarKids_HangMeUpToDry
# Coldplay_InMyPlace
#    CountZero_Shake No melody 3 data
#    Coldplay_InMyPlace No melody 3 data
# Coldplay_Shiver
#    Coldplay_Shiver No melody 3 data
# CorinneBaileyRae_PutYourRecordsOn
#    CorinneBaileyRae_PutYourRecordsOn No melody 3 data
# CountZero_Shake
# CountingCrows_AccidentallyInLove
#    FlightOfTheConcords_BusinessTime No melody 3 data
#    CountingCrows_AccidentallyInLove No melody 3 data
# CrazyFrog_JingleBells
#    CrazyFrog_JingleBells No melody 3 data
# FleetwoodMac_Rhiannon
#    FleetwoodMac_Rhiannon No melody 3 data
# FlightOfTheConcords_BusinessTime
# FooFighters_AllMyLife
#    KaiserChiefs_Ruby No melody 3 data
#    FooFighters_AllMyLife No melody 3 data
# Incubus_Drive
#    Incubus_Drive No melody 3 data
# Inxs_NeedYouTonight
#    Inxs_NeedYouTonight No melody 3 data
# KaiserChiefs_Ruby
#    KennyChesney_SheThinksMyTractorsSexy No melody 3 data
# KennyChesney_SheThinksMyTractorsSexy
#    KeithUrban_IToldYouSo No melody 3 data
# KeithUrban_IToldYouSo
#    KanyeWest_LoveLockdown No melody 3 data
# KanyeWest_LoveLockdown
#    Kansas_CarryOnMyWaywardSon No melody 3 data
# Kansas_CarryOnMyWaywardSon
# KingsOfLeon_SexOnFire
#    Korn_FreakOnALeash No melody 3 data
#    KingsOfLeon_SexOnFire No melody 3 data
# Kiss_RockAndRollAllNite
#    Kiss_RockAndRollAllNite No melody 3 data
# Knack_MySharona
#    Knack_MySharona No melody 3 data
# Korn_FreakOnALeash
# KtTunstall_BlackHorseAndTheCherryTree
#    LadyGagaFeaturingBeyonce_Telephone No melody 3 data
#    KtTunstall_BlackHorseAndTheCherryTree No melody 3 data
# KtTunstall_SuddenlyISee
#    KtTunstall_SuddenlyISee No melody 3 data
# LaRoux_Bulletproof
#    LaRoux_Bulletproof No melody 3 data
# LadyGagaFeaturingBeyonce_Telephone
# LadyGaga_BadRomance
#    LadyGaga_BadRomance No melody 3 data
# LadyGaga_BornThisWay
#    LadyGaga_BornThisWay No melody 3 data
# LambOfGod_Requiem
#    LambOfGod_Requiem No melody 3 data
# LennyKravitz_AreYouGonnaGoMyWay
#    LennyKravitz_AreYouGonnaGoMyWay No melody 3 data
# LilyAllen_NotFair
#    Live_IAlone No melody 3 data
#    LilyAllen_NotFair No melody 3 data
# LinkinPark_InTheEnd
#    LinkinPark_InTheEnd No melody 3 data
# Lit_MyOwnWorstEnemy
#    Lit_MyOwnWorstEnemy No melody 3 data
# Live_IAlone
#    LoquilloYLosTrogloditas_CadillacSolitario No melody 3 data
#    Maroon5_ThisLove No melody 3 data
# Maroon5_ThisLove
#    LynyrdSkynyrd_FreeBird No melody 3 data
# LynyrdSkynyrd_FreeBird
#    LosLobos_LaBamba No melody 3 data
# LosLobos_LaBamba
# LoquilloYLosTrogloditas_CadillacSolitario
# MartinaMcbride_ThisOnesForTheGirls
#    MartinaMcbride_ThisOnesForTheGirls No melody 3 data
# MarvinGaye_IHeardItThroughTheGrapevine
#    MarvinGaye_IHeardItThroughTheGrapevine No melody 3 data
# MarvinGaye_WhatsGoingOn
#    MarvinGaye_WhatsGoingOn No melody 3 data
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
#    McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe No melody 3 data
# MichaelJackson_BeatIt
#    MichaelJackson_BeatIt No melody 3 data
# MightyMightyBosstones_WheredYouGo
#    MightyMightyBosstones_WheredYouGo No melody 3 data
# MikeOldfield_Quicksilver
#    MikeOldfield_Quicksilver No melody 3 data
# MileyCyrus_7Things
#    MileyCyrus_7Things No melody 3 data
# MirandaCosgrove_HeadphonesOn
#    Muffs_KidsInAmerica No melody 3 data
#    MirandaCosgrove_HeadphonesOn No melody 3 data
# Misfits_AstroZombies
#    Misfits_AstroZombies No melody 3 data
# ModestMouse_FloatOn
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:    7.5s
#    ModestMouse_FloatOn No melody 3 data
# Muffs_KidsInAmerica
# Muse_Hysteria
#    TaylorSwift_LoveStory No melody 3 data
#    Muse_Hysteria No melody 3 data
# TPain_Bartender
#    TPain_Bartender No melody 3 data
# TalkingHeads_PsychoKiller
#    TalkingHeads_PsychoKiller No melody 3 data
# TaylorSwift_LoveStory
# TaylorSwift_YouBelongWithMe
#    TheAllAmericanRejects_DirtyLittleSecret No melody 3 data
#    TaylorSwift_YouBelongWithMe No melody 3 data
# TearsForFears_EverybodyWantsToRuleTheWorld
#    TearsForFears_EverybodyWantsToRuleTheWorld No melody 3 data
# Tesla_ModernDayCowboy
#    Tesla_ModernDayCowboy No melody 3 data
# TheAllAmericanRejects_DirtyLittleSecret
# TheAllmanBrothersBand_RamblinMan
#    TheBeatles_WhatGoesOn No melody 3 data
#    TheAllmanBrothersBand_RamblinMan No melody 3 data
# TheBeatles_TwistAndShout
#    TheBeatles_TwistAndShout No melody 3 data
# TheBeatles_Wait
#    TheBeatles_Wait No melody 3 data
# TheBeatles_WhatGoesOn
# TheBeatles_WhenIm64
#    TheBeatles_WithinYouWithoutYou No melody 3 data
#    TheBeatles_WhenIm64 No melody 3 data
# TheBeatles_WhileMyGuitarGentlyWeeps
#    TheBeatles_WhileMyGuitarGentlyWeeps No melody 3 data
# TheBeatles_WithALittleHelpFromMyFriends
#    TheBeatles_WithALittleHelpFromMyFriends No melody 3 data
# TheBeatles_WithinYouWithoutYou
# TheBeatles_YellowSubmarine
#    TheBravery_Believe No melody 3 data
#    TheBeatles_YellowSubmarine No melody 3 data
# TheBeatles_YouWontSeeMe
#    TheBeatles_YouWontSeeMe No melody 3 data
# TheBlackKeys_YourTouch
#    TheBlackKeys_YourTouch No melody 3 data
# TheBravery_Believe
# TheBronx_FalseAlarm
# TheKillers_SomebodyToldMe
#    TheBronx_FalseAlarm No melody 3 data
# TheBronx_SixDaysAWeek
#    TheBronx_SixDaysAWeek No melody 3 data
#    TheKooks_Naive No melody 3 data
# TheKooks_Naive
#    TheKillers_SomebodyToldMe No melody 3 data
# TheLastGoodnight_PicturesOfYou
#    ThirdEyeBlind_Jumper No melody 3 data
#    TheLastGoodnight_PicturesOfYou No melody 3 data
# TheTurtles_HappyTogether
#    TheTurtles_HappyTogether No melody 3 data
# ThinLizzy_TheBoysAreBackInTown
#    ThinLizzy_TheBoysAreBackInTown No melody 3 data
# ThirdEyeBlind_Jumper
# ThirdEyeBlind_NeverLetYouGo
#    Tonic_IfYouCouldOnlySee No melody 3 data
#    ThirdEyeBlind_NeverLetYouGo No melody 3 data
# TomPettyAndTheHeartbreakers_IWontBackDown
#    TomPettyAndTheHeartbreakers_IWontBackDown No melody 3 data
# TomPetty_FreeFallin
#    TomPetty_FreeFallin No melody 3 data
# Tonic_IfYouCouldOnlySee
#    VanHalen_Jump No melody 3 data
# VanHalen_Jump
#    VampireWeekend_Holiday No melody 3 data
# VampireWeekend_Holiday
#    VampireWeekend_Cousins No melody 3 data
# VampireWeekend_Cousins
#    TvOnTheRadio_WolfLikeMe No melody 3 data
# TvOnTheRadio_WolfLikeMe
# VanillaIce_IceIceBaby
#    VanillaIce_IceIceBaby No melody 3 data
# VillagePeople_Ymca
#    VillagePeople_Ymca No melody 3 data
# Weezer_IslandInTheSun
#    Weezer_IslandInTheSun No melody 3 data
# WildCherry_PlayThatFunkyMusic
#    WildCherry_PlayThatFunkyMusic No melody 3 data
# Bach10_01AchGottundHerr
#    Bach10_04ChristeDuBeistand No melody 3 data
#    Bach10_01AchGottundHerr No melody 3 data
# Bach10_02AchLiebenChristen
#    Bach10_02AchLiebenChristen No melody 3 data
# Bach10_03ChristederdubistTagundLicht
#    Bach10_03ChristederdubistTagundLicht No melody 3 data
# Bach10_04ChristeDuBeistand
#    Bach10_08FuerDeinenThron No melody 3 data
# Bach10_08FuerDeinenThron
#    Bach10_07HerrGott No melody 3 data
# Bach10_07HerrGott
#    Bach10_06DieSonne No melody 3 data
# Bach10_06DieSonne
#    Bach10_05DieNacht No melody 3 data
# Bach10_05DieNacht
# Bach10_09Jesus
#    Bach10_09Jesus No melody 3 data
# Bach10_10NunBitten
#    Bach10_10NunBitten No melody 3 data
# Done!
# [Parallel(n_jobs=-1)]: Done 330 out of 330 | elapsed:    8.6s finished

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/" "multif0_incomplete" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
#     > already done!
# AimeeNorwich_Child
#     > already done!
# AimeeNorwich_Flying
# CelestialShore_DieForUs
#     > already done!
# AlexanderRoss_GoodbyeBolero
#     > already done!
# AlexanderRoss_VelvetCurtain
#     > already done!
# AmarLal_Rest
#     > already done!
# AmarLal_SpringDay1
#     > already done!
# Auctioneer_OurFutureFaces
#     > already done!
# AvaLuna_Waterduct
#     > already done!
# BigTroubles_Phantom
#     > already done!
# BrandonWebster_DontHearAThing
#     > already done!
# BrandonWebster_YesSirICanFly
#     > already done!
#     > already done!
# ChrisJacoby_BoothShotLincoln
#     > already done!
# ChrisJacoby_PigsFoot
#     > already done!
# ClaraBerryAndWooldog_AirTraffic
#     > already done!
# ClaraBerryAndWooldog_Boys
#     > already done!
# ClaraBerryAndWooldog_Stella
#     > already done!
# ClaraBerryAndWooldog_TheBadGuys
#     > already done!
# ClaraBerryAndWooldog_WaltzForMyVictims
#     > already done!
# Creepoid_OldTree
#     > already done!
# CroqueMadame_Oil
#     > already done!
# CroqueMadame_Pilot
#     > already done!
#     > already done!
# Debussy_LenfantProdigue
#     > already done!
# DreamersOfTheGhetto_HeavyLove
# EthanHein_1930sSynthAndUprightBass
#     > already done!
# EthanHein_BluesForNofi
#     > already done!
# EthanHein_GirlOnABridge
#     > already done!
# EthanHein_HarmonicaFigure
#     EthanHein_HarmonicaFigure No multif0 data
# FacesOnFilm_WaitingForGa
#     > already done!
# FamilyBand_Again
#     > already done!
# Grants_PunchDrunk
#     > already done!
# Handel_TornamiAVagheggiar
#     > already done!
# HeladoNegro_MitadDelMundo
#     > already done!
# HezekiahJones_BorrowedHeart
#     > already done!
# HopAlong_SisterCities
#     > already done!
# InvisibleFamiliars_DisturbingWildlife
#     > already done!
# JoelHelander_Definition
#     > already done!
# JoelHelander_ExcessiveResistancetoChange
#     > already done!
# JoelHelander_IntheAtticBedroom
#     > already done!
# KarimDouaidy_Hopscotch
#     > already done!
# KarimDouaidy_Yatora
#     > already done!
# LizNelson_Coldwar
#     > already done!
# LizNelson_ImComingHome
#     > already done!
# LizNelson_Rainfall
#     > already done!
# Lushlife_ToynbeeSuite
#     > already done!
# MatthewEntwistle_AnEveningWithOliver
#     > already done!
# MatthewEntwistle_ImpressionsOfSaturn
# MatthewEntwistle_DontYouEver
#     > already done!
# MatthewEntwistle_FairerHopes
#     > already done!
#     > already done!
# MatthewEntwistle_Lontano
# MatthewEntwistle_TheArch
#     > already done!
#     > already done!
# MatthewEntwistle_TheFlaxenField
#     > already done!
# Meaxic_YouListen
# Meaxic_TakeAStep
#     > already done!
#     > already done!
# MichaelKropf_AllGoodThings
#     > already done!
# Mozart_BesterJungling
#     > already done!
#     > already done!
# Mozart_DiesBildnis
#     > already done!
# MusicDelta_80sRock
#     > already done!
# MusicDelta_Beatles
#     > already done!
# MusicDelta_BebopJazz
#     > already done!
# MusicDelta_Beethoven
# MusicDelta_Britpop
# MusicDelta_ChineseDrama
#     > already done!
# MusicDelta_ChineseChaoZhou
#     > already done!
#     > already done!
# MusicDelta_ChineseHenan
#     > already done!
# MusicDelta_ChineseJiangNan
#     > already done!
# MusicDelta_ChineseXinJing
#     > already done!
# MusicDelta_ChineseYaoZu
#     > already done!
# MusicDelta_CoolJazz
#     > already done!
# MusicDelta_Country1
#     > already done!
# MusicDelta_Country2
#     > already done!
# MusicDelta_Disco
#     > already done!
# MusicDelta_FreeJazz
#     > already done!
# MusicDelta_FunkJazz
#     > already done!
# MusicDelta_FusionJazz
#     > already done!
# MusicDelta_Gospel
#     > already done!
# MusicDelta_GriegTrolltog
#     > already done!
# MusicDelta_Grunge
#     > already done!
# MusicDelta_Hendrix
#     > already done!
# MusicDelta_InTheHalloftheMountainKing
#     > already done!
#     > already done!
# MusicDelta_LatinJazz
#     > already done!
# MusicDelta_ModalJazz
#     > already done!
# MusicDelta_Pachelbel
#     > already done!
# MusicDelta_Punk
#     > already done!
# MusicDelta_Reggae
#     > already done!
# MusicDelta_Rock
#     > already done!
# MusicDelta_Rockabilly
# MusicDelta_Shadows
#     > already done!
# MusicDelta_SpeedMetal
#     > already done!
# MusicDelta_SwingJazz
#     > already done!
# MusicDelta_Vivaldi
#     > already done!
# MusicDelta_Zeppelin
#     > already done!
# NightPanther_Fire
#     > already done!
# Phoenix_BrokenPledgeChicagoReel
#     > already done!
# Phoenix_ColliersDaughter
#     > already done!
# Phoenix_ElzicsFarewell
#     > already done!
# Phoenix_LarkOnTheStrandDrummondCastle
#     > already done!
# Phoenix_ScotchMorris
#     > already done!
# Phoenix_SeanCaughlinsTheScartaglen
#     > already done!
# PortStWillow_StayEven
#     > already done!
#     > already done!
# PurlingHiss_Lolita
# Schubert_Erstarrung
#     > already done!
# Schumann_Mignon
#     > already done!
# SecretMountains_HighHorse
#     > already done!
# Snowmine_Curfews
#     > already done!
# StevenClark_Bounty
#     > already done!
# StrandOfOaks_Spacestation
#     > already done!
# SweetLights_YouLetMeDown
#     > already done!
# TablaBreakbeatScience_Animoog
#     > already done!
# TablaBreakbeatScience_CaptainSky
#     > already done!
# TablaBreakbeatScience_MiloVsMongo
#     TablaBreakbeatScience_MiloVsMongo No multif0 data
# TablaBreakbeatScience_MoodyPlucks
#     TablaBreakbeatScience_MoodyPlucks No multif0 data
# TablaBreakbeatScience_PhaseTransition
#     > already done!
# TablaBreakbeatScience_RockSteady
#     TablaBreakbeatScience_RockSteady No multif0 data
# TablaBreakbeatScience_Scorpio
#     TablaBreakbeatScience_Scorpio No multif0 data
# TablaBreakbeatScience_Vger
#     TablaBreakbeatScience_Vger No multif0 data
# TablaBreakbeatScience_WhoIsIt
#     > already done!
#     > already done!
# TheDistricts_Vermont
#     > already done!
# TheScarletBrand_LesFleursDuMal
# TheSoSoGlos_Emergency
# CassandraJenkins_PerfectDay
#     > already done!
# Wolf_DieBekherte
#     > already done!
# Allegria_MendelssohnMovement1
#     Allegria_MendelssohnMovement1 No multif0 data
# AmadeusRedux_MozartAllegro
#     AmadeusRedux_MozartAllegro No multif0 data
# AmadeusRedux_SchubertMovement2
#     AmadeusRedux_SchubertMovement2 No multif0 data
# AmadeusRedux_SchubertMovement3
#     AmadeusRedux_SchubertMovement3 No multif0 data
# BarefootSisters_RedJetta
#     BarefootSisters_RedJetta No multif0 data
#     > already done!
# CatMartino_IPromise
#     > already done!
# Cayetana_MissThing
#     > already done!
# DahkaBand_SoldierMan
#     DahkaBand_SoldierMan No multif0 data
# DeadMilkmen_PrisonersCinema
#     > already done!
# DeclareAString_MendelssohnPianoTrio1Movement1
#     DeclareAString_MendelssohnPianoTrio1Movement1 No multif0 data
# DeclareAString_MendelssohnPianoTrio1Movement2
#     DeclareAString_MendelssohnPianoTrio1Movement2 No multif0 data
# FallingSparks_Improvisation1
#     FallingSparks_Improvisation1 No multif0 data
# FallingSparks_Improvisation2
#     FallingSparks_Improvisation2 No multif0 data
# FallingSparks_Improvisation3
#     FallingSparks_Improvisation3 No multif0 data
# FallingSparks_PakKlongTalad
#     FallingSparks_PakKlongTalad No multif0 data
# FennelCartwright_DearTessie
#     FennelCartwright_DearTessie No multif0 data
# FennelCartwright_FlowerDrumSong
#     FennelCartwright_FlowerDrumSong No multif0 data
# FennelCartwright_WinterLake
#     FennelCartwright_WinterLake No multif0 data
# FilthyBird_IdLikeToKnow
#     > already done!
# FruitCathedral_KeepMeRunnin
#     > already done!
# HopsNVinyl_ChickenFriedSteak
#     HopsNVinyl_ChickenFriedSteak No multif0 data
# HopsNVinyl_HoneyBrown
#     HopsNVinyl_HoneyBrown No multif0 data
# HopsNVinyl_ReignCheck
#     HopsNVinyl_ReignCheck No multif0 data
# HopsNVinyl_WidowsWalk
#     HopsNVinyl_WidowsWalk No multif0 data
# Karachacha_Volamos
#     Karachacha_Volamos No multif0 data
# Katzn_CharlieKnox
#     Katzn_CharlieKnox No multif0 data
# LewisAndClarke_TheSilverSea
#     LewisAndClarke_TheSilverSea No multif0 data
# LittleTybee_TheAlchemist
#     > already done!
# MatthewEntwistle_ReturnToVenezia
#     MatthewEntwistle_ReturnToVenezia No multif0 data
# MidnightBlue_HuntingSeason
#     > already done!
# MidnightBlue_StarsAreScreaming
#     > already done!
# MutualBenefit_NotForNothing
#     > already done!
# PatternIsMovement_SaveMe
#     > already done!
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#     > already done!
# Plasma_GoodShout
#     > already done!
# PoliceHearingDepartment_Brahms
#     PoliceHearingDepartment_Brahms No multif0 data
# PoliceHearingDepartment_SchumannMovement1
#     PoliceHearingDepartment_SchumannMovement1 No multif0 data
# PoliceHearingDepartment_SchumannMovement2
#     Sweat_Mesozoic No multif0 data
#     PoliceHearingDepartment_SchumannMovement2 No multif0 data
# PoliceHearingDepartment_VivaldiMovement1
#     PoliceHearingDepartment_VivaldiMovement1 No multif0 data
# PoliceHearingDepartment_VivaldiMovement2
#     PoliceHearingDepartment_VivaldiMovement2 No multif0 data
# PoliceHearingDepartment_VivaldiMovement3
#     PoliceHearingDepartment_VivaldiMovement3 No multif0 data
# QuantumChromos_Circuits
#     QuantumChromos_Circuits No multif0 data
# RodrigoBonelli_BalladForLaura
#     RodrigoBonelli_BalladForLaura No multif0 data
# SasquatchConnection_BoomBoxing
#     SasquatchConnection_BoomBoxing No multif0 data
# SasquatchConnection_HolyClamsBatman
#     SasquatchConnection_HolyClamsBatman No multif0 data
# SasquatchConnection_Illuminati
#     SasquatchConnection_Illuminati No multif0 data
# SasquatchConnection_Struttin
#     SasquatchConnection_Struttin No multif0 data
# SasquatchConnection_ThanksALatte
#     SasquatchConnection_ThanksALatte No multif0 data
# SlowGhost_FirstSnow
#     > already done!
# SlowGhost_MidnightGroove
#     > already done!
# SlowGhost_Peanut
#     > already done!
# SlowGhost_YoureAMystery
#     > already done!
# SongYiJeon_TwoMoons
#     SongYiJeon_TwoMoons No multif0 data
# Sweat_AlmostAlways
#     Sweat_AlmostAlways No multif0 data
# Sweat_Anecdoche
#     Sweat_Anecdoche No multif0 data
# Sweat_Elegy
#     Sweat_Elegy No multif0 data
# Sweat_Mesozoic
# Sweat_Sn1572
#     Sweat_Sn1572 No multif0 data
# Sweat_Tact
#     Sweat_Tact No multif0 data
# TemperedElan_DorothyJeanne
#     TemperedElan_DorothyJeanne No multif0 data
# TemperedElan_WiseOne
#     TemperedElan_WiseOne No multif0 data
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#     > already done!
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
#     TheFranckDuo_FranckViolinSonataInAMajorMovement2 No multif0 data
# TheKitchenettes_Alive
#     > already done!
# TheNoHoStringOrchestra_ElgarMovement1
#     TheNoHoStringOrchestra_ElgarMovement1 No multif0 data
# TheNoHoStringOrchestra_ElgarMovement2
#     TheNoHoStringOrchestra_ElgarMovement2 No multif0 data
# TheNoHoStringOrchestra_ElgarMovement3
#     TheNoHoStringOrchestra_ElgarMovement3 No multif0 data
# TheTonTons_Lush
#     > already done!
# TleilaxEnsemble_Late
#     TleilaxEnsemble_Late No multif0 data
# TleilaxEnsemble_MelancholyFlowers
#     TleilaxEnsemble_MelancholyFlowers No multif0 data
# Torres_NewSkin
#     > already done!
# TrevorAndTheSoundwaves_AloneAndSad
#     > already done!
# Verdi_IlTrovatore
#     Verdi_IlTrovatore No multif0 data
# AHa_TakeOnMe
#     > already done!
# AcDc_BackInBlack
#     > already done!
# Adele_SomeoneLikeYou
#     > already done!
# Aerosmith_LoveInAnElevator
#     > already done!
# AlanisMorissette_YouOughtaKnow
#     > already done!
# AllThatRemains_Chiron
#     > already done!
# AnEndlessSporadic_Anything
#     > already done!
# Anberlin_TheFeelGoodDrag
#     > already done!
# ArcadeFire_BlackMirror
#     > already done!
# ArcticMonkeys_Brainstorm
#     > already done!
# BillyIdol_WhiteWedding
#     > already done!
# BillySquier_TheStroke
#     > already done!
# BlackEyedPeas_IGottaFeeling
#     > already done!
# BlackSabbath_WarPigs
#     > already done!
# Blink182_AllTheSmallThings
#     > already done!
# Blondie_OneWayOrAnother
#     > already done!
# BlueOysterCult_DontFearTheReaper
#     > already done!
# BobSeger_OldTimeRockAndRoll
#     > already done!
# Boston_MoreThanAFeeling
#     > already done!
# BradPaisley_MudOnTheTires
#     > already done!
# BrooksDunn_HillbillyDeluxe
#     > already done!
# BrunoMars_Grenade
#     > already done!
# BrunoMars_JustTheWayYouAre
#     > already done!
# BrunoMars_MarryYou
#     > already done!
# BryanAdams_SummerOf69
#     > already done!
# Bush_Machinehead
#     > already done!
# CarlDouglas_KungFuFighting
#     > already done!
# CarrieUnderwood_HomeSweetHome
#     > already done!
# CeeloGreen_ForgetYou
#     > already done!
# CheapTrick_IWantYouToWantMe
#     > already done!
# CherryPoppinDaddies_ZootSuitRiot
#     > already done!
# ChrisBrown_Yeah
#     > already done!
# ChristinaAguilera_GenieInABottle
#     > already done!
# Chromeo_Tenderoni
#     > already done!
# Chumbawamba_Tubthumping
#     Chumbawamba_Tubthumping No multif0 data
# ColdWarKids_HangMeUpToDry
#     > already done!
# Coldplay_InMyPlace
#     > already done!
# Coldplay_Shiver
#     > already done!
# CorinneBaileyRae_PutYourRecordsOn
#     > already done!
# CountZero_Shake
#     > already done!
# CountingCrows_AccidentallyInLove
#     > already done!
# CrazyFrog_JingleBells
#     CrazyFrog_JingleBells No multif0 data
# FleetwoodMac_Rhiannon
#     > already done!
# FlightOfTheConcords_BusinessTime
#     > already done!
# FooFighters_AllMyLife
# Incubus_Drive
#     > already done!
#     > already done!
# Inxs_NeedYouTonight
#     > already done!
# KaiserChiefs_Ruby
#     > already done!
# Kansas_CarryOnMyWaywardSon
#     > already done!
# KanyeWest_LoveLockdown
#     > already done!
# KeithUrban_IToldYouSo
#     > already done!
# KennyChesney_SheThinksMyTractorsSexy
#     > already done!
# KingsOfLeon_SexOnFire
#     KingsOfLeon_SexOnFire No multif0 data
# Kiss_RockAndRollAllNite
#     > already done!
# Knack_MySharona
#     > already done!
# Korn_FreakOnALeash
#     > already done!
# KtTunstall_BlackHorseAndTheCherryTree
#     > already done!
# KtTunstall_SuddenlyISee
#     > already done!
# LaRoux_Bulletproof
#     > already done!
# LadyGagaFeaturingBeyonce_Telephone
#     > already done!
# LadyGaga_BadRomance
#     > already done!
# LadyGaga_BornThisWay
#     > already done!
# LambOfGod_Requiem
#     > already done!
# LennyKravitz_AreYouGonnaGoMyWay
#     > already done!
# LilyAllen_NotFair
#     > already done!
# LinkinPark_InTheEnd
#     > already done!
# Lit_MyOwnWorstEnemy
#     > already done!
# Live_IAlone
#     > already done!
# LoquilloYLosTrogloditas_CadillacSolitario
#     LoquilloYLosTrogloditas_CadillacSolitario No multif0 data
# LosLobos_LaBamba
#     > already done!
# LynyrdSkynyrd_FreeBird
#     > already done!
# Maroon5_ThisLove
#     > already done!
# MartinaMcbride_ThisOnesForTheGirls
#     > already done!
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:    8.0s
# MarvinGaye_IHeardItThroughTheGrapevine
#     > already done!
# MarvinGaye_WhatsGoingOn
#     > already done!
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
#     > already done!
# MichaelJackson_BeatIt
#     > already done!
# MightyMightyBosstones_WheredYouGo
#     > already done!
# MikeOldfield_Quicksilver
#     MikeOldfield_Quicksilver No multif0 data
# MileyCyrus_7Things
#     > already done!
# MirandaCosgrove_HeadphonesOn
#     > already done!
# Misfits_AstroZombies
#     > already done!
# ModestMouse_FloatOn
#     > already done!
# Muffs_KidsInAmerica
#     > already done!
# Muse_Hysteria
#     > already done!
# TPain_Bartender
#     > already done!
# TalkingHeads_PsychoKiller
#     > already done!
# TaylorSwift_LoveStory
#     > already done!
# TaylorSwift_YouBelongWithMe
#     > already done!
# TearsForFears_EverybodyWantsToRuleTheWorld
#     > already done!
# Tesla_ModernDayCowboy
#     > already done!
# TheAllAmericanRejects_DirtyLittleSecret
#     > already done!
# TheAllmanBrothersBand_RamblinMan
#     > already done!
# TheBeatles_TwistAndShout
#     TheBeatles_TwistAndShout No multif0 data
# TheBeatles_Wait
#     TheBeatles_Wait No multif0 data
# TheBeatles_WhatGoesOn
#     TheBeatles_WhatGoesOn No multif0 data
# TheBeatles_WhenIm64
#     TheBeatles_WhenIm64 No multif0 data
# TheBeatles_WhileMyGuitarGentlyWeeps
#     TheBeatles_WhileMyGuitarGentlyWeeps No multif0 data
# TheBeatles_WithALittleHelpFromMyFriends
#     TheBeatles_WithALittleHelpFromMyFriends No multif0 data
# TheBeatles_WithinYouWithoutYou
#     TheBeatles_WithinYouWithoutYou No multif0 data
# TheBeatles_YellowSubmarine
#     TheBeatles_YellowSubmarine No multif0 data
# TheBeatles_YouWontSeeMe
#     TheBeatles_YouWontSeeMe No multif0 data
# TheBlackKeys_YourTouch
#     TheBlackKeys_YourTouch No multif0 data
# TheBravery_Believe
#     TheBravery_Believe No multif0 data
# TheBronx_FalseAlarm
#     > already done!
# TheBronx_SixDaysAWeek
#     > already done!
# TheKillers_SomebodyToldMe
#     > already done!
# TheKooks_Naive
#     > already done!
# TheLastGoodnight_PicturesOfYou
#     > already done!
# TheTurtles_HappyTogether
#     > already done!
# ThinLizzy_TheBoysAreBackInTown
#     > already done!
# ThirdEyeBlind_Jumper
#     > already done!
# ThirdEyeBlind_NeverLetYouGo
#     > already done!
# TomPettyAndTheHeartbreakers_IWontBackDown
#     > already done!
# TomPetty_FreeFallin
#     > already done!
# Tonic_IfYouCouldOnlySee
#     > already done!
# TvOnTheRadio_WolfLikeMe
#     TvOnTheRadio_WolfLikeMe No multif0 data
# VampireWeekend_Cousins
#     > already done!
# VampireWeekend_Holiday
# VanHalen_Jump
#     > already done!
#     VanHalen_Jump No multif0 data
#     > already done!
# VanillaIce_IceIceBaby
# VillagePeople_Ymca
#     > already done!
# Weezer_IslandInTheSun
#     WildCherry_PlayThatFunkyMusic No multif0 data
#     Weezer_IslandInTheSun No multif0 data
# WildCherry_PlayThatFunkyMusic
# Bach10_01AchGottundHerr
#     > computing CQT for Bach10_01AchGottundHerr_MIX.wav
#     Saved data for Bach10_01AchGottundHerr_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bach10_02AchLiebenChristen
#     > computing CQT for Bach10_02AchLiebenChristen_MIX.wav
#     Saved data for Bach10_02AchLiebenChristen_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bach10_03ChristederdubistTagundLicht
#     > computing CQT for Bach10_03ChristederdubistTagundLicht_MIX.wav
#     Saved data for Bach10_03ChristederdubistTagundLicht_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bach10_04ChristeDuBeistand
#     > computing CQT for Bach10_04ChristeDuBeistand_MIX.wav
#     Saved data for Bach10_04ChristeDuBeistand_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bach10_05DieNacht
#     > computing CQT for Bach10_05DieNacht_MIX.wav
#     Saved data for Bach10_05DieNacht_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bach10_06DieSonne
#     > computing CQT for Bach10_06DieSonne_MIX.wav
#     Saved data for Bach10_06DieSonne_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bach10_07HerrGott
#     > computing CQT for Bach10_07HerrGott_MIX.wav
#     Saved data for Bach10_07HerrGott_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bach10_08FuerDeinenThron
#     > computing CQT for Bach10_08FuerDeinenThron_MIX.wav
#     Saved data for Bach10_08FuerDeinenThron_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bach10_09Jesus
#     > computing CQT for Bach10_09Jesus_MIX.wav
#     Saved data for Bach10_09Jesus_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Bach10_10NunBitten
#     > computing CQT for Bach10_10NunBitten_MIX.wav
#     Saved data for Bach10_10NunBitten_multif0_incomplete to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/
# Done!
# [Parallel(n_jobs=-1)]: Done 330 out of 330 | elapsed:  1.3min finished

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/" "bass" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
#     > using precomputed CQT for AClassicEducation_NightOwl_MIX.wav
# AimeeNorwich_Child
#     > using precomputed CQT for AimeeNorwich_Child_MIX.wav
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
#     > using precomputed CQT for AimeeNorwich_Flying_MIX.wav
#     > using precomputed CQT for AlexanderRoss_GoodbyeBolero_MIX.wav
# AlexanderRoss_VelvetCurtain
# AmarLal_Rest
#     > using precomputed CQT for AlexanderRoss_VelvetCurtain_MIX.wav
# AmarLal_SpringDay1
#     > using precomputed CQT for AmarLal_Rest_MIX.wav
#     > using precomputed CQT for AmarLal_SpringDay1_MIX.wav
# Auctioneer_OurFutureFaces
#     > using precomputed CQT for Auctioneer_OurFutureFaces_MIX.wav
# AvaLuna_Waterduct
#     > using precomputed CQT for AvaLuna_Waterduct_MIX.wav
# BigTroubles_Phantom
#     > using precomputed CQT for BigTroubles_Phantom_MIX.wav
# BrandonWebster_DontHearAThing
#     > using precomputed CQT for BrandonWebster_DontHearAThing_MIX.wav
# BrandonWebster_YesSirICanFly
#     > using precomputed CQT for BrandonWebster_YesSirICanFly_MIX.wav
# CelestialShore_DieForUs
#     > using precomputed CQT for CelestialShore_DieForUs_MIX.wav
# ChrisJacoby_BoothShotLincoln
#     > using precomputed CQT for ChrisJacoby_BoothShotLincoln_MIX.wav
# ChrisJacoby_PigsFoot
#     > using precomputed CQT for ChrisJacoby_PigsFoot_MIX.wav
# ClaraBerryAndWooldog_AirTraffic
#     > using precomputed CQT for ClaraBerryAndWooldog_AirTraffic_MIX.wav
# ClaraBerryAndWooldog_Boys
#     > using precomputed CQT for ClaraBerryAndWooldog_Boys_MIX.wav
# ClaraBerryAndWooldog_Stella
#     > using precomputed CQT for ClaraBerryAndWooldog_Stella_MIX.wav
#     > using precomputed CQT for ClaraBerryAndWooldog_WaltzForMyVictims_MIX.wav
# ClaraBerryAndWooldog_TheBadGuys
#     > using precomputed CQT for ClaraBerryAndWooldog_TheBadGuys_MIX.wav
# ClaraBerryAndWooldog_WaltzForMyVictims
# Creepoid_OldTree
#     > using precomputed CQT for Creepoid_OldTree_MIX.wav
# CroqueMadame_Oil
#     > using precomputed CQT for CroqueMadame_Oil_MIX.wav
# CroqueMadame_Pilot
#     > using precomputed CQT for CroqueMadame_Pilot_MIX.wav
# Debussy_LenfantProdigue
#     > using precomputed CQT for Debussy_LenfantProdigue_MIX.wav
# DreamersOfTheGhetto_HeavyLove
#     > using precomputed CQT for DreamersOfTheGhetto_HeavyLove_MIX.wav
# EthanHein_1930sSynthAndUprightBass
#     > using precomputed CQT for EthanHein_1930sSynthAndUprightBass_MIX.wav
# EthanHein_BluesForNofi
# EthanHein_GirlOnABridge
#     > using precomputed CQT for EthanHein_GirlOnABridge_MIX.wav
#     > computing CQT for EthanHein_BluesForNofi_MIX.wav
#     Saved data for EthanHein_BluesForNofi_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# EthanHein_HarmonicaFigure
#     > computing CQT for EthanHein_HarmonicaFigure_MIX.wav
#     Saved data for EthanHein_HarmonicaFigure_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# FacesOnFilm_WaitingForGa
#     > using precomputed CQT for FacesOnFilm_WaitingForGa_MIX.wav
#     Saved data for BrandonWebster_YesSirICanFly_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# FamilyBand_Again
#     > using precomputed CQT for FamilyBand_Again_MIX.wav
#     Saved data for AmarLal_SpringDay1_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Grants_PunchDrunk
#     > computing CQT for Grants_PunchDrunk_MIX.wav

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/" "vocal" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"

# %%
data_dir = ("/scratch/rmb456/multif0_ismir2017/" +
    "training_data_with_blur/multif0_complete")

# %%
import medleydb as mdb
import glob
import shutil
import os

# %%
mtracks = list(mtracks)

# %%
new_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/bad_extras"

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['EXTRA'])
good_count = 0
bad_count = 0

for mtrack in mtracks:
    bad_mtrack = False
    for stem in mtrack.stems.values():
        if stem.pitch_estimate_pyin is not None:

            if 'p' in stem.f0_type:
                bad_mtrack = True
                print(stem.instrument)
    if bad_mtrack:
        bad_count += 1
        print mtrack.track_id
    else:
        good_count += 1
        
        
    if bad_mtrack:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                bname = os.path.basename(f)
                os.rename(f, os.path.join(new_dir, bname))

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['V1'])
for mtrack in mtracks:
    if mtrack.has_melody:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                print(f)
                os.remove(f)

# %%
rm /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/*/TrevorAndTheSoundwaves_AloneAndSad_multif0_complete*.npy

# %%
x = 5
print(x)
