# %%
import numpy as np
import os
import glob

# %%
cd /scratch/rmb456/multif0_ismir2017/training_data_with_blur/
# Out:
# /scratch/rmb456/multif0_ismir2017/training_data_with_blur

# %%
ls

# %%
dirname = 'melody1'
files = glob.glob(os.path.join(dirname, '*.npz'))

for f in files:
    data = np.load(f)
    
    bname = os.path.basename(f).split('.')[0]
    print(bname)
    input_bname = "{}_input.npy".format(bname)
    output_bname = "{}_output.npy".format(bname)
    input_path = os.path.join(dirname, 'inputs', input_bname)
    output_path = os.path.join(dirname, 'outputs', output_bname)
    
    np.save(input_path, data['data_in'])
    np.save(output_path, data['data_out'])

# %%
dirname = 'melody2'
files = glob.glob(os.path.join(dirname, '*.npz'))

for f in files:
    data = np.load(f)
    
    bname = os.path.basename(f).split('.')[0]
    print(bname)
    input_bname = "{}_input.npy".format(bname)
    output_bname = "{}_output.npy".format(bname)
    input_path = os.path.join(dirname, 'inputs', input_bname)
    output_path = os.path.join(dirname, 'outputs', output_bname)
    
    np.save(input_path, data['data_in'])
    np.save(output_path, data['data_out'])

# %%
dirname = 'melody3'
files = glob.glob(os.path.join(dirname, '*.npz'))

for f in files:
    data = np.load(f)
    
    bname = os.path.basename(f).split('.')[0]
    print(bname)
    input_bname = "{}_input.npy".format(bname)
    output_bname = "{}_output.npy".format(bname)
    input_path = os.path.join(dirname, 'inputs', input_bname)
    output_path = os.path.join(dirname, 'outputs', output_bname)
    
    np.save(input_path, data['data_in'])
    np.save(output_path, data['data_out'])

# %%
dirname = 'multif0_complete'
files = glob.glob(os.path.join(dirname, '*.npz'))

for f in files:
    
    bname = os.path.basename(f).split('.')[0]
    print(bname)
    input_bname = "{}_input.npy".format(bname)
    output_bname = "{}_output.npy".format(bname)
    input_path = os.path.join(dirname, 'inputs', input_bname)
    output_path = os.path.join(dirname, 'outputs', output_bname)
    
    if os.path.exists(input_path) and os.path.exists(output_path):
        print("    > Already done!")
        continue
    
    try:
        data = np.load(f)
        np.save(input_path, data['data_in'])
        np.save(output_path, data['data_out'])
    except:
        print("failed on {}".format(f))
        os.remove(f)
# Out:
# AvaLuna_Waterduct_multif0_complete
#     > Already done!
# ClaraBerryAndWooldog_TheBadGuys_multif0_complete
#     > Already done!
# MusicDelta_Hendrix_multif0_complete
#     > Already done!
# MusicDelta_LatinJazz_multif0_complete
#     > Already done!
# MusicDelta_SwingJazz_multif0_complete
#     > Already done!
# AmarLal_SpringDay1_multif0_complete
#     > Already done!
# DeadMilkmen_PrisonersCinema_multif0_complete
#     > Already done!
# TheDistricts_Vermont_multif0_complete
#     > Already done!
# MusicDelta_FusionJazz_multif0_complete
#     > Already done!
# BradPaisley_MudOnTheTires_multif0_complete
#     > Already done!
# FacesOnFilm_WaitingForGa_multif0_complete
#     > Already done!
# Adele_SomeoneLikeYou_multif0_complete
#     > Already done!
# ChrisJacoby_PigsFoot_multif0_complete
#     > Already done!
# Misfits_AstroZombies_multif0_complete
#     > Already done!
# TalkingHeads_PsychoKiller_multif0_complete
#     > Already done!
# TheBronx_FalseAlarm_multif0_complete
#     > Already done!
# NightPanther_Fire_multif0_complete
#     > Already done!
# MusicDelta_Beatles_multif0_complete
#     > Already done!
# Phoenix_ScotchMorris_multif0_complete
#     > Already done!
# TablaBreakbeatScience_WhoIsIt_multif0_complete
#     > Already done!
# AmarLal_Rest_multif0_complete
#     > Already done!
# MusicDelta_Country2_multif0_complete
#     > Already done!
# TablaBreakbeatScience_Animoog_multif0_complete
#     > Already done!
# Creepoid_OldTree_multif0_complete
#     > Already done!
# KarimDouaidy_Yatora_multif0_complete
#     > Already done!
# Snowmine_Curfews_multif0_complete
#     > Already done!
# BryanAdams_SummerOf69_multif0_complete
#     > Already done!
# MatthewEntwistle_TheFlaxenField_multif0_complete
#     > Already done!
# MatthewEntwistle_ImpressionsOfSaturn_multif0_complete
#     > Already done!
# LaRoux_Bulletproof_multif0_complete
#     > Already done!
# FilthyBird_IdLikeToKnow_multif0_complete
#     > Already done!
# MusicDelta_ModalJazz_multif0_complete
#     > Already done!
# AlexanderRoss_VelvetCurtain_multif0_complete
#     > Already done!
# AlanisMorissette_YouOughtaKnow_multif0_complete
#     > Already done!
# LilyAllen_NotFair_multif0_complete
#     > Already done!
# SlowGhost_Peanut_multif0_complete
#     > Already done!
# MatthewEntwistle_DontYouEver_multif0_complete
#     > Already done!
# ThinLizzy_TheBoysAreBackInTown_multif0_complete
#     > Already done!
# MusicDelta_Grunge_multif0_complete
#     > Already done!
# FooFighters_AllMyLife_multif0_complete
#     > Already done!
# LizNelson_ImComingHome_multif0_complete
#     > Already done!
# Mozart_BesterJungling_multif0_complete
#     > Already done!
# Korn_FreakOnALeash_multif0_complete
#     > Already done!
# MusicDelta_Pachelbel_multif0_complete
#     > Already done!
# AClassicEducation_NightOwl_multif0_complete
#     > Already done!
# EthanHein_GirlOnABridge_multif0_complete
#     > Already done!
# TheBronx_SixDaysAWeek_multif0_complete
#     > Already done!
# MusicDelta_SpeedMetal_multif0_complete
#     > Already done!
# FruitCathedral_KeepMeRunnin_multif0_complete
#     > Already done!
# Meaxic_TakeAStep_multif0_complete
# JoelHelander_Definition_multif0_complete
#     > Already done!
# MusicDelta_FunkJazz_multif0_complete
#     > Already done!
# TablaBreakbeatScience_CaptainSky_multif0_complete
#     > Already done!
# ClaraBerryAndWooldog_Boys_multif0_complete
#     > Already done!
# CheapTrick_IWantYouToWantMe_multif0_complete
#     > Already done!
# AlexanderRoss_GoodbyeBolero_multif0_complete
#     > Already done!
# Coldplay_InMyPlace_multif0_complete
#     > Already done!
# MusicDelta_Country1_multif0_complete
#     > Already done!
# TheTonTons_Lush_multif0_complete
#     > Already done!
# MusicDelta_ChineseXinJing_multif0_complete
#     > Already done!
# Mozart_DiesBildnis_multif0_complete
#     > Already done!
# TheScarletBrand_LesFleursDuMal_multif0_complete
#     > Already done!
# PatternIsMovement_SaveMe_multif0_complete
#     > Already done!
# Phoenix_ColliersDaughter_multif0_complete
#     > Already done!
# AimeeNorwich_Flying_multif0_complete
# Handel_TornamiAVagheggiar_multif0_complete
#     > Already done!
# MusicDelta_ChineseChaoZhou_multif0_complete
#     > Already done!
# MusicDelta_ChineseJiangNan_multif0_complete
#     > Already done!
# MusicDelta_80sRock_multif0_complete
#     > Already done!
# KtTunstall_SuddenlyISee_multif0_complete
#     > Already done!
# Debussy_LenfantProdigue_multif0_complete
#     > Already done!
# MusicDelta_Shadows_multif0_complete
#     > Already done!
# TheKitchenettes_Alive_multif0_complete
#     > Already done!
# MusicDelta_Reggae_multif0_complete
#     > Already done!
# MusicDelta_FreeJazz_multif0_complete
#     > Already done!
# Phoenix_ElzicsFarewell_multif0_complete
#     > Already done!
# LennyKravitz_AreYouGonnaGoMyWay_multif0_complete
#     > Already done!
# Wolf_DieBekherte_multif0_complete
#     > Already done!
# FamilyBand_Again_multif0_complete
#     > Already done!
# Bush_Machinehead_multif0_complete
#     > Already done!
# MusicDelta_Disco_multif0_complete
#     > Already done!
# BrandonWebster_DontHearAThing_multif0_complete
#     > Already done!
# Lit_MyOwnWorstEnemy_multif0_complete
#     > Already done!
# AimeeNorwich_Child_multif0_complete
#     > Already done!
# MusicDelta_Gospel_multif0_complete
#     > Already done!
# TheAllmanBrothersBand_RamblinMan_multif0_complete
#     > Already done!
# InvisibleFamiliars_DisturbingWildlife_multif0_complete
#     > Already done!
# TheSoSoGlos_Emergency_multif0_complete
#     > Already done!
# MusicDelta_Britpop_multif0_complete
#     > Already done!
# StrandOfOaks_Spacestation_multif0_complete
#     > Already done!
# BlackEyedPeas_IGottaFeeling_multif0_complete
#     > Already done!
# Knack_MySharona_multif0_complete
#     > Already done!
# MusicDelta_Punk_multif0_complete
#     > Already done!
# BlackSabbath_WarPigs_multif0_complete
#     > Already done!
# EthanHein_1930sSynthAndUprightBass_multif0_complete
#     > Already done!
# PurlingHiss_Lolita_multif0_complete
#     > Already done!
# MusicDelta_ChineseDrama_multif0_complete
#     > Already done!
# KanyeWest_LoveLockdown_multif0_complete
#     > Already done!
# JoelHelander_IntheAtticBedroom_multif0_complete
# MatthewEntwistle_AnEveningWithOliver_multif0_complete
#     > Already done!
# VampireWeekend_Holiday_multif0_complete
#     > Already done!
# AnEndlessSporadic_Anything_multif0_complete
#     > Already done!
# ClaraBerryAndWooldog_WaltzForMyVictims_multif0_complete
#     > Already done!
# MidnightBlue_StarsAreScreaming_multif0_complete
#     > Already done!
# MusicDelta_BebopJazz_multif0_complete
#     > Already done!
# MightyMightyBosstones_WheredYouGo_multif0_complete
#     > Already done!
# MusicDelta_Rock_multif0_complete
#     > Already done!
# Plasma_GoodShout_multif0_complete
#     > Already done!
# VampireWeekend_Cousins_multif0_complete
#     > Already done!
# LizNelson_Rainfall_multif0_complete
#     > Already done!
# Kansas_CarryOnMyWaywardSon_multif0_complete
#     > Already done!
# AcDc_BackInBlack_multif0_complete
#     > Already done!
# MidnightBlue_HuntingSeason_multif0_complete
#     > Already done!
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_multif0_complete
#     > Already done!
# MusicDelta_Zeppelin_multif0_complete
#     > Already done!
# Muffs_KidsInAmerica_multif0_complete
#     > Already done!
# LynyrdSkynyrd_FreeBird_multif0_complete
#     > Already done!
# MirandaCosgrove_HeadphonesOn_multif0_complete
#     > Already done!
# SweetLights_YouLetMeDown_multif0_complete
#     > Already done!
# TrevorAndTheSoundwaves_AloneAndSad_multif0_complete
# SlowGhost_FirstSnow_multif0_complete
#     > Already done!
# MusicDelta_ChineseYaoZu_multif0_complete
#     > Already done!
# PortStWillow_StayEven_multif0_complete
#     > Already done!
# MusicDelta_GriegTrolltog_multif0_complete
#     > Already done!
# TablaBreakbeatScience_PhaseTransition_multif0_complete
#     > Already done!
# MutualBenefit_NotForNothing_multif0_complete
#     > Already done!
# BigTroubles_Phantom_multif0_complete
#     > Already done!
# JoelHelander_ExcessiveResistancetoChange_multif0_complete
#     > Already done!
# TheLastGoodnight_PicturesOfYou_multif0_complete
#     > Already done!
# MusicDelta_ChineseHenan_multif0_complete
#     > Already done!
# MusicDelta_CoolJazz_multif0_complete
#     > Already done!
# Phoenix_LarkOnTheStrandDrummondCastle_multif0_complete
#     > Already done!
# LizNelson_Coldwar_multif0_complete
#     > Already done!
# Coldplay_Shiver_multif0_complete
#     > Already done!
# Auctioneer_OurFutureFaces_multif0_complete
#     > Already done!
# MichaelKropf_AllGoodThings_multif0_complete
#     > Already done!
# CarrieUnderwood_HomeSweetHome_multif0_complete
#     > Already done!
# MusicDelta_InTheHalloftheMountainKing_multif0_complete
#     > Already done!
# ColdWarKids_HangMeUpToDry_multif0_complete
#     > Already done!
# HopAlong_SisterCities_multif0_complete
#     > Already done!
# Grants_PunchDrunk_multif0_complete
#     > Already done!
# AllThatRemains_Chiron_multif0_complete
#     > Already done!
# CountingCrows_AccidentallyInLove_multif0_complete
#     > Already done!
# KennyChesney_SheThinksMyTractorsSexy_multif0_complete
#     > Already done!
# CassandraJenkins_PerfectDay_multif0_complete
#     > Already done!
# Phoenix_SeanCaughlinsTheScartaglen_multif0_complete
#     > Already done!
# KarimDouaidy_Hopscotch_multif0_complete
#     > Already done!
# CatMartino_IPromise_multif0_complete
#     > Already done!
# DreamersOfTheGhetto_HeavyLove_multif0_complete
#     > Already done!
# CroqueMadame_Pilot_multif0_complete
#     > Already done!
# Meaxic_YouListen_multif0_complete
#     > Already done!
# HeladoNegro_MitadDelMundo_multif0_complete
#     > Already done!
# EthanHein_BluesForNofi_multif0_complete
#     > Already done!
# MusicDelta_Rockabilly_multif0_complete
#     > Already done!
# Muse_Hysteria_multif0_complete
#     > Already done!
# MusicDelta_Beethoven_multif0_complete
#     > Already done!
# Cayetana_MissThing_multif0_complete
#     > Already done!
# SecretMountains_HighHorse_multif0_complete
#     > Already done!
# KeithUrban_IToldYouSo_multif0_complete
#     > Already done!
# ChrisJacoby_BoothShotLincoln_multif0_complete
#     > Already done!
# MusicDelta_Vivaldi_multif0_complete
#     > Already done!
# MatthewEntwistle_FairerHopes_multif0_complete
#     > Already done!
# LittleTybee_TheAlchemist_multif0_complete
#     > Already done!
# FlightOfTheConcords_BusinessTime_multif0_complete
# MatthewEntwistle_TheArch_multif0_complete
#     > Already done!
# ClaraBerryAndWooldog_Stella_multif0_complete
#     > Already done!
# CountZero_Shake_multif0_complete
#     > Already done!
# Torres_NewSkin_multif0_complete
#     > Already done!
# TheFranckDuo_FranckViolinSonataInAMajorMovement1_multif0_complete
#     > Already done!
# StevenClark_Bounty_multif0_complete
#     > Already done!
# HezekiahJones_BorrowedHeart_multif0_complete
#     > Already done!
# MarvinGaye_WhatsGoingOn_multif0_complete
#     > Already done!
# Lushlife_ToynbeeSuite_multif0_complete
#     > Already done!
# SlowGhost_YoureAMystery_multif0_complete
#     > Already done!
# Schubert_Erstarrung_multif0_complete
#     > Already done!
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe_multif0_complete
#     > Already done!
# LambOfGod_Requiem_multif0_complete
#     > Already done!
# ThirdEyeBlind_Jumper_multif0_complete
#     > Already done!
# CroqueMadame_Oil_multif0_complete
#     > Already done!
# BrandonWebster_YesSirICanFly_multif0_complete
#     > Already done!
# ClaraBerryAndWooldog_AirTraffic_multif0_complete
#     > Already done!
# LadyGagaFeaturingBeyonce_Telephone_multif0_complete
#     > Already done!
# Phoenix_BrokenPledgeChicagoReel_multif0_complete
#     > Already done!
# Schumann_Mignon_multif0_complete
#     > Already done!
# SlowGhost_MidnightGroove_multif0_complete
#     > Already done!
# CelestialShore_DieForUs_multif0_complete
# CeeloGreen_ForgetYou_multif0_complete
#     > Already done!
# MatthewEntwistle_Lontano_multif0_complete
#     > Already done!

# %%
dirname = 'multif0_incomplete'
files = glob.glob(os.path.join(dirname, '*.npz'))

for f in files:
    
    bname = os.path.basename(f).split('.')[0]
    print(bname)
    input_bname = "{}_input.npy".format(bname)
    output_bname = "{}_output.npy".format(bname)
    input_path = os.path.join(dirname, 'inputs', input_bname)
    output_path = os.path.join(dirname, 'outputs', output_bname)
    
    if os.path.exists(input_path) and os.path.exists(output_path):
        print("    > Already done!")
        continue
    
    try:
        data = np.load(f)
        np.save(input_path, data['data_in'])
        np.save(output_path, data['data_out'])
    except:
        print("failed on {}".format(f))
        os.remove(f)
# Out:
# TheKitchenettes_Alive_multif0_incomplete
#     > Already done!
# MusicDelta_Zeppelin_multif0_incomplete
#     > Already done!
# CeeloGreen_ForgetYou_multif0_incomplete
#     > Already done!
# MichaelKropf_AllGoodThings_multif0_incomplete
#     > Already done!
# MatthewEntwistle_ImpressionsOfSaturn_multif0_incomplete
#     > Already done!
# BrandonWebster_YesSirICanFly_multif0_incomplete
#     > Already done!
# LadyGagaFeaturingBeyonce_Telephone_multif0_incomplete
#     > Already done!
# TheTonTons_Lush_multif0_incomplete
#     > Already done!
# MusicDelta_Gospel_multif0_incomplete
#     > Already done!
# Snowmine_Curfews_multif0_incomplete
#     > Already done!
# LambOfGod_Requiem_multif0_incomplete
#     > Already done!
# CroqueMadame_Pilot_multif0_incomplete
# LizNelson_Rainfall_multif0_incomplete
#     > Already done!
# TheKooks_Naive_multif0_incomplete
#     > Already done!
# SlowGhost_Peanut_multif0_incomplete
#     > Already done!
# MatthewEntwistle_TheArch_multif0_incomplete
#     > Already done!
# MusicDelta_Country2_multif0_incomplete
#     > Already done!
# VanillaIce_IceIceBaby_multif0_incomplete
#     > Already done!
# MusicDelta_Beethoven_multif0_incomplete
#     > Already done!
# AimeeNorwich_Child_multif0_incomplete
#     > Already done!
# TheScarletBrand_LesFleursDuMal_multif0_incomplete
#     > Already done!
# AllThatRemains_Chiron_multif0_incomplete
#     > Already done!
# Inxs_NeedYouTonight_multif0_incomplete
#     > Already done!
# CelestialShore_DieForUs_multif0_incomplete
# MightyMightyBosstones_WheredYouGo_multif0_incomplete
#     > Already done!
# Lushlife_ToynbeeSuite_multif0_incomplete
#     > Already done!
# ClaraBerryAndWooldog_Stella_multif0_incomplete
#     > Already done!
# Bush_Machinehead_multif0_incomplete
#     > Already done!
# Knack_MySharona_multif0_incomplete
#     > Already done!
# LizNelson_ImComingHome_multif0_incomplete
#     > Already done!
# LizNelson_Coldwar_multif0_incomplete
#     > Already done!
# BrunoMars_JustTheWayYouAre_multif0_incomplete
#     > Already done!
# Creepoid_OldTree_multif0_incomplete
# MusicDelta_Punk_multif0_incomplete
#     > Already done!
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe_multif0_incomplete
#     > Already done!
# VillagePeople_Ymca_multif0_incomplete
#     > Already done!
# CorinneBaileyRae_PutYourRecordsOn_multif0_incomplete
#     > Already done!
# CountingCrows_AccidentallyInLove_multif0_incomplete
#     > Already done!
# Tonic_IfYouCouldOnlySee_multif0_incomplete
#     > Already done!
# ColdWarKids_HangMeUpToDry_multif0_incomplete
#     > Already done!
# TheDistricts_Vermont_multif0_incomplete
#     > Already done!
# MusicDelta_ChineseDrama_multif0_incomplete
#     > Already done!
# Coldplay_InMyPlace_multif0_incomplete
#     > Already done!
# ThinLizzy_TheBoysAreBackInTown_multif0_incomplete
#     > Already done!
# Blondie_OneWayOrAnother_multif0_incomplete
#     > Already done!
# ChristinaAguilera_GenieInABottle_multif0_incomplete
#     > Already done!
# AlexanderRoss_GoodbyeBolero_multif0_incomplete
# MusicDelta_InTheHalloftheMountainKing_multif0_incomplete
#     > Already done!
# AimeeNorwich_Flying_multif0_incomplete
#     > Already done!
# MusicDelta_Britpop_multif0_incomplete
#     > Already done!
# LadyGaga_BornThisWay_multif0_incomplete
#     > Already done!
# BillyIdol_WhiteWedding_multif0_incomplete
#     > Already done!
# JoelHelander_Definition_multif0_incomplete
#     > Already done!
# Torres_NewSkin_multif0_incomplete
#     > Already done!
# NightPanther_Fire_multif0_incomplete
#     > Already done!
# TheBronx_SixDaysAWeek_multif0_incomplete
#     > Already done!
# Muffs_KidsInAmerica_multif0_incomplete
#     > Already done!
# AvaLuna_Waterduct_multif0_incomplete
# TrevorAndTheSoundwaves_AloneAndSad_multif0_incomplete
#     > Already done!
# KtTunstall_BlackHorseAndTheCherryTree_multif0_incomplete
#     > Already done!
# MirandaCosgrove_HeadphonesOn_multif0_incomplete
#     > Already done!
# MatthewEntwistle_DontYouEver_multif0_incomplete
#     > Already done!
# VampireWeekend_Cousins_multif0_incomplete
#     > Already done!
# Grants_PunchDrunk_multif0_incomplete
#     > Already done!
# Kiss_RockAndRollAllNite_multif0_incomplete
#     > Already done!
# TheAllAmericanRejects_DirtyLittleSecret_multif0_incomplete
#     > Already done!
# Phoenix_ScotchMorris_multif0_incomplete
#     > Already done!
# KeithUrban_IToldYouSo_multif0_incomplete
#     > Already done!
# TaylorSwift_LoveStory_multif0_incomplete
#     > Already done!
# ArcticMonkeys_Brainstorm_multif0_incomplete
#     > Already done!
# BrunoMars_MarryYou_multif0_incomplete
#     > Already done!
# TablaBreakbeatScience_PhaseTransition_multif0_incomplete
#     > Already done!
# Debussy_LenfantProdigue_multif0_incomplete
# Schumann_Mignon_multif0_incomplete
#     > Already done!
# FacesOnFilm_WaitingForGa_multif0_incomplete
#     > Already done!
# CassandraJenkins_PerfectDay_multif0_incomplete
#     > Already done!
# Phoenix_ElzicsFarewell_multif0_incomplete
#     > Already done!
# AClassicEducation_NightOwl_multif0_incomplete
# MichaelJackson_BeatIt_multif0_incomplete
#     > Already done!
# Mozart_BesterJungling_multif0_incomplete
#     > Already done!
# KarimDouaidy_Hopscotch_multif0_incomplete
#     > Already done!
# Schubert_Erstarrung_multif0_incomplete
#     > Already done!
# MusicDelta_ChineseChaoZhou_multif0_incomplete
#     > Already done!
# CountZero_Shake_multif0_incomplete
#     > Already done!
# Mozart_DiesBildnis_multif0_incomplete
#     > Already done!
# SecretMountains_HighHorse_multif0_incomplete
#     > Already done!
# Anberlin_TheFeelGoodDrag_multif0_incomplete
#     > Already done!
# LinkinPark_InTheEnd_multif0_incomplete
#     > Already done!
# ThirdEyeBlind_NeverLetYouGo_multif0_incomplete
#     > Already done!
# BrunoMars_Grenade_multif0_incomplete
#     > Already done!
# FleetwoodMac_Rhiannon_multif0_incomplete
#     > Already done!
# BigTroubles_Phantom_multif0_incomplete
# MusicDelta_Disco_multif0_incomplete
#     > Already done!
# BradPaisley_MudOnTheTires_multif0_incomplete
#     > Already done!
# CherryPoppinDaddies_ZootSuitRiot_multif0_incomplete
#     > Already done!
# TheTurtles_HappyTogether_multif0_incomplete
#     > Already done!
# Muse_Hysteria_multif0_incomplete
#     > Already done!
# MidnightBlue_StarsAreScreaming_multif0_incomplete
#     > Already done!
# KarimDouaidy_Yatora_multif0_incomplete
#     > Already done!
# CarlDouglas_KungFuFighting_multif0_incomplete
#     > Already done!
# ClaraBerryAndWooldog_Boys_multif0_incomplete
# MidnightBlue_HuntingSeason_multif0_incomplete
#     > Already done!
# TheKillers_SomebodyToldMe_multif0_incomplete
#     > Already done!
# CatMartino_IPromise_multif0_incomplete
#     > Already done!
# BlueOysterCult_DontFearTheReaper_multif0_incomplete
#     > Already done!
# MusicDelta_ChineseYaoZu_multif0_incomplete
#     > Already done!
# EthanHein_GirlOnABridge_multif0_incomplete
#     > Already done!
# Blink182_AllTheSmallThings_multif0_incomplete
#     > Already done!
# MatthewEntwistle_Lontano_multif0_incomplete
#     > Already done!
# BobSeger_OldTimeRockAndRoll_multif0_incomplete
#     > Already done!
# MusicDelta_Reggae_multif0_incomplete
#     > Already done!
# TaylorSwift_YouBelongWithMe_multif0_incomplete
#     > Already done!
# Tesla_ModernDayCowboy_multif0_incomplete
#     > Already done!
# ChrisBrown_Yeah_multif0_incomplete
#     > Already done!
# AcDc_BackInBlack_multif0_incomplete
#     > Already done!
# BlackSabbath_WarPigs_multif0_incomplete
#     > Already done!
# ChrisJacoby_PigsFoot_multif0_incomplete
# Plasma_GoodShout_multif0_incomplete
#     > Already done!
# Handel_TornamiAVagheggiar_multif0_incomplete
#     > Already done!
# Chromeo_Tenderoni_multif0_incomplete
#     > Already done!
# ClaraBerryAndWooldog_TheBadGuys_multif0_incomplete
# ArcadeFire_BlackMirror_multif0_incomplete
#     > Already done!
# LosLobos_LaBamba_multif0_incomplete
#     > Already done!
# Live_IAlone_multif0_incomplete
#     > Already done!
# BrandonWebster_DontHearAThing_multif0_incomplete
# MusicDelta_Rockabilly_multif0_incomplete
#     > Already done!
# StrandOfOaks_Spacestation_multif0_incomplete
#     > Already done!
# PatternIsMovement_SaveMe_multif0_incomplete
#     > Already done!
# MusicDelta_Vivaldi_multif0_incomplete
#     > Already done!
# Incubus_Drive_multif0_incomplete
#     > Already done!
# FooFighters_AllMyLife_multif0_incomplete
#     > Already done!
# LaRoux_Bulletproof_multif0_incomplete
#     > Already done!
# KtTunstall_SuddenlyISee_multif0_incomplete
#     > Already done!
# MusicDelta_Pachelbel_multif0_incomplete
#     > Already done!
# MusicDelta_Country1_multif0_incomplete
#     > Already done!
# TearsForFears_EverybodyWantsToRuleTheWorld_multif0_incomplete
#     > Already done!
# MartinaMcbride_ThisOnesForTheGirls_multif0_incomplete
#     > Already done!
# MusicDelta_BebopJazz_multif0_incomplete
#     > Already done!
# EthanHein_1930sSynthAndUprightBass_multif0_incomplete
# Meaxic_TakeAStep_multif0_incomplete
#     > Already done!
# MusicDelta_SwingJazz_multif0_incomplete
#     > Already done!
# LittleTybee_TheAlchemist_multif0_incomplete
#     > Already done!
# MusicDelta_Grunge_multif0_incomplete
#     > Already done!
# Phoenix_LarkOnTheStrandDrummondCastle_multif0_incomplete
#     > Already done!
# LadyGaga_BadRomance_multif0_incomplete
#     > Already done!
# MileyCyrus_7Things_multif0_incomplete
#     > Already done!
# JoelHelander_IntheAtticBedroom_multif0_incomplete
#     > Already done!
# MusicDelta_GriegTrolltog_multif0_incomplete
#     > Already done!
# Kansas_CarryOnMyWaywardSon_multif0_incomplete
#     > Already done!
# ThirdEyeBlind_Jumper_multif0_incomplete
#     > Already done!
# SlowGhost_YoureAMystery_multif0_incomplete
#     > Already done!
# Boston_MoreThanAFeeling_multif0_incomplete
#     > Already done!
# TablaBreakbeatScience_Animoog_multif0_incomplete
#     > Already done!
# AmarLal_Rest_multif0_incomplete
# MarvinGaye_WhatsGoingOn_multif0_incomplete
#     > Already done!
# DreamersOfTheGhetto_HeavyLove_multif0_incomplete
# StevenClark_Bounty_multif0_incomplete
#     > Already done!
# KaiserChiefs_Ruby_multif0_incomplete
#     > Already done!
# Phoenix_ColliersDaughter_multif0_incomplete
#     > Already done!
# MarvinGaye_IHeardItThroughTheGrapevine_multif0_incomplete
#     > Already done!
# MusicDelta_SpeedMetal_multif0_incomplete
#     > Already done!
# AnEndlessSporadic_Anything_multif0_incomplete
#     > Already done!
# TPain_Bartender_multif0_incomplete
#     > Already done!
# MusicDelta_Beatles_multif0_incomplete
#     > Already done!
# Adele_SomeoneLikeYou_multif0_incomplete
#     > Already done!
# MusicDelta_LatinJazz_multif0_incomplete
#     > Already done!
# HopAlong_SisterCities_multif0_incomplete
#     > Already done!
# PurlingHiss_Lolita_multif0_incomplete
#     > Already done!
# KennyChesney_SheThinksMyTractorsSexy_multif0_incomplete
#     > Already done!
# MatthewEntwistle_AnEveningWithOliver_multif0_incomplete
#     > Already done!
# TheFranckDuo_FranckViolinSonataInAMajorMovement1_multif0_incomplete
#     > Already done!
# ClaraBerryAndWooldog_WaltzForMyVictims_multif0_incomplete
# Meaxic_YouListen_multif0_incomplete
#     > Already done!
# TheLastGoodnight_PicturesOfYou_multif0_incomplete
#     > Already done!
# LilyAllen_NotFair_multif0_incomplete
#     > Already done!
# Lit_MyOwnWorstEnemy_multif0_incomplete
#     > Already done!
# Wolf_DieBekherte_multif0_incomplete
#     > Already done!
# MusicDelta_FunkJazz_multif0_incomplete
#     > Already done!
# MatthewEntwistle_TheFlaxenField_multif0_incomplete
#     > Already done!
# Cayetana_MissThing_multif0_incomplete
#     > Already done!
# CheapTrick_IWantYouToWantMe_multif0_incomplete
#     > Already done!
# CarrieUnderwood_HomeSweetHome_multif0_incomplete
#     > Already done!
# Phoenix_SeanCaughlinsTheScartaglen_multif0_incomplete
#     > Already done!
# ClaraBerryAndWooldog_AirTraffic_multif0_incomplete
#     > Already done!
# MusicDelta_FreeJazz_multif0_incomplete
#     > Already done!
# MusicDelta_Hendrix_multif0_incomplete
#     > Already done!
# VampireWeekend_Holiday_multif0_incomplete
#     > Already done!
# BrooksDunn_HillbillyDeluxe_multif0_incomplete
#     > Already done!
# SweetLights_YouLetMeDown_multif0_incomplete
#     > Already done!
# Phoenix_BrokenPledgeChicagoReel_multif0_incomplete
#     > Already done!
# BryanAdams_SummerOf69_multif0_incomplete
#     > Already done!
# FilthyBird_IdLikeToKnow_multif0_incomplete
#     > Already done!
# Korn_FreakOnALeash_multif0_incomplete
#     > Already done!
# MusicDelta_ModalJazz_multif0_incomplete
#     > Already done!
# EthanHein_BluesForNofi_multif0_incomplete
#     > Already done!
# AlexanderRoss_VelvetCurtain_multif0_incomplete
# FlightOfTheConcords_BusinessTime_multif0_incomplete
#     > Already done!
# MusicDelta_80sRock_multif0_incomplete
#     > Already done!
# MusicDelta_Rock_multif0_incomplete
#     > Already done!
# ModestMouse_FloatOn_multif0_incomplete
#     > Already done!
# MusicDelta_CoolJazz_multif0_incomplete
#     > Already done!
# Misfits_AstroZombies_multif0_incomplete
#     > Already done!
# TheAllmanBrothersBand_RamblinMan_multif0_incomplete
#     > Already done!
# DeadMilkmen_PrisonersCinema_multif0_incomplete
#     > Already done!
# Maroon5_ThisLove_multif0_incomplete
#     > Already done!
# MusicDelta_ChineseXinJing_multif0_incomplete
#     > Already done!
# CroqueMadame_Oil_multif0_incomplete
# FruitCathedral_KeepMeRunnin_multif0_incomplete
#     > Already done!
# TablaBreakbeatScience_WhoIsIt_multif0_incomplete
#     > Already done!
# HeladoNegro_MitadDelMundo_multif0_incomplete
#     > Already done!
# Aerosmith_LoveInAnElevator_multif0_incomplete
#     > Already done!
# Coldplay_Shiver_multif0_incomplete
#     > Already done!
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_multif0_incomplete
#     > Already done!
# LynyrdSkynyrd_FreeBird_multif0_incomplete
#     > Already done!
# SlowGhost_FirstSnow_multif0_incomplete
#     > Already done!
# AmarLal_SpringDay1_multif0_incomplete
#     > Already done!
# AlanisMorissette_YouOughtaKnow_multif0_incomplete
#     > Already done!
# KanyeWest_LoveLockdown_multif0_incomplete
#     > Already done!
# TablaBreakbeatScience_CaptainSky_multif0_incomplete
#     > Already done!
# TomPettyAndTheHeartbreakers_IWontBackDown_multif0_incomplete
#     > Already done!
# BlackEyedPeas_IGottaFeeling_multif0_incomplete
#     > Already done!
# PortStWillow_StayEven_multif0_incomplete
#     > Already done!
# TomPetty_FreeFallin_multif0_incomplete
#     > Already done!
# JoelHelander_ExcessiveResistancetoChange_multif0_incomplete
#     > Already done!
# MusicDelta_Shadows_multif0_incomplete
#     > Already done!
# MatthewEntwistle_FairerHopes_multif0_incomplete
#     > Already done!
# FamilyBand_Again_multif0_incomplete
#     > Already done!
# MusicDelta_ChineseJiangNan_multif0_incomplete
#     > Already done!
# MusicDelta_ChineseHenan_multif0_incomplete
#     > Already done!
# MutualBenefit_NotForNothing_multif0_incomplete
#     > Already done!
# BillySquier_TheStroke_multif0_incomplete
#     > Already done!
# ChrisJacoby_BoothShotLincoln_multif0_incomplete
# Auctioneer_OurFutureFaces_multif0_incomplete
# HezekiahJones_BorrowedHeart_multif0_incomplete
#     > Already done!
# LennyKravitz_AreYouGonnaGoMyWay_multif0_incomplete
#     > Already done!
# TheSoSoGlos_Emergency_multif0_incomplete
#     > Already done!
# SlowGhost_MidnightGroove_multif0_incomplete
#     > Already done!
# InvisibleFamiliars_DisturbingWildlife_multif0_incomplete
#     > Already done!
# AHa_TakeOnMe_multif0_incomplete
#     > Already done!
# TalkingHeads_PsychoKiller_multif0_incomplete
#     > Already done!
# TheBronx_FalseAlarm_multif0_incomplete
#     > Already done!
# MusicDelta_FusionJazz_multif0_incomplete
#     > Already done!

# %%
files = glob.glob(os.path.join(dirname, '*.npz'))

# %%
f = files[0]
dat = np.load(f)

# %%
x = dat['data_in']

# %%
x.shape
# Out:
# (6, 600, 39216)

# %%
f
# Out:
# 'multif0_incomplete/TheKitchenettes_Alive_multif0_incomplete.npz'
